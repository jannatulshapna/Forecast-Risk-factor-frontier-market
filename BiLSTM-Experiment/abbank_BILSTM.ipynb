# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("/content/ABBANK.csv",parse_dates=['DATE'])
df.head()
# Out:
#      #       DATE TRADING CODE  LTP*  ...   YCP  TRADE  VALUE (mn)   VOLUME
# 0  439 2018-05-08       ABBANK  11.8  ...  11.8    140       2.675  224,757
# 1  438 2018-06-08       ABBANK  12.0  ...  11.9    117       1.872  158,467
# 2  437 2018-07-08       ABBANK  12.0  ...  11.9    139       2.222  186,217
# 3  436 2018-08-08       ABBANK  12.3  ...  12.0    216       6.382  525,104
# 4  435 2018-09-08       ABBANK  12.5  ...  12.2    466      11.309  906,224
#
# [5 rows x 12 columns]

# %%
# Sort DataFrame by date
df = df.sort_values('DATE')

# Double check the result
df.head()
# Out:
#       #       DATE TRADING CODE  LTP*  ...   YCP  TRADE  VALUE (mn)   VOLUME
# 36  403 2018-01-10       ABBANK  12.6  ...  12.7    128       4.411  349,439
# 59  380 2018-01-11       ABBANK  11.3  ...  11.6    111       4.567  395,514
# 37  402 2018-02-10       ABBANK  12.4  ...  12.6    159       6.574  526,280
# 79  360 2018-02-12       ABBANK  11.4  ...  11.6    234       8.858  768,778
# 16  423 2018-03-09       ABBANK  13.5  ...  13.8    236       4.782  354,776
#
# [5 rows x 12 columns]

# %%
df = df.set_index('DATE')
df.head(3)
# Out:
#               # TRADING CODE  LTP*  HIGH  ...   YCP  TRADE  VALUE (mn)   VOLUME
# DATE                                      ...
# 2018-01-10  403       ABBANK  12.6  12.8  ...  12.7    128       4.411  349,439
# 2018-01-11  380       ABBANK  11.3  11.7  ...  11.6    111       4.567  395,514
# 2018-02-10  402       ABBANK  12.4  12.6  ...  12.6    159       6.574  526,280
#
# [3 rows x 11 columns]

# %%
df['daily_ret'] = df['CLOSEP*'].pct_change()
df['daily_ret'] = df['daily_ret'].fillna(0.0)

# %%
df['volatility']= df['daily_ret'].rolling(window=21).std()
df['volatility'] = df['volatility'].fillna(0.0)

# %%
df['volatility'] = df['volatility']*100

# %%
import matplotlib.pyplot as plt

# %%
df=df.reset_index()['volatility']

# %%
plt.plot(df)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
df.shape
# Out:
# (439, 1)

# %%
##splitting dataset into train and test split where train=70 percent and test=30 percent
training_size=int(len(df)*0.70)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
training_size,test_size
# Out:
# (307, 132)

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [],[]
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (206, 100)
# (206,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import Bidirectional

# %%
model=Sequential()
model.add(Bidirectional(LSTM(50,return_sequences=True,input_shape=(100,1))))
model.add(Bidirectional(LSTM(50,return_sequences=True)))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 13s 576ms/step - loss: 0.1993 - val_loss: 0.1111
# Epoch 2/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0338 - val_loss: 0.0223
# Epoch 3/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0277 - val_loss: 0.0704
# Epoch 4/100
# 7/7 [==============================] - 1s 213ms/step - loss: 0.0212 - val_loss: 0.0248
# Epoch 5/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0223 - val_loss: 0.0343
# Epoch 6/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0222 - val_loss: 0.0325
# Epoch 7/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0174 - val_loss: 0.0253
# Epoch 8/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0148 - val_loss: 0.0252
# Epoch 9/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0144 - val_loss: 0.0267
# Epoch 10/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0139 - val_loss: 0.0224
# Epoch 11/100
# 7/7 [==============================] - 1s 214ms/step - loss: 0.0176 - val_loss: 0.0362
# Epoch 12/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0160 - val_loss: 0.0271
# Epoch 13/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0127 - val_loss: 0.0254
# Epoch 14/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0123 - val_loss: 0.0369
# Epoch 15/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0108 - val_loss: 0.0225
# Epoch 16/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0097 - val_loss: 0.0286
# Epoch 17/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0116 - val_loss: 0.0240
# Epoch 18/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0150 - val_loss: 0.0346
# Epoch 19/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0088 - val_loss: 0.0290
# Epoch 20/100
# 7/7 [==============================] - 2s 246ms/step - loss: 0.0097 - val_loss: 0.0355
# Epoch 21/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0094 - val_loss: 0.0323
# Epoch 22/100
# 7/7 [==============================] - 1s 215ms/step - loss: 0.0111 - val_loss: 0.0330
# Epoch 23/100
# 7/7 [==============================] - 1s 213ms/step - loss: 0.0095 - val_loss: 0.0355
# Epoch 24/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0097 - val_loss: 0.0441
# Epoch 25/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0097 - val_loss: 0.0379
# Epoch 26/100
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0089 - val_loss: 0.0432
# Epoch 27/100
# 7/7 [==============================] - 1s 215ms/step - loss: 0.0101 - val_loss: 0.0436
# Epoch 28/100
# 7/7 [==============================] - 1s 214ms/step - loss: 0.0110 - val_loss: 0.0380
# Epoch 29/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0089 - val_loss: 0.0358
# Epoch 30/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0110 - val_loss: 0.0376
# Epoch 31/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0099 - val_loss: 0.0285
# Epoch 32/100
# 7/7 [==============================] - 1s 215ms/step - loss: 0.0123 - val_loss: 0.0321
# Epoch 33/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0120 - val_loss: 0.0540
# Epoch 34/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0086 - val_loss: 0.0343
# Epoch 35/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0103 - val_loss: 0.0388
# Epoch 36/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0080 - val_loss: 0.0426
# Epoch 37/100
# 7/7 [==============================] - 1s 215ms/step - loss: 0.0092 - val_loss: 0.0550
# Epoch 38/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0122 - val_loss: 0.0395
# Epoch 39/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0085 - val_loss: 0.0399
# Epoch 40/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0091 - val_loss: 0.0444
# Epoch 41/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0096 - val_loss: 0.0478
# Epoch 42/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0075 - val_loss: 0.0497
# Epoch 43/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0064 - val_loss: 0.0444
# Epoch 44/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0091 - val_loss: 0.0440
# Epoch 45/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0100 - val_loss: 0.0584
# Epoch 46/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0151 - val_loss: 0.0570
# Epoch 47/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0078 - val_loss: 0.0279
# Epoch 48/100
# 7/7 [==============================] - 2s 247ms/step - loss: 0.0119 - val_loss: 0.0546
# Epoch 49/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0082 - val_loss: 0.0488
# Epoch 50/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0086 - val_loss: 0.0399
# Epoch 51/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0086 - val_loss: 0.0546
# Epoch 52/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0085 - val_loss: 0.0522
# Epoch 53/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0092 - val_loss: 0.0460
# Epoch 54/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0091 - val_loss: 0.0532
# Epoch 55/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0083 - val_loss: 0.0464
# Epoch 56/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0096 - val_loss: 0.0548
# Epoch 57/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0067 - val_loss: 0.0520
# Epoch 58/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0073 - val_loss: 0.0520
# Epoch 59/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0073 - val_loss: 0.0489
# Epoch 60/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0091 - val_loss: 0.0597
# Epoch 61/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0091 - val_loss: 0.0605
# Epoch 62/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0072 - val_loss: 0.0648
# Epoch 63/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0084 - val_loss: 0.0647
# Epoch 64/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0080 - val_loss: 0.0640
# Epoch 65/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0100 - val_loss: 0.0423
# Epoch 66/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0091 - val_loss: 0.0466
# Epoch 67/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0060 - val_loss: 0.0457
# Epoch 68/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0100 - val_loss: 0.0603
# Epoch 69/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0100 - val_loss: 0.0460
# Epoch 70/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0070 - val_loss: 0.0471
# Epoch 71/100
# 7/7 [==============================] - 2s 232ms/step - loss: 0.0068 - val_loss: 0.0573
# Epoch 72/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0113 - val_loss: 0.0638
# Epoch 73/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0093 - val_loss: 0.0650
# Epoch 74/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0095 - val_loss: 0.0547
# Epoch 75/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0081 - val_loss: 0.0517
# Epoch 76/100
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0076 - val_loss: 0.0619
# Epoch 77/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0085 - val_loss: 0.0539
# Epoch 78/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0059 - val_loss: 0.0480
# Epoch 79/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0065 - val_loss: 0.0496
# Epoch 80/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0069 - val_loss: 0.0463
# Epoch 81/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0101 - val_loss: 0.0566
# Epoch 82/100
# 7/7 [==============================] - 2s 232ms/step - loss: 0.0078 - val_loss: 0.0500
# Epoch 83/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0052 - val_loss: 0.0376
# Epoch 84/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0100 - val_loss: 0.0507
# Epoch 85/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0089 - val_loss: 0.0473
# Epoch 86/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0090 - val_loss: 0.0378
# Epoch 87/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0073 - val_loss: 0.0532
# Epoch 88/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0085 - val_loss: 0.0444
# Epoch 89/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0067 - val_loss: 0.0495
# Epoch 90/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0079 - val_loss: 0.0575
# Epoch 91/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0093 - val_loss: 0.0534
# Epoch 92/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0105 - val_loss: 0.0417
# Epoch 93/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0084 - val_loss: 0.0442
# Epoch 94/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0079 - val_loss: 0.0518
# Epoch 95/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0069 - val_loss: 0.0711
# Epoch 96/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0088 - val_loss: 0.0368
# Epoch 97/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0096 - val_loss: 0.0509
# Epoch 98/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0091 - val_loss: 0.0393
# Epoch 99/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0068 - val_loss: 0.0343
# Epoch 100/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0067 - val_loss: 0.0362

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath = "/content/drive/MyDrive/stock_price_BILSTM/modelsABBANK/model.h5"
model.save(filepath)

# %%
from keras.models import load_model
f1 = '/content/drive/MyDrive/stock_price_BILSTM/modelsABBANK/model.h5'
model = load_model(f1)

# %%
import tensorflow as tf
from sklearn.metrics import r2_score

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict = np.reshape(train_predict,(1, train_predict.size))
train_predict=scaler.inverse_transform(train_predict)
test_predict = np.reshape(test_predict,(1, test_predict.size))
test_predict=scaler.inverse_transform(test_predict)
X = np.reshape(ytest,(1, ytest.size))
Y_test =scaler.inverse_transform(X)

# %%
Y_test
# Out:
# array([[5.77833297, 5.4605433 , 5.45780979, 4.95236307, 4.90427289,
#         4.90427289, 4.90427289, 4.91069709, 4.91069709, 4.9158754 ,
#         4.9158754 , 4.9158754 , 4.78334713, 4.86006931, 4.96822042,
#         5.32295157, 5.55344854, 4.75624882, 3.50806423, 4.0686967 ,
#         4.10598373, 4.5598002 , 4.5587057 , 4.57335973, 4.74973621,
#         5.58531825, 5.98288539, 6.02029215, 6.84130014, 6.84130014,
#         7.24987936]])

# %%
test_predict
# Out:
# array([[ 8.220818 ,  8.2576275,  8.225558 ,  8.235079 ,  8.126936 ,
#          8.062862 ,  8.056816 ,  8.0999975,  8.183781 ,  8.295134 ,
#          8.427237 ,  8.638065 ,  8.789088 ,  8.889207 ,  9.006713 ,
#          9.15189  ,  9.394837 ,  9.660812 ,  9.5802355,  9.047373 ,
#          8.758097 ,  8.52568  ,  8.489339 ,  8.464749 ,  8.447239 ,
#          8.489915 ,  8.819858 ,  9.239226 ,  9.588235 , 10.133948 ,
#         10.542088 ]], dtype=float32)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
#Y_test = Y_test.transpose()
RMSE = math.sqrt(mean_squared_error(Y_test,test_predict))
RMSE
# Out:
# 3.9660966828294586

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(Y_test,test_predict)
print('MAE: %f' % mae)
# Out:
# MAE: 3.912263

# %%
train_predict.shape
# Out:
# (1, 206)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
test_predict = test_predict.transpose()

# %%
train_predict = train_predict.transpose()

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df),color ='blue', label ='original')
plt.plot(trainPredictPlot, color ='orange', label ='predicted')
plt.plot(testPredictPlot , color ='red', label ='tested')
#plt.show()
plt.xlabel('number of days')
plt.ylabel('volatility magnitude')
plt.title('ABBANk Risk Factor Prediction')
plt.legend(loc='best')
plt.show(block=False)

# %%
x_input=test_data[32:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<10):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

#print(lst_output)
# Out:
# [0.53154635]
# 101
# 1 day input [0.29892411 0.30369517 0.24108716 0.22878582 0.22841025 0.2267251
#  0.22673823 0.22673823 0.22640815 0.22640815 0.22603772 0.22565318
#  0.23066105 0.23102229 0.25594638 0.26792732 0.27129029 0.2447781
#  0.19192441 0.18954479 0.19031594 0.19105481 0.19122905 0.19313052
#  0.19317772 0.19317772 0.19317772 0.20017361 0.20207059 0.25775035
#  0.29665808 0.32179847 0.32014706 0.31681408 0.32117795 0.30134366
#  0.30925855 0.29821057 0.2958408  0.29833505 0.29835887 0.33295912
#  0.38506751 0.38373929 0.38279213 0.39941192 0.40414346 0.41282035
#  0.4098142  0.42393687 0.39249416 0.36505131 0.34238201 0.34186826
#  0.34130355 0.338122   0.33674049 0.31841139 0.32404033 0.32460131
#  0.32373662 0.32321626 0.2868974  0.26531349 0.30338564 0.30534555
#  0.28400671 0.27730889 0.2620578  0.26192661 0.23766964 0.23536174
#  0.23536174 0.23536174 0.23567004 0.23567004 0.23591855 0.23591855
#  0.23591855 0.22955837 0.23324035 0.23843065 0.25545461 0.26651643
#  0.22825789 0.16835606 0.19526147 0.19705091 0.21883009 0.21877757
#  0.21948083 0.22794534 0.26804589 0.2871256  0.28892079 0.32832192
#  0.32832192 0.34793011 0.35074026 0.53154635]
# 1 day output [[0.58341277]]
# 2 day input [0.30369517 0.24108716 0.22878582 0.22841025 0.2267251  0.22673823
#  0.22673823 0.22640815 0.22640815 0.22603772 0.22565318 0.23066105
#  0.23102229 0.25594638 0.26792732 0.27129029 0.2447781  0.19192441
#  0.18954479 0.19031594 0.19105481 0.19122905 0.19313052 0.19317772
#  0.19317772 0.19317772 0.20017361 0.20207059 0.25775035 0.29665808
#  0.32179847 0.32014706 0.31681408 0.32117795 0.30134366 0.30925855
#  0.29821057 0.2958408  0.29833505 0.29835887 0.33295912 0.38506751
#  0.38373929 0.38279213 0.39941192 0.40414346 0.41282035 0.4098142
#  0.42393687 0.39249416 0.36505131 0.34238201 0.34186826 0.34130355
#  0.338122   0.33674049 0.31841139 0.32404033 0.32460131 0.32373662
#  0.32321626 0.2868974  0.26531349 0.30338564 0.30534555 0.28400671
#  0.27730889 0.2620578  0.26192661 0.23766964 0.23536174 0.23536174
#  0.23536174 0.23567004 0.23567004 0.23591855 0.23591855 0.23591855
#  0.22955837 0.23324035 0.23843065 0.25545461 0.26651643 0.22825789
#  0.16835606 0.19526147 0.19705091 0.21883009 0.21877757 0.21948083
#  0.22794534 0.26804589 0.2871256  0.28892079 0.32832192 0.32832192
#  0.34793011 0.35074026 0.53154635 0.58341277]
# 2 day output [[0.6247217]]
# 3 day input [0.24108716 0.22878582 0.22841025 0.2267251  0.22673823 0.22673823
#  0.22640815 0.22640815 0.22603772 0.22565318 0.23066105 0.23102229
#  0.25594638 0.26792732 0.27129029 0.2447781  0.19192441 0.18954479
#  0.19031594 0.19105481 0.19122905 0.19313052 0.19317772 0.19317772
#  0.19317772 0.20017361 0.20207059 0.25775035 0.29665808 0.32179847
#  0.32014706 0.31681408 0.32117795 0.30134366 0.30925855 0.29821057
#  0.2958408  0.29833505 0.29835887 0.33295912 0.38506751 0.38373929
#  0.38279213 0.39941192 0.40414346 0.41282035 0.4098142  0.42393687
#  0.39249416 0.36505131 0.34238201 0.34186826 0.34130355 0.338122
#  0.33674049 0.31841139 0.32404033 0.32460131 0.32373662 0.32321626
#  0.2868974  0.26531349 0.30338564 0.30534555 0.28400671 0.27730889
#  0.2620578  0.26192661 0.23766964 0.23536174 0.23536174 0.23536174
#  0.23567004 0.23567004 0.23591855 0.23591855 0.23591855 0.22955837
#  0.23324035 0.23843065 0.25545461 0.26651643 0.22825789 0.16835606
#  0.19526147 0.19705091 0.21883009 0.21877757 0.21948083 0.22794534
#  0.26804589 0.2871256  0.28892079 0.32832192 0.32832192 0.34793011
#  0.35074026 0.53154635 0.58341277 0.62472171]
# 3 day output [[0.65071017]]
# 4 day input [0.22878582 0.22841025 0.2267251  0.22673823 0.22673823 0.22640815
#  0.22640815 0.22603772 0.22565318 0.23066105 0.23102229 0.25594638
#  0.26792732 0.27129029 0.2447781  0.19192441 0.18954479 0.19031594
#  0.19105481 0.19122905 0.19313052 0.19317772 0.19317772 0.19317772
#  0.20017361 0.20207059 0.25775035 0.29665808 0.32179847 0.32014706
#  0.31681408 0.32117795 0.30134366 0.30925855 0.29821057 0.2958408
#  0.29833505 0.29835887 0.33295912 0.38506751 0.38373929 0.38279213
#  0.39941192 0.40414346 0.41282035 0.4098142  0.42393687 0.39249416
#  0.36505131 0.34238201 0.34186826 0.34130355 0.338122   0.33674049
#  0.31841139 0.32404033 0.32460131 0.32373662 0.32321626 0.2868974
#  0.26531349 0.30338564 0.30534555 0.28400671 0.27730889 0.2620578
#  0.26192661 0.23766964 0.23536174 0.23536174 0.23536174 0.23567004
#  0.23567004 0.23591855 0.23591855 0.23591855 0.22955837 0.23324035
#  0.23843065 0.25545461 0.26651643 0.22825789 0.16835606 0.19526147
#  0.19705091 0.21883009 0.21877757 0.21948083 0.22794534 0.26804589
#  0.2871256  0.28892079 0.32832192 0.32832192 0.34793011 0.35074026
#  0.53154635 0.58341277 0.62472171 0.65071017]
# 4 day output [[0.6627915]]
# 5 day input [0.22841025 0.2267251  0.22673823 0.22673823 0.22640815 0.22640815
#  0.22603772 0.22565318 0.23066105 0.23102229 0.25594638 0.26792732
#  0.27129029 0.2447781  0.19192441 0.18954479 0.19031594 0.19105481
#  0.19122905 0.19313052 0.19317772 0.19317772 0.19317772 0.20017361
#  0.20207059 0.25775035 0.29665808 0.32179847 0.32014706 0.31681408
#  0.32117795 0.30134366 0.30925855 0.29821057 0.2958408  0.29833505
#  0.29835887 0.33295912 0.38506751 0.38373929 0.38279213 0.39941192
#  0.40414346 0.41282035 0.4098142  0.42393687 0.39249416 0.36505131
#  0.34238201 0.34186826 0.34130355 0.338122   0.33674049 0.31841139
#  0.32404033 0.32460131 0.32373662 0.32321626 0.2868974  0.26531349
#  0.30338564 0.30534555 0.28400671 0.27730889 0.2620578  0.26192661
#  0.23766964 0.23536174 0.23536174 0.23536174 0.23567004 0.23567004
#  0.23591855 0.23591855 0.23591855 0.22955837 0.23324035 0.23843065
#  0.25545461 0.26651643 0.22825789 0.16835606 0.19526147 0.19705091
#  0.21883009 0.21877757 0.21948083 0.22794534 0.26804589 0.2871256
#  0.28892079 0.32832192 0.32832192 0.34793011 0.35074026 0.53154635
#  0.58341277 0.62472171 0.65071017 0.66279149]
# 5 day output [[0.6669203]]
# 6 day input [0.2267251  0.22673823 0.22673823 0.22640815 0.22640815 0.22603772
#  0.22565318 0.23066105 0.23102229 0.25594638 0.26792732 0.27129029
#  0.2447781  0.19192441 0.18954479 0.19031594 0.19105481 0.19122905
#  0.19313052 0.19317772 0.19317772 0.19317772 0.20017361 0.20207059
#  0.25775035 0.29665808 0.32179847 0.32014706 0.31681408 0.32117795
#  0.30134366 0.30925855 0.29821057 0.2958408  0.29833505 0.29835887
#  0.33295912 0.38506751 0.38373929 0.38279213 0.39941192 0.40414346
#  0.41282035 0.4098142  0.42393687 0.39249416 0.36505131 0.34238201
#  0.34186826 0.34130355 0.338122   0.33674049 0.31841139 0.32404033
#  0.32460131 0.32373662 0.32321626 0.2868974  0.26531349 0.30338564
#  0.30534555 0.28400671 0.27730889 0.2620578  0.26192661 0.23766964
#  0.23536174 0.23536174 0.23536174 0.23567004 0.23567004 0.23591855
#  0.23591855 0.23591855 0.22955837 0.23324035 0.23843065 0.25545461
#  0.26651643 0.22825789 0.16835606 0.19526147 0.19705091 0.21883009
#  0.21877757 0.21948083 0.22794534 0.26804589 0.2871256  0.28892079
#  0.32832192 0.32832192 0.34793011 0.35074026 0.53154635 0.58341277
#  0.62472171 0.65071017 0.66279149 0.6669203 ]
# 6 day output [[0.66701597]]
# 7 day input [0.22673823 0.22673823 0.22640815 0.22640815 0.22603772 0.22565318
#  0.23066105 0.23102229 0.25594638 0.26792732 0.27129029 0.2447781
#  0.19192441 0.18954479 0.19031594 0.19105481 0.19122905 0.19313052
#  0.19317772 0.19317772 0.19317772 0.20017361 0.20207059 0.25775035
#  0.29665808 0.32179847 0.32014706 0.31681408 0.32117795 0.30134366
#  0.30925855 0.29821057 0.2958408  0.29833505 0.29835887 0.33295912
#  0.38506751 0.38373929 0.38279213 0.39941192 0.40414346 0.41282035
#  0.4098142  0.42393687 0.39249416 0.36505131 0.34238201 0.34186826
#  0.34130355 0.338122   0.33674049 0.31841139 0.32404033 0.32460131
#  0.32373662 0.32321626 0.2868974  0.26531349 0.30338564 0.30534555
#  0.28400671 0.27730889 0.2620578  0.26192661 0.23766964 0.23536174
#  0.23536174 0.23536174 0.23567004 0.23567004 0.23591855 0.23591855
#  0.23591855 0.22955837 0.23324035 0.23843065 0.25545461 0.26651643
#  0.22825789 0.16835606 0.19526147 0.19705091 0.21883009 0.21877757
#  0.21948083 0.22794534 0.26804589 0.2871256  0.28892079 0.32832192
#  0.32832192 0.34793011 0.35074026 0.53154635 0.58341277 0.62472171
#  0.65071017 0.66279149 0.6669203  0.66701597]
# 7 day output [[0.6650504]]
# 8 day input [0.22673823 0.22640815 0.22640815 0.22603772 0.22565318 0.23066105
#  0.23102229 0.25594638 0.26792732 0.27129029 0.2447781  0.19192441
#  0.18954479 0.19031594 0.19105481 0.19122905 0.19313052 0.19317772
#  0.19317772 0.19317772 0.20017361 0.20207059 0.25775035 0.29665808
#  0.32179847 0.32014706 0.31681408 0.32117795 0.30134366 0.30925855
#  0.29821057 0.2958408  0.29833505 0.29835887 0.33295912 0.38506751
#  0.38373929 0.38279213 0.39941192 0.40414346 0.41282035 0.4098142
#  0.42393687 0.39249416 0.36505131 0.34238201 0.34186826 0.34130355
#  0.338122   0.33674049 0.31841139 0.32404033 0.32460131 0.32373662
#  0.32321626 0.2868974  0.26531349 0.30338564 0.30534555 0.28400671
#  0.27730889 0.2620578  0.26192661 0.23766964 0.23536174 0.23536174
#  0.23536174 0.23567004 0.23567004 0.23591855 0.23591855 0.23591855
#  0.22955837 0.23324035 0.23843065 0.25545461 0.26651643 0.22825789
#  0.16835606 0.19526147 0.19705091 0.21883009 0.21877757 0.21948083
#  0.22794534 0.26804589 0.2871256  0.28892079 0.32832192 0.32832192
#  0.34793011 0.35074026 0.53154635 0.58341277 0.62472171 0.65071017
#  0.66279149 0.6669203  0.66701597 0.66505039]
# 8 day output [[0.66219294]]
# 9 day input [0.22640815 0.22640815 0.22603772 0.22565318 0.23066105 0.23102229
#  0.25594638 0.26792732 0.27129029 0.2447781  0.19192441 0.18954479
#  0.19031594 0.19105481 0.19122905 0.19313052 0.19317772 0.19317772
#  0.19317772 0.20017361 0.20207059 0.25775035 0.29665808 0.32179847
#  0.32014706 0.31681408 0.32117795 0.30134366 0.30925855 0.29821057
#  0.2958408  0.29833505 0.29835887 0.33295912 0.38506751 0.38373929
#  0.38279213 0.39941192 0.40414346 0.41282035 0.4098142  0.42393687
#  0.39249416 0.36505131 0.34238201 0.34186826 0.34130355 0.338122
#  0.33674049 0.31841139 0.32404033 0.32460131 0.32373662 0.32321626
#  0.2868974  0.26531349 0.30338564 0.30534555 0.28400671 0.27730889
#  0.2620578  0.26192661 0.23766964 0.23536174 0.23536174 0.23536174
#  0.23567004 0.23567004 0.23591855 0.23591855 0.23591855 0.22955837
#  0.23324035 0.23843065 0.25545461 0.26651643 0.22825789 0.16835606
#  0.19526147 0.19705091 0.21883009 0.21877757 0.21948083 0.22794534
#  0.26804589 0.2871256  0.28892079 0.32832192 0.32832192 0.34793011
#  0.35074026 0.53154635 0.58341277 0.62472171 0.65071017 0.66279149
#  0.6669203  0.66701597 0.66505039 0.66219294]
# 9 day output [[0.6592365]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,111)

# %%
plt.plot(day_new,scaler.inverse_transform(df[339:]),color ='blue', label ='origial')
plt.plot(day_pred,scaler.inverse_transform(lst_output),color='red', label='future')
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 10 Days Forecasting')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=df.tolist()
df3.extend(lst_output)
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 30 Days Forecasting')
plt.plot(df3[409:],color='red', label='future')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)

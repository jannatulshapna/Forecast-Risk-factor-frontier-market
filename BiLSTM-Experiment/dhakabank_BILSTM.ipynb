# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("/content/IBNSINA.csv",parse_dates=['DATE'])
df.head()
# Out:
#      #       DATE TRADING CODE   LTP*  ...    YCP   TRADE  VALUE (mn)    VOLUME
# 0  439 2018-05-08      IBNSINA  306.0  ...  306.3  1217.0      64.278  206556.0
# 1  438 2018-06-08      IBNSINA  301.8  ...  306.1   744.0      32.516  107437.0
# 2  437 2018-07-08      IBNSINA  296.6  ...  300.3   817.0      37.425  125501.0
# 3  436 2018-08-08      IBNSINA  298.8  ...  295.1   708.0      39.266  131382.0
# 4  435 2018-09-08      IBNSINA  300.0  ...  296.3   628.0      24.447   82592.0
#
# [5 rows x 12 columns]

# %%
# Sort DataFrame by date
df = df.sort_values('DATE')

# Double check the result
df.head()
# Out:
#       #       DATE TRADING CODE   LTP*  ...    YCP  TRADE  VALUE (mn)    VOLUME
# 36  403 2018-01-10      IBNSINA  280.1  ...  279.7  698.0      31.318  110873.0
# 59  380 2018-01-11      IBNSINA  238.3  ...  240.4  296.0       6.548   27435.0
# 37  402 2018-02-10      IBNSINA  277.5  ...  280.3  827.0      33.399  120034.0
# 79  360 2018-02-12      IBNSINA  240.0  ...  242.0  477.0      10.392   43333.0
# 16  423 2018-03-09      IBNSINA  290.2  ...  292.6  391.0      20.225   69398.0
#
# [5 rows x 12 columns]

# %%
df = df.set_index('DATE')
df.head(3)
# Out:
#               # TRADING CODE   LTP*   HIGH  ...    YCP  TRADE  VALUE (mn)    VOLUME
# DATE                                        ...
# 2018-01-10  403      IBNSINA  280.1  285.0  ...  279.7  698.0      31.318  110873.0
# 2018-01-11  380      IBNSINA  238.3  241.4  ...  240.4  296.0       6.548   27435.0
# 2018-02-10  402      IBNSINA  277.5  282.8  ...  280.3  827.0      33.399  120034.0
#
# [3 rows x 11 columns]

# %%
df['daily_ret'] = df['CLOSEP*'].pct_change()
df['daily_ret'] = df['daily_ret'].fillna(0.0)

# %%
df['volatility']= df['daily_ret'].rolling(window=21).std()
df['volatility'] = df['volatility'].fillna(0.0)

# %%
df['volatility'] = df['volatility']*100

# %%
import matplotlib.pyplot as plt

# %%
df=df.reset_index()['volatility']

# %%
plt.plot(df)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
df.shape
# Out:
# (439, 1)

# %%
##splitting dataset into train and test split where train=70 percent and test=30 percent
training_size=int(len(df)*0.70)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [],[]
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (206, 100)
# (206,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import Bidirectional

# %%
model=Sequential()
model.add(Bidirectional(LSTM(50,return_sequences=True,input_shape=(100,1))))
model.add(Bidirectional(LSTM(50,return_sequences=True)))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 14s 543ms/step - loss: 0.0562 - val_loss: 0.0264
# Epoch 2/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0082 - val_loss: 0.0399
# Epoch 3/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0059 - val_loss: 0.0143
# Epoch 4/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0061 - val_loss: 0.0271
# Epoch 5/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0055 - val_loss: 0.0195
# Epoch 6/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0045 - val_loss: 0.0148
# Epoch 7/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0042 - val_loss: 0.0181
# Epoch 8/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0041 - val_loss: 0.0124
# Epoch 9/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0037 - val_loss: 0.0131
# Epoch 10/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0031 - val_loss: 0.0123
# Epoch 11/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0031 - val_loss: 0.0103
# Epoch 12/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0030 - val_loss: 0.0104
# Epoch 13/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0025 - val_loss: 0.0103
# Epoch 14/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0025 - val_loss: 0.0131
# Epoch 15/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0028 - val_loss: 0.0128
# Epoch 16/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0025 - val_loss: 0.0099
# Epoch 17/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0026 - val_loss: 0.0060
# Epoch 18/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0025 - val_loss: 0.0130
# Epoch 19/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0024 - val_loss: 0.0093
# Epoch 20/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0021 - val_loss: 0.0085
# Epoch 21/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0019 - val_loss: 0.0095
# Epoch 22/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0019 - val_loss: 0.0062
# Epoch 23/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0025 - val_loss: 0.0064
# Epoch 24/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0025 - val_loss: 0.0067
# Epoch 25/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0021 - val_loss: 0.0087
# Epoch 26/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0022 - val_loss: 0.0108
# Epoch 27/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0026 - val_loss: 0.0080
# Epoch 28/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0021 - val_loss: 0.0063
# Epoch 29/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0020 - val_loss: 0.0053
# Epoch 30/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 31/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0020 - val_loss: 0.0055
# Epoch 32/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0020 - val_loss: 0.0057
# Epoch 33/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0017 - val_loss: 0.0080
# Epoch 34/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0018 - val_loss: 0.0066
# Epoch 35/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0019 - val_loss: 0.0069
# Epoch 36/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0019 - val_loss: 0.0053
# Epoch 37/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0018 - val_loss: 0.0046
# Epoch 38/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0015 - val_loss: 0.0062
# Epoch 39/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0016 - val_loss: 0.0053
# Epoch 40/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0015 - val_loss: 0.0058
# Epoch 41/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0016 - val_loss: 0.0047
# Epoch 42/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0015 - val_loss: 0.0055
# Epoch 43/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0021 - val_loss: 0.0057
# Epoch 44/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0015 - val_loss: 0.0061
# Epoch 45/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0012 - val_loss: 0.0055
# Epoch 46/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0014 - val_loss: 0.0051
# Epoch 47/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0015 - val_loss: 0.0053
# Epoch 48/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 49/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0016 - val_loss: 0.0044
# Epoch 50/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 51/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0014 - val_loss: 0.0060
# Epoch 52/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0016 - val_loss: 0.0057
# Epoch 53/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0015 - val_loss: 0.0057
# Epoch 54/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0014 - val_loss: 0.0075
# Epoch 55/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0016 - val_loss: 0.0063
# Epoch 56/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0015 - val_loss: 0.0047
# Epoch 57/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0018 - val_loss: 0.0052
# Epoch 58/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0015 - val_loss: 0.0052
# Epoch 59/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0012 - val_loss: 0.0068
# Epoch 60/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0013 - val_loss: 0.0048
# Epoch 61/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 62/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0013 - val_loss: 0.0047
# Epoch 63/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0012 - val_loss: 0.0062
# Epoch 64/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0013 - val_loss: 0.0053
# Epoch 65/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0011 - val_loss: 0.0074
# Epoch 66/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0015 - val_loss: 0.0054
# Epoch 67/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0011 - val_loss: 0.0051
# Epoch 68/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0010 - val_loss: 0.0068
# Epoch 69/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0013 - val_loss: 0.0060
# Epoch 70/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0010 - val_loss: 0.0052
# Epoch 71/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0011 - val_loss: 0.0060
# Epoch 72/100
# 7/7 [==============================] - 2s 215ms/step - loss: 0.0012 - val_loss: 0.0050
# Epoch 73/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0012 - val_loss: 0.0066
# Epoch 74/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0013 - val_loss: 0.0063
# Epoch 75/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0012 - val_loss: 0.0051
# Epoch 76/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0011 - val_loss: 0.0055
# Epoch 77/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0010 - val_loss: 0.0059
# Epoch 78/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0012 - val_loss: 0.0056
# Epoch 79/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0011 - val_loss: 0.0053
# Epoch 80/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 81/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0012 - val_loss: 0.0066
# Epoch 82/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0011 - val_loss: 0.0066
# Epoch 83/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0011 - val_loss: 0.0096
# Epoch 84/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0013 - val_loss: 0.0090
# Epoch 85/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0011 - val_loss: 0.0083
# Epoch 86/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0011 - val_loss: 0.0074
# Epoch 87/100
# 7/7 [==============================] - 2s 220ms/step - loss: 8.5819e-04 - val_loss: 0.0063
# Epoch 88/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0011 - val_loss: 0.0063
# Epoch 89/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0010 - val_loss: 0.0085
# Epoch 90/100
# 7/7 [==============================] - 1s 214ms/step - loss: 0.0012 - val_loss: 0.0076
# Epoch 91/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0011 - val_loss: 0.0058
# Epoch 92/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0011 - val_loss: 0.0057
# Epoch 93/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0013 - val_loss: 0.0057
# Epoch 94/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0014 - val_loss: 0.0152
# Epoch 95/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0018 - val_loss: 0.0116
# Epoch 96/100
# 7/7 [==============================] - 1s 214ms/step - loss: 0.0016 - val_loss: 0.0064
# Epoch 97/100
# 7/7 [==============================] - 2s 220ms/step - loss: 9.9567e-04 - val_loss: 0.0058
# Epoch 98/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0013 - val_loss: 0.0072
# Epoch 99/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0014 - val_loss: 0.0110
# Epoch 100/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0015 - val_loss: 0.0050

# %%
filepath1 = "/content/drive/MyDrive/stock_price_BILSTM/modelsIBNSINA/model.h5"

# %%
filepath2 = "/content/drive/MyDrive/stock price CNN/modelsIBNSINA/model1.h5"

# %%
filepath3 = "/content/drive/MyDrive/stock_price_BILSTM/modelsIBNSINA/model.h5"

# %%
X = np.reshape(ytest,(1, ytest.size))
Y_test =scaler.inverse_transform(X)

# %%
from keras.models import load_model

# %%
model1 = load_model(filepath1)

# %%
model2 = load_model(filepath2)

# %%
model3 = load_model(filepath3)

# %%
predicted1 = model1.predict(X_test)

# %%
predicted2 = model2.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc68122fb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predicted3 = model3.predict(X_test)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc681344e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
predicted1 = scaler.inverse_transform(predicted1)
predicted2 = scaler.inverse_transform(predicted2)
predicted3 = scaler.inverse_transform(predicted3)

# %%
import tensorflow as tf
from sklearn.metrics import r2_score

# %%
Y_test = Y_test.transpose()

# %%
Y_test
# Out:
# array([[3.40031531],
#        [3.33576764],
#        [2.16976503],
#        [0.84743907],
#        [0.83024663],
#        [0.83047049],
#        [0.83251486],
#        [0.83251486],
#        [0.92133951],
#        [0.92475339],
#        [1.01814602],
#        [1.0480618 ],
#        [1.05894413],
#        [1.64421273],
#        [2.81218613],
#        [3.18640458],
#        [3.18495377],
#        [3.40556798],
#        [4.62212599],
#        [4.8637966 ],
#        [4.87696143],
#        [4.87595992],
#        [5.39006825],
#        [5.68439031],
#        [5.74525138],
#        [6.19616053],
#        [6.29838604],
#        [6.42966536],
#        [6.55622475],
#        [7.47836252],
#        [7.63840352]])

# %%
predicted1
# Out:
# array([[3.5546155 ],
#        [3.4196045 ],
#        [3.3132632 ],
#        [2.9618974 ],
#        [2.3654923 ],
#        [1.8871678 ],
#        [1.5237648 ],
#        [1.2592221 ],
#        [1.0741293 ],
#        [0.9723731 ],
#        [0.9143751 ],
#        [0.910627  ],
#        [0.9268    ],
#        [0.95377153],
#        [1.1312149 ],
#        [1.5870643 ],
#        [2.0764046 ],
#        [2.47754   ],
#        [2.8442924 ],
#        [3.4369364 ],
#        [3.9643683 ],
#        [4.3620963 ],
#        [4.6391273 ],
#        [4.945202  ],
#        [5.2219586 ],
#        [5.414735  ],
#        [5.635089  ],
#        [5.7941394 ],
#        [5.909909  ],
#        [5.9925113 ],
#        [6.243567  ]], dtype=float32)

# %%
### Plotting 

plt.plot(Y_test,color ='green', label ='original')
plt.plot(predicted1,color ='blue', label ='CNN')
plt.plot(predicted2,color ='yellow', label ='LSTM')
plt.plot(predicted3,color ='red', label ='BiLSTM')


plt.xlabel('number of days')
plt.ylabel('volatility magnitude')
plt.title('ABBANk Risk Factor Prediction')
plt.legend(loc='best')
plt.show(block=False)

# %%
##Transformback to original form
train_predict = np.reshape(train_predict,(1, train_predict.size))
train_predict=scaler.inverse_transform(train_predict)
test_predict = np.reshape(test_predict,(1, test_predict.size))
test_predict=scaler.inverse_transform(test_predict)
X = np.reshape(ytest,(1, ytest.size))
Y_test =scaler.inverse_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-ccb03206dec6> in <module>()
#       1
#       2 ##Transformback to original form
# ----> 3 train_predict = np.reshape(train_predict,(1, train_predict.size))
#       4 train_predict=scaler.inverse_transform(train_predict)
#       5 test_predict = np.reshape(test_predict,(1, test_predict.size))
#
# NameError: name 'train_predict' is not defined

# %%
Y_test
# Out:
# array([[3.40031531, 3.33576764, 2.16976503, 0.84743907, 0.83024663,
#         0.83047049, 0.83251486, 0.83251486, 0.92133951, 0.92475339,
#         1.01814602, 1.0480618 , 1.05894413, 1.64421273, 2.81218613,
#         3.18640458, 3.18495377, 3.40556798, 4.62212599, 4.8637966 ,
#         4.87696143, 4.87595992, 5.39006825, 5.68439031, 5.74525138,
#         6.19616053, 6.29838604, 6.42966536, 6.55622475, 7.47836252,
#         7.63840352]])

# %%
test_predict
# Out:
# array([[ 0.07329169,  0.07044969,  0.06745621,  0.064027  ,  0.05891807,
#          0.05218294,  0.0443318 ,  0.03581287,  0.02712983,  0.01854996,
#          0.01029374,  0.00579858, -0.00136188, -0.00749922, -0.01274384,
#         -0.01651296, -0.0160889 , -0.01306935, -0.01159565, -0.00849156,
#         -0.00436385,  0.00089073,  0.00714683,  0.01388077,  0.02096713,
#          0.02813568,  0.03524068,  0.04259209,  0.04944445,  0.05646357,
#          0.06437383]], dtype=float32)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
#Y_test = Y_test.transpose()
RMSE = math.sqrt(mean_squared_error(Y_test,test_predict))
RMSE
# Out:
# 4.160205144977553

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(Y_test,test_predict)
print('MAE: %f' % mae)
# Out:
# MAE: 0.585392

# %%
train_predict.shape
# Out:
# (1, 206)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
test_predict = test_predict.transpose()

# %%
train_predict = train_predict.transpose()

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df),color ='blue', label ='original')
plt.plot(trainPredictPlot, color ='orange', label ='predicted')
plt.plot(testPredictPlot , color ='red', label ='tested')
#plt.show()
plt.xlabel('number of days')
plt.ylabel('volatility magnitude')
plt.title('ABBANk Risk Factor Prediction')
plt.legend(loc='best')
plt.show(block=False)

# %%
x_input=test_data[32:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<10):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

#print(lst_output)
# Out:
# [0.5823239]
# 101
# 1 day input [0.46939476 0.46508239 0.33064757 0.31554556 0.31142385 0.31143423
#  0.31143423 0.31272627 0.31236791 0.31274351 0.31244482 0.31275278
#  0.31520767 0.314971   0.37868554 0.37870705 0.46062637 0.41516084
#  0.39319655 0.39156389 0.39182234 0.39223981 0.37026831 0.37065393
#  0.37035112 0.37450905 0.37683625 0.37710066 0.37629008 0.44014014
#  0.47956168 0.51625221 0.51703151 0.51669583 0.53956476 0.49445231
#  0.4958781  0.41719452 0.40917669 0.41538423 0.4168736  0.46112966
#  0.55572431 0.56214907 0.56230355 0.59237323 0.59078332 0.63592415
#  0.64031881 0.64471553 0.6044776  0.57544794 0.54010989 0.53696481
#  0.5351887  0.5168587  0.51666936 0.51436681 0.51332907 0.50908814
#  0.50235861 0.50158278 0.45756382 0.37334524 0.39898636 0.4123765
#  0.3864597  0.3864597  0.33799657 0.33068152 0.32166857 0.31502429
#  0.31501535 0.31496654 0.31487897 0.31532685 0.31532685 0.31619613
#  0.31704009 0.31691474 0.31691474 0.32145788 0.35203741 0.41169048
#  0.39144382 0.35172436 0.3559866  0.32456115 0.37658341 0.35534253
#  0.3553266  0.37181956 0.42987637 0.43685938 0.45367113 0.49025387
#  0.49025387 0.50469626 0.51671423 0.58232391]
# 1 day output [[0.5998689]]
# 2 day input [0.46508239 0.33064757 0.31554556 0.31142385 0.31143423 0.31143423
#  0.31272627 0.31236791 0.31274351 0.31244482 0.31275278 0.31520767
#  0.314971   0.37868554 0.37870705 0.46062637 0.41516084 0.39319655
#  0.39156389 0.39182234 0.39223981 0.37026831 0.37065393 0.37035112
#  0.37450905 0.37683625 0.37710066 0.37629008 0.44014014 0.47956168
#  0.51625221 0.51703151 0.51669583 0.53956476 0.49445231 0.4958781
#  0.41719452 0.40917669 0.41538423 0.4168736  0.46112966 0.55572431
#  0.56214907 0.56230355 0.59237323 0.59078332 0.63592415 0.64031881
#  0.64471553 0.6044776  0.57544794 0.54010989 0.53696481 0.5351887
#  0.5168587  0.51666936 0.51436681 0.51332907 0.50908814 0.50235861
#  0.50158278 0.45756382 0.37334524 0.39898636 0.4123765  0.3864597
#  0.3864597  0.33799657 0.33068152 0.32166857 0.31502429 0.31501535
#  0.31496654 0.31487897 0.31532685 0.31532685 0.31619613 0.31704009
#  0.31691474 0.31691474 0.32145788 0.35203741 0.41169048 0.39144382
#  0.35172436 0.3559866  0.32456115 0.37658341 0.35534253 0.3553266
#  0.37181956 0.42987637 0.43685938 0.45367113 0.49025387 0.49025387
#  0.50469626 0.51671423 0.58232391 0.59986889]
# 2 day output [[0.6169131]]
# 3 day input [0.33064757 0.31554556 0.31142385 0.31143423 0.31143423 0.31272627
#  0.31236791 0.31274351 0.31244482 0.31275278 0.31520767 0.314971
#  0.37868554 0.37870705 0.46062637 0.41516084 0.39319655 0.39156389
#  0.39182234 0.39223981 0.37026831 0.37065393 0.37035112 0.37450905
#  0.37683625 0.37710066 0.37629008 0.44014014 0.47956168 0.51625221
#  0.51703151 0.51669583 0.53956476 0.49445231 0.4958781  0.41719452
#  0.40917669 0.41538423 0.4168736  0.46112966 0.55572431 0.56214907
#  0.56230355 0.59237323 0.59078332 0.63592415 0.64031881 0.64471553
#  0.6044776  0.57544794 0.54010989 0.53696481 0.5351887  0.5168587
#  0.51666936 0.51436681 0.51332907 0.50908814 0.50235861 0.50158278
#  0.45756382 0.37334524 0.39898636 0.4123765  0.3864597  0.3864597
#  0.33799657 0.33068152 0.32166857 0.31502429 0.31501535 0.31496654
#  0.31487897 0.31532685 0.31532685 0.31619613 0.31704009 0.31691474
#  0.31691474 0.32145788 0.35203741 0.41169048 0.39144382 0.35172436
#  0.3559866  0.32456115 0.37658341 0.35534253 0.3553266  0.37181956
#  0.42987637 0.43685938 0.45367113 0.49025387 0.49025387 0.50469626
#  0.51671423 0.58232391 0.59986889 0.61691308]
# 3 day output [[0.6318126]]
# 4 day input [0.31554556 0.31142385 0.31143423 0.31143423 0.31272627 0.31236791
#  0.31274351 0.31244482 0.31275278 0.31520767 0.314971   0.37868554
#  0.37870705 0.46062637 0.41516084 0.39319655 0.39156389 0.39182234
#  0.39223981 0.37026831 0.37065393 0.37035112 0.37450905 0.37683625
#  0.37710066 0.37629008 0.44014014 0.47956168 0.51625221 0.51703151
#  0.51669583 0.53956476 0.49445231 0.4958781  0.41719452 0.40917669
#  0.41538423 0.4168736  0.46112966 0.55572431 0.56214907 0.56230355
#  0.59237323 0.59078332 0.63592415 0.64031881 0.64471553 0.6044776
#  0.57544794 0.54010989 0.53696481 0.5351887  0.5168587  0.51666936
#  0.51436681 0.51332907 0.50908814 0.50235861 0.50158278 0.45756382
#  0.37334524 0.39898636 0.4123765  0.3864597  0.3864597  0.33799657
#  0.33068152 0.32166857 0.31502429 0.31501535 0.31496654 0.31487897
#  0.31532685 0.31532685 0.31619613 0.31704009 0.31691474 0.31691474
#  0.32145788 0.35203741 0.41169048 0.39144382 0.35172436 0.3559866
#  0.32456115 0.37658341 0.35534253 0.3553266  0.37181956 0.42987637
#  0.43685938 0.45367113 0.49025387 0.49025387 0.50469626 0.51671423
#  0.58232391 0.59986889 0.61691308 0.63181257]
# 4 day output [[0.64551693]]
# 5 day input [0.31142385 0.31143423 0.31143423 0.31272627 0.31236791 0.31274351
#  0.31244482 0.31275278 0.31520767 0.314971   0.37868554 0.37870705
#  0.46062637 0.41516084 0.39319655 0.39156389 0.39182234 0.39223981
#  0.37026831 0.37065393 0.37035112 0.37450905 0.37683625 0.37710066
#  0.37629008 0.44014014 0.47956168 0.51625221 0.51703151 0.51669583
#  0.53956476 0.49445231 0.4958781  0.41719452 0.40917669 0.41538423
#  0.4168736  0.46112966 0.55572431 0.56214907 0.56230355 0.59237323
#  0.59078332 0.63592415 0.64031881 0.64471553 0.6044776  0.57544794
#  0.54010989 0.53696481 0.5351887  0.5168587  0.51666936 0.51436681
#  0.51332907 0.50908814 0.50235861 0.50158278 0.45756382 0.37334524
#  0.39898636 0.4123765  0.3864597  0.3864597  0.33799657 0.33068152
#  0.32166857 0.31502429 0.31501535 0.31496654 0.31487897 0.31532685
#  0.31532685 0.31619613 0.31704009 0.31691474 0.31691474 0.32145788
#  0.35203741 0.41169048 0.39144382 0.35172436 0.3559866  0.32456115
#  0.37658341 0.35534253 0.3553266  0.37181956 0.42987637 0.43685938
#  0.45367113 0.49025387 0.49025387 0.50469626 0.51671423 0.58232391
#  0.59986889 0.61691308 0.63181257 0.64551693]
# 5 day output [[0.65638673]]
# 6 day input [0.31143423 0.31143423 0.31272627 0.31236791 0.31274351 0.31244482
#  0.31275278 0.31520767 0.314971   0.37868554 0.37870705 0.46062637
#  0.41516084 0.39319655 0.39156389 0.39182234 0.39223981 0.37026831
#  0.37065393 0.37035112 0.37450905 0.37683625 0.37710066 0.37629008
#  0.44014014 0.47956168 0.51625221 0.51703151 0.51669583 0.53956476
#  0.49445231 0.4958781  0.41719452 0.40917669 0.41538423 0.4168736
#  0.46112966 0.55572431 0.56214907 0.56230355 0.59237323 0.59078332
#  0.63592415 0.64031881 0.64471553 0.6044776  0.57544794 0.54010989
#  0.53696481 0.5351887  0.5168587  0.51666936 0.51436681 0.51332907
#  0.50908814 0.50235861 0.50158278 0.45756382 0.37334524 0.39898636
#  0.4123765  0.3864597  0.3864597  0.33799657 0.33068152 0.32166857
#  0.31502429 0.31501535 0.31496654 0.31487897 0.31532685 0.31532685
#  0.31619613 0.31704009 0.31691474 0.31691474 0.32145788 0.35203741
#  0.41169048 0.39144382 0.35172436 0.3559866  0.32456115 0.37658341
#  0.35534253 0.3553266  0.37181956 0.42987637 0.43685938 0.45367113
#  0.49025387 0.49025387 0.50469626 0.51671423 0.58232391 0.59986889
#  0.61691308 0.63181257 0.64551693 0.65638673]
# 6 day output [[0.66430825]]
# 7 day input [0.31143423 0.31272627 0.31236791 0.31274351 0.31244482 0.31275278
#  0.31520767 0.314971   0.37868554 0.37870705 0.46062637 0.41516084
#  0.39319655 0.39156389 0.39182234 0.39223981 0.37026831 0.37065393
#  0.37035112 0.37450905 0.37683625 0.37710066 0.37629008 0.44014014
#  0.47956168 0.51625221 0.51703151 0.51669583 0.53956476 0.49445231
#  0.4958781  0.41719452 0.40917669 0.41538423 0.4168736  0.46112966
#  0.55572431 0.56214907 0.56230355 0.59237323 0.59078332 0.63592415
#  0.64031881 0.64471553 0.6044776  0.57544794 0.54010989 0.53696481
#  0.5351887  0.5168587  0.51666936 0.51436681 0.51332907 0.50908814
#  0.50235861 0.50158278 0.45756382 0.37334524 0.39898636 0.4123765
#  0.3864597  0.3864597  0.33799657 0.33068152 0.32166857 0.31502429
#  0.31501535 0.31496654 0.31487897 0.31532685 0.31532685 0.31619613
#  0.31704009 0.31691474 0.31691474 0.32145788 0.35203741 0.41169048
#  0.39144382 0.35172436 0.3559866  0.32456115 0.37658341 0.35534253
#  0.3553266  0.37181956 0.42987637 0.43685938 0.45367113 0.49025387
#  0.49025387 0.50469626 0.51671423 0.58232391 0.59986889 0.61691308
#  0.63181257 0.64551693 0.65638673 0.66430825]
# 7 day output [[0.6694674]]
# 8 day input [0.31272627 0.31236791 0.31274351 0.31244482 0.31275278 0.31520767
#  0.314971   0.37868554 0.37870705 0.46062637 0.41516084 0.39319655
#  0.39156389 0.39182234 0.39223981 0.37026831 0.37065393 0.37035112
#  0.37450905 0.37683625 0.37710066 0.37629008 0.44014014 0.47956168
#  0.51625221 0.51703151 0.51669583 0.53956476 0.49445231 0.4958781
#  0.41719452 0.40917669 0.41538423 0.4168736  0.46112966 0.55572431
#  0.56214907 0.56230355 0.59237323 0.59078332 0.63592415 0.64031881
#  0.64471553 0.6044776  0.57544794 0.54010989 0.53696481 0.5351887
#  0.5168587  0.51666936 0.51436681 0.51332907 0.50908814 0.50235861
#  0.50158278 0.45756382 0.37334524 0.39898636 0.4123765  0.3864597
#  0.3864597  0.33799657 0.33068152 0.32166857 0.31502429 0.31501535
#  0.31496654 0.31487897 0.31532685 0.31532685 0.31619613 0.31704009
#  0.31691474 0.31691474 0.32145788 0.35203741 0.41169048 0.39144382
#  0.35172436 0.3559866  0.32456115 0.37658341 0.35534253 0.3553266
#  0.37181956 0.42987637 0.43685938 0.45367113 0.49025387 0.49025387
#  0.50469626 0.51671423 0.58232391 0.59986889 0.61691308 0.63181257
#  0.64551693 0.65638673 0.66430825 0.66946739]
# 8 day output [[0.67223155]]
# 9 day input [0.31236791 0.31274351 0.31244482 0.31275278 0.31520767 0.314971
#  0.37868554 0.37870705 0.46062637 0.41516084 0.39319655 0.39156389
#  0.39182234 0.39223981 0.37026831 0.37065393 0.37035112 0.37450905
#  0.37683625 0.37710066 0.37629008 0.44014014 0.47956168 0.51625221
#  0.51703151 0.51669583 0.53956476 0.49445231 0.4958781  0.41719452
#  0.40917669 0.41538423 0.4168736  0.46112966 0.55572431 0.56214907
#  0.56230355 0.59237323 0.59078332 0.63592415 0.64031881 0.64471553
#  0.6044776  0.57544794 0.54010989 0.53696481 0.5351887  0.5168587
#  0.51666936 0.51436681 0.51332907 0.50908814 0.50235861 0.50158278
#  0.45756382 0.37334524 0.39898636 0.4123765  0.3864597  0.3864597
#  0.33799657 0.33068152 0.32166857 0.31502429 0.31501535 0.31496654
#  0.31487897 0.31532685 0.31532685 0.31619613 0.31704009 0.31691474
#  0.31691474 0.32145788 0.35203741 0.41169048 0.39144382 0.35172436
#  0.3559866  0.32456115 0.37658341 0.35534253 0.3553266  0.37181956
#  0.42987637 0.43685938 0.45367113 0.49025387 0.49025387 0.50469626
#  0.51671423 0.58232391 0.59986889 0.61691308 0.63181257 0.64551693
#  0.65638673 0.66430825 0.66946739 0.67223155]
# 9 day output [[0.67300886]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,111)

# %%
plt.plot(day_new,scaler.inverse_transform(df[339:]),color ='blue', label ='origial')
plt.plot(day_pred,scaler.inverse_transform(lst_output),color='red', label='future')
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 10 Days Forecasting')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=df.tolist()
df3.extend(lst_output)
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 30 Days Forecasting')
plt.plot(df3[409:],color='red', label='future')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)

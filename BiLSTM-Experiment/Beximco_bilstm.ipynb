# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("/content/BEXIMCO.csv",parse_dates=['DATE'])
df.head()
# Out:
#      #       DATE TRADING CODE  LTP*  ...   YCP   TRADE  VALUE (mn)     VOLUME
# 0  439 2018-05-08      BEXIMCO  24.9  ...  25.4  1816.0      90.461  3600335.0
# 1  438 2018-06-08      BEXIMCO  25.0  ...  25.0   917.0      45.987  1842571.0
# 2  437 2018-07-08      BEXIMCO  25.0  ...  25.0   759.0      30.122  1205502.0
# 3  436 2018-08-08      BEXIMCO  24.9  ...  25.0   884.0      49.327  1970165.0
# 4  435 2018-09-08      BEXIMCO  24.8  ...  24.9   897.0      43.200  1736595.0
#
# [5 rows x 12 columns]

# %%
# Sort DataFrame by date
df = df.sort_values('DATE')

# Double check the result
df.head()
# Out:
#       #       DATE TRADING CODE  LTP*  ...   YCP   TRADE  VALUE (mn)     VOLUME
# 36  403 2018-01-10      BEXIMCO  24.1  ...  23.9   645.0      22.999   951654.0
# 59  380 2018-01-11      BEXIMCO  24.3  ...  24.6  1453.0      91.217  3757631.0
# 37  402 2018-02-10      BEXIMCO  23.9  ...  24.0   616.0      21.479   893881.0
# 79  360 2018-02-12      BEXIMCO  21.8  ...  21.9   962.0      38.681  1777123.0
# 16  423 2018-03-09      BEXIMCO  26.0  ...  26.3  1647.0      88.152  3383219.0
#
# [5 rows x 12 columns]

# %%
df = df.set_index('DATE')
df.head(3)
# Out:
#               # TRADING CODE  LTP*  HIGH  ...   YCP   TRADE  VALUE (mn)     VOLUME
# DATE                                      ...
# 2018-01-10  403      BEXIMCO  24.1  24.5  ...  23.9   645.0      22.999   951654.0
# 2018-01-11  380      BEXIMCO  24.3  24.8  ...  24.6  1453.0      91.217  3757631.0
# 2018-02-10  402      BEXIMCO  23.9  24.3  ...  24.0   616.0      21.479   893881.0
#
# [3 rows x 11 columns]

# %%
df['daily_ret'] = df['CLOSEP*'].pct_change()
df['daily_ret'] = df['daily_ret'].fillna(0.0)

# %%
df['volatility']= df['daily_ret'].rolling(window=21).std()
df['volatility'] = df['volatility'].fillna(0.0)

# %%
df['volatility'] = df['volatility']*100

# %%
import matplotlib.pyplot as plt

# %%
df=df.reset_index()['volatility']

# %%
plt.plot(df)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
##splitting dataset into train and test split where train=70 percent and test=30 percent
training_size=int(len(df)*0.70)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [],[]
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (206, 100)
# (206,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import Bidirectional

# %%
model=Sequential()
model.add(Bidirectional(LSTM(50,return_sequences=True,input_shape=(100,1))))
model.add(Bidirectional(LSTM(50,return_sequences=True)))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 19s 755ms/step - loss: 0.2900 - val_loss: 0.2251
# Epoch 2/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0375 - val_loss: 0.0443
# Epoch 3/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0365 - val_loss: 0.1367
# Epoch 4/100
# 7/7 [==============================] - 2s 285ms/step - loss: 0.0195 - val_loss: 0.0788
# Epoch 5/100
# 7/7 [==============================] - 2s 288ms/step - loss: 0.0160 - val_loss: 0.0693
# Epoch 6/100
# 7/7 [==============================] - 2s 291ms/step - loss: 0.0121 - val_loss: 0.0943
# Epoch 7/100
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0119 - val_loss: 0.0562
# Epoch 8/100
# 7/7 [==============================] - 2s 282ms/step - loss: 0.0094 - val_loss: 0.0678
# Epoch 9/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.0115 - val_loss: 0.0506
# Epoch 10/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0080 - val_loss: 0.0580
# Epoch 11/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0098 - val_loss: 0.0535
# Epoch 12/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0091 - val_loss: 0.0565
# Epoch 13/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0075 - val_loss: 0.0605
# Epoch 14/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0075 - val_loss: 0.0571
# Epoch 15/100
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0081 - val_loss: 0.0564
# Epoch 16/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0067 - val_loss: 0.0637
# Epoch 17/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0083 - val_loss: 0.0627
# Epoch 18/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0084 - val_loss: 0.0645
# Epoch 19/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0070 - val_loss: 0.0621
# Epoch 20/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0077 - val_loss: 0.0662
# Epoch 21/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0060 - val_loss: 0.0669
# Epoch 22/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0073 - val_loss: 0.0647
# Epoch 23/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0069 - val_loss: 0.0631
# Epoch 24/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0082 - val_loss: 0.0667
# Epoch 25/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0068 - val_loss: 0.0721
# Epoch 26/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0067 - val_loss: 0.0680
# Epoch 27/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0071 - val_loss: 0.0705
# Epoch 28/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0068 - val_loss: 0.0628
# Epoch 29/100
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0083 - val_loss: 0.0729
# Epoch 30/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0071 - val_loss: 0.0730
# Epoch 31/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0081 - val_loss: 0.0757
# Epoch 32/100
# 7/7 [==============================] - 2s 250ms/step - loss: 0.0071 - val_loss: 0.0725
# Epoch 33/100
# 7/7 [==============================] - 2s 266ms/step - loss: 0.0081 - val_loss: 0.0781
# Epoch 34/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0067 - val_loss: 0.0696
# Epoch 35/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0072 - val_loss: 0.0717
# Epoch 36/100
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0072 - val_loss: 0.0810
# Epoch 37/100
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0062 - val_loss: 0.0838
# Epoch 38/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0074 - val_loss: 0.0974
# Epoch 39/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0103 - val_loss: 0.0668
# Epoch 40/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0076 - val_loss: 0.0611
# Epoch 41/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0078 - val_loss: 0.0870
# Epoch 42/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0083 - val_loss: 0.0618
# Epoch 43/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0074 - val_loss: 0.0638
# Epoch 44/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0058 - val_loss: 0.0769
# Epoch 45/100
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0069 - val_loss: 0.0570
# Epoch 46/100
# 7/7 [==============================] - 2s 282ms/step - loss: 0.0064 - val_loss: 0.0561
# Epoch 47/100
# 7/7 [==============================] - 2s 278ms/step - loss: 0.0075 - val_loss: 0.0742
# Epoch 48/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0059 - val_loss: 0.0578
# Epoch 49/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0063 - val_loss: 0.0682
# Epoch 50/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0078 - val_loss: 0.0589
# Epoch 51/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0059 - val_loss: 0.0671
# Epoch 52/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0074 - val_loss: 0.0640
# Epoch 53/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0066 - val_loss: 0.0507
# Epoch 54/100
# 7/7 [==============================] - 2s 283ms/step - loss: 0.0072 - val_loss: 0.0710
# Epoch 55/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0052 - val_loss: 0.0575
# Epoch 56/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0071 - val_loss: 0.0542
# Epoch 57/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0071 - val_loss: 0.0553
# Epoch 58/100
# 7/7 [==============================] - 2s 281ms/step - loss: 0.0068 - val_loss: 0.0677
# Epoch 59/100
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0060 - val_loss: 0.0550
# Epoch 60/100
# 7/7 [==============================] - 2s 286ms/step - loss: 0.0068 - val_loss: 0.0558
# Epoch 61/100
# 7/7 [==============================] - 2s 290ms/step - loss: 0.0057 - val_loss: 0.0467
# Epoch 62/100
# 7/7 [==============================] - 2s 282ms/step - loss: 0.0071 - val_loss: 0.0546
# Epoch 63/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0056 - val_loss: 0.0507
# Epoch 64/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0053 - val_loss: 0.0525
# Epoch 65/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.0061 - val_loss: 0.0491
# Epoch 66/100
# 7/7 [==============================] - 2s 292ms/step - loss: 0.0071 - val_loss: 0.0400
# Epoch 67/100
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0066 - val_loss: 0.0543
# Epoch 68/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0057 - val_loss: 0.0550
# Epoch 69/100
# 7/7 [==============================] - 2s 282ms/step - loss: 0.0068 - val_loss: 0.0655
# Epoch 70/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0088 - val_loss: 0.0524
# Epoch 71/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0066 - val_loss: 0.0349
# Epoch 72/100
# 7/7 [==============================] - 2s 285ms/step - loss: 0.0067 - val_loss: 0.0433
# Epoch 73/100
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0066 - val_loss: 0.0520
# Epoch 74/100
# 7/7 [==============================] - 2s 284ms/step - loss: 0.0071 - val_loss: 0.0454
# Epoch 75/100
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0054 - val_loss: 0.0372
# Epoch 76/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0071 - val_loss: 0.0409
# Epoch 77/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.0069 - val_loss: 0.0444
# Epoch 78/100
# 7/7 [==============================] - 2s 279ms/step - loss: 0.0055 - val_loss: 0.0380
# Epoch 79/100
# 7/7 [==============================] - 2s 285ms/step - loss: 0.0074 - val_loss: 0.0423
# Epoch 80/100
# 7/7 [==============================] - 2s 282ms/step - loss: 0.0046 - val_loss: 0.0402
# Epoch 81/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.0060 - val_loss: 0.0349
# Epoch 82/100
# 7/7 [==============================] - 2s 283ms/step - loss: 0.0059 - val_loss: 0.0315
# Epoch 83/100
# 7/7 [==============================] - 2s 287ms/step - loss: 0.0056 - val_loss: 0.0412
# Epoch 84/100
# 7/7 [==============================] - 2s 280ms/step - loss: 0.0061 - val_loss: 0.0436
# Epoch 85/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0066 - val_loss: 0.0372
# Epoch 86/100
# 7/7 [==============================] - 2s 283ms/step - loss: 0.0069 - val_loss: 0.0415
# Epoch 87/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0052 - val_loss: 0.0374
# Epoch 88/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.0046 - val_loss: 0.0301
# Epoch 89/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0044 - val_loss: 0.0371
# Epoch 90/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0069 - val_loss: 0.0349
# Epoch 91/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.0057 - val_loss: 0.0285
# Epoch 92/100
# 7/7 [==============================] - 2s 289ms/step - loss: 0.0052 - val_loss: 0.0264
# Epoch 93/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.0065 - val_loss: 0.0260
# Epoch 94/100
# 7/7 [==============================] - 2s 289ms/step - loss: 0.0070 - val_loss: 0.0310
# Epoch 95/100
# 7/7 [==============================] - 2s 282ms/step - loss: 0.0064 - val_loss: 0.0225
# Epoch 96/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0048 - val_loss: 0.0198
# Epoch 97/100
# 7/7 [==============================] - 2s 293ms/step - loss: 0.0064 - val_loss: 0.0251
# Epoch 98/100
# 7/7 [==============================] - 2s 283ms/step - loss: 0.0054 - val_loss: 0.0337
# Epoch 99/100
# 7/7 [==============================] - 2s 283ms/step - loss: 0.0049 - val_loss: 0.0264
# Epoch 100/100
# 7/7 [==============================] - 2s 287ms/step - loss: 0.0048 - val_loss: 0.0201

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath = "/content/drive/MyDrive/stock_price_BILSTM/modelsBEXIMCO/model.h5"
model.save(filepath)

# %%
from keras.models import load_model
f1 = '/content/drive/MyDrive/stock_price_BILSTM/modelsBEXIMCO/model.h5'
model = load_model(f1)

# %%
import tensorflow as tf
from sklearn.metrics import r2_score

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict = np.reshape(train_predict,(1, train_predict.size))
train_predict=scaler.inverse_transform(train_predict)
test_predict = np.reshape(test_predict,(1, test_predict.size))
test_predict=scaler.inverse_transform(test_predict)
X = np.reshape(ytest,(1, ytest.size))
Y_test =scaler.inverse_transform(X)

# %%
Y_test
# Out:
# array([[3.81370212, 3.81383118, 3.56191161, 2.04829596, 1.92499939,
#         1.89944295, 1.8697861 , 1.8697861 , 1.8697861 , 1.8697861 ,
#         1.93544257, 1.96788973, 2.02727223, 2.11785583, 2.43071404,
#         3.29314766, 3.29585613, 3.08364102, 3.14162285, 3.4149629 ,
#         3.43534413, 3.44735356, 3.72048026, 3.72874139, 3.91155786,
#         4.26397766, 4.32638629, 4.52910576, 4.54819412, 4.66008224,
#         4.8091881 ]])

# %%
test_predict
# Out:
# array([[6.0872684, 5.6478224, 5.3485646, 5.1258473, 4.6926575, 4.3923426,
#         4.2325134, 4.189854 , 4.2451153, 4.371397 , 4.5456953, 4.775275 ,
#         5.0171013, 5.261531 , 5.503494 , 5.78661  , 6.22785  , 6.5894446,
#         6.8127017, 6.969787 , 7.117558 , 7.1967454, 7.2162104, 7.2514343,
#         7.2460055, 7.2561107, 7.3306537, 7.402458 , 7.512839 , 7.6202803,
#         7.7493734]], dtype=float32)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
#Y_test = Y_test.transpose()
RMSE = math.sqrt(mean_squared_error(Y_test,test_predict))
RMSE
# Out:
# 2.565697615833651

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(Y_test,test_predict)
print('MAE: %f' % mae)
# Out:
# MAE: 2.538346

# %%
train_predict.shape
# Out:
# (1, 206)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
test_predict = test_predict.transpose()

# %%
train_predict = train_predict.transpose()

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df),color ='blue', label ='original')
plt.plot(trainPredictPlot, color ='orange', label ='predicted')
plt.plot(testPredictPlot , color ='red', label ='tested')
#plt.show()
plt.xlabel('number of days')
plt.ylabel('volatility magnitude')
plt.title('ABBANk Risk Factor Prediction')
plt.legend(loc='best')
plt.show(block=False)

# %%
x_input=test_data[32:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<10):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

#print(lst_output)
# Out:
# [0.44273463]
# 101
# 1 day input [0.34835725 0.36742557 0.30540075 0.219133   0.20813281 0.20915418
#  0.20605889 0.20929064 0.20867645 0.21090052 0.21083144 0.23047119
#  0.24380066 0.26968789 0.31186371 0.3145075  0.36542342 0.37764991
#  0.36122544 0.35914764 0.35905038 0.36113632 0.35708704 0.35981801
#  0.35873323 0.35962851 0.36003886 0.37103588 0.38481764 0.4464845
#  0.45385783 0.47044836 0.46360867 0.46060927 0.46504199 0.44031109
#  0.43765383 0.3782734  0.35509243 0.38548246 0.3936953  0.42740302
#  0.44640881 0.44559282 0.44531299 0.4797756  0.4967968  0.49640402
#  0.49330048 0.50619862 0.45779409 0.44912863 0.43252814 0.4263956
#  0.42077436 0.39974981 0.39971708 0.39971708 0.39971708 0.39971708
#  0.36948172 0.36030863 0.31668819 0.30497701 0.30550268 0.3056356
#  0.24518158 0.21074107 0.2107482  0.1968274  0.11318663 0.10637339
#  0.10496117 0.10332237 0.10332237 0.10332237 0.10332237 0.10695047
#  0.10874347 0.11202488 0.11703043 0.13431864 0.18197579 0.18212546
#  0.17039868 0.17360269 0.18870717 0.18983342 0.19049704 0.20558973
#  0.20604623 0.21614847 0.23562281 0.23907145 0.25027351 0.25132831
#  0.25751113 0.26575055 0.2688418  0.44273463]
# 1 day output [[0.48794442]]
# 2 day input [0.36742557 0.30540075 0.219133   0.20813281 0.20915418 0.20605889
#  0.20929064 0.20867645 0.21090052 0.21083144 0.23047119 0.24380066
#  0.26968789 0.31186371 0.3145075  0.36542342 0.37764991 0.36122544
#  0.35914764 0.35905038 0.36113632 0.35708704 0.35981801 0.35873323
#  0.35962851 0.36003886 0.37103588 0.38481764 0.4464845  0.45385783
#  0.47044836 0.46360867 0.46060927 0.46504199 0.44031109 0.43765383
#  0.3782734  0.35509243 0.38548246 0.3936953  0.42740302 0.44640881
#  0.44559282 0.44531299 0.4797756  0.4967968  0.49640402 0.49330048
#  0.50619862 0.45779409 0.44912863 0.43252814 0.4263956  0.42077436
#  0.39974981 0.39971708 0.39971708 0.39971708 0.39971708 0.36948172
#  0.36030863 0.31668819 0.30497701 0.30550268 0.3056356  0.24518158
#  0.21074107 0.2107482  0.1968274  0.11318663 0.10637339 0.10496117
#  0.10332237 0.10332237 0.10332237 0.10332237 0.10695047 0.10874347
#  0.11202488 0.11703043 0.13431864 0.18197579 0.18212546 0.17039868
#  0.17360269 0.18870717 0.18983342 0.19049704 0.20558973 0.20604623
#  0.21614847 0.23562281 0.23907145 0.25027351 0.25132831 0.25751113
#  0.26575055 0.2688418  0.44273463 0.48794442]
# 2 day output [[0.5356142]]
# 3 day input [0.30540075 0.219133   0.20813281 0.20915418 0.20605889 0.20929064
#  0.20867645 0.21090052 0.21083144 0.23047119 0.24380066 0.26968789
#  0.31186371 0.3145075  0.36542342 0.37764991 0.36122544 0.35914764
#  0.35905038 0.36113632 0.35708704 0.35981801 0.35873323 0.35962851
#  0.36003886 0.37103588 0.38481764 0.4464845  0.45385783 0.47044836
#  0.46360867 0.46060927 0.46504199 0.44031109 0.43765383 0.3782734
#  0.35509243 0.38548246 0.3936953  0.42740302 0.44640881 0.44559282
#  0.44531299 0.4797756  0.4967968  0.49640402 0.49330048 0.50619862
#  0.45779409 0.44912863 0.43252814 0.4263956  0.42077436 0.39974981
#  0.39971708 0.39971708 0.39971708 0.39971708 0.36948172 0.36030863
#  0.31668819 0.30497701 0.30550268 0.3056356  0.24518158 0.21074107
#  0.2107482  0.1968274  0.11318663 0.10637339 0.10496117 0.10332237
#  0.10332237 0.10332237 0.10332237 0.10695047 0.10874347 0.11202488
#  0.11703043 0.13431864 0.18197579 0.18212546 0.17039868 0.17360269
#  0.18870717 0.18983342 0.19049704 0.20558973 0.20604623 0.21614847
#  0.23562281 0.23907145 0.25027351 0.25132831 0.25751113 0.26575055
#  0.2688418  0.44273463 0.48794442 0.53561419]
# 3 day output [[0.58355725]]
# 4 day input [0.219133   0.20813281 0.20915418 0.20605889 0.20929064 0.20867645
#  0.21090052 0.21083144 0.23047119 0.24380066 0.26968789 0.31186371
#  0.3145075  0.36542342 0.37764991 0.36122544 0.35914764 0.35905038
#  0.36113632 0.35708704 0.35981801 0.35873323 0.35962851 0.36003886
#  0.37103588 0.38481764 0.4464845  0.45385783 0.47044836 0.46360867
#  0.46060927 0.46504199 0.44031109 0.43765383 0.3782734  0.35509243
#  0.38548246 0.3936953  0.42740302 0.44640881 0.44559282 0.44531299
#  0.4797756  0.4967968  0.49640402 0.49330048 0.50619862 0.45779409
#  0.44912863 0.43252814 0.4263956  0.42077436 0.39974981 0.39971708
#  0.39971708 0.39971708 0.39971708 0.36948172 0.36030863 0.31668819
#  0.30497701 0.30550268 0.3056356  0.24518158 0.21074107 0.2107482
#  0.1968274  0.11318663 0.10637339 0.10496117 0.10332237 0.10332237
#  0.10332237 0.10332237 0.10695047 0.10874347 0.11202488 0.11703043
#  0.13431864 0.18197579 0.18212546 0.17039868 0.17360269 0.18870717
#  0.18983342 0.19049704 0.20558973 0.20604623 0.21614847 0.23562281
#  0.23907145 0.25027351 0.25132831 0.25751113 0.26575055 0.2688418
#  0.44273463 0.48794442 0.53561419 0.58355725]
# 4 day output [[0.6289971]]
# 5 day input [0.20813281 0.20915418 0.20605889 0.20929064 0.20867645 0.21090052
#  0.21083144 0.23047119 0.24380066 0.26968789 0.31186371 0.3145075
#  0.36542342 0.37764991 0.36122544 0.35914764 0.35905038 0.36113632
#  0.35708704 0.35981801 0.35873323 0.35962851 0.36003886 0.37103588
#  0.38481764 0.4464845  0.45385783 0.47044836 0.46360867 0.46060927
#  0.46504199 0.44031109 0.43765383 0.3782734  0.35509243 0.38548246
#  0.3936953  0.42740302 0.44640881 0.44559282 0.44531299 0.4797756
#  0.4967968  0.49640402 0.49330048 0.50619862 0.45779409 0.44912863
#  0.43252814 0.4263956  0.42077436 0.39974981 0.39971708 0.39971708
#  0.39971708 0.39971708 0.36948172 0.36030863 0.31668819 0.30497701
#  0.30550268 0.3056356  0.24518158 0.21074107 0.2107482  0.1968274
#  0.11318663 0.10637339 0.10496117 0.10332237 0.10332237 0.10332237
#  0.10332237 0.10695047 0.10874347 0.11202488 0.11703043 0.13431864
#  0.18197579 0.18212546 0.17039868 0.17360269 0.18870717 0.18983342
#  0.19049704 0.20558973 0.20604623 0.21614847 0.23562281 0.23907145
#  0.25027351 0.25132831 0.25751113 0.26575055 0.2688418  0.44273463
#  0.48794442 0.53561419 0.58355725 0.62899709]
# 5 day output [[0.6696908]]
# 6 day input [0.20915418 0.20605889 0.20929064 0.20867645 0.21090052 0.21083144
#  0.23047119 0.24380066 0.26968789 0.31186371 0.3145075  0.36542342
#  0.37764991 0.36122544 0.35914764 0.35905038 0.36113632 0.35708704
#  0.35981801 0.35873323 0.35962851 0.36003886 0.37103588 0.38481764
#  0.4464845  0.45385783 0.47044836 0.46360867 0.46060927 0.46504199
#  0.44031109 0.43765383 0.3782734  0.35509243 0.38548246 0.3936953
#  0.42740302 0.44640881 0.44559282 0.44531299 0.4797756  0.4967968
#  0.49640402 0.49330048 0.50619862 0.45779409 0.44912863 0.43252814
#  0.4263956  0.42077436 0.39974981 0.39971708 0.39971708 0.39971708
#  0.39971708 0.36948172 0.36030863 0.31668819 0.30497701 0.30550268
#  0.3056356  0.24518158 0.21074107 0.2107482  0.1968274  0.11318663
#  0.10637339 0.10496117 0.10332237 0.10332237 0.10332237 0.10332237
#  0.10695047 0.10874347 0.11202488 0.11703043 0.13431864 0.18197579
#  0.18212546 0.17039868 0.17360269 0.18870717 0.18983342 0.19049704
#  0.20558973 0.20604623 0.21614847 0.23562281 0.23907145 0.25027351
#  0.25132831 0.25751113 0.26575055 0.2688418  0.44273463 0.48794442
#  0.53561419 0.58355725 0.62899709 0.66969079]
# 6 day output [[0.70443034]]
# 7 day input [0.20605889 0.20929064 0.20867645 0.21090052 0.21083144 0.23047119
#  0.24380066 0.26968789 0.31186371 0.3145075  0.36542342 0.37764991
#  0.36122544 0.35914764 0.35905038 0.36113632 0.35708704 0.35981801
#  0.35873323 0.35962851 0.36003886 0.37103588 0.38481764 0.4464845
#  0.45385783 0.47044836 0.46360867 0.46060927 0.46504199 0.44031109
#  0.43765383 0.3782734  0.35509243 0.38548246 0.3936953  0.42740302
#  0.44640881 0.44559282 0.44531299 0.4797756  0.4967968  0.49640402
#  0.49330048 0.50619862 0.45779409 0.44912863 0.43252814 0.4263956
#  0.42077436 0.39974981 0.39971708 0.39971708 0.39971708 0.39971708
#  0.36948172 0.36030863 0.31668819 0.30497701 0.30550268 0.3056356
#  0.24518158 0.21074107 0.2107482  0.1968274  0.11318663 0.10637339
#  0.10496117 0.10332237 0.10332237 0.10332237 0.10332237 0.10695047
#  0.10874347 0.11202488 0.11703043 0.13431864 0.18197579 0.18212546
#  0.17039868 0.17360269 0.18870717 0.18983342 0.19049704 0.20558973
#  0.20604623 0.21614847 0.23562281 0.23907145 0.25027351 0.25132831
#  0.25751113 0.26575055 0.2688418  0.44273463 0.48794442 0.53561419
#  0.58355725 0.62899709 0.66969079 0.70443034]
# 7 day output [[0.7324151]]
# 8 day input [0.20929064 0.20867645 0.21090052 0.21083144 0.23047119 0.24380066
#  0.26968789 0.31186371 0.3145075  0.36542342 0.37764991 0.36122544
#  0.35914764 0.35905038 0.36113632 0.35708704 0.35981801 0.35873323
#  0.35962851 0.36003886 0.37103588 0.38481764 0.4464845  0.45385783
#  0.47044836 0.46360867 0.46060927 0.46504199 0.44031109 0.43765383
#  0.3782734  0.35509243 0.38548246 0.3936953  0.42740302 0.44640881
#  0.44559282 0.44531299 0.4797756  0.4967968  0.49640402 0.49330048
#  0.50619862 0.45779409 0.44912863 0.43252814 0.4263956  0.42077436
#  0.39974981 0.39971708 0.39971708 0.39971708 0.39971708 0.36948172
#  0.36030863 0.31668819 0.30497701 0.30550268 0.3056356  0.24518158
#  0.21074107 0.2107482  0.1968274  0.11318663 0.10637339 0.10496117
#  0.10332237 0.10332237 0.10332237 0.10332237 0.10695047 0.10874347
#  0.11202488 0.11703043 0.13431864 0.18197579 0.18212546 0.17039868
#  0.17360269 0.18870717 0.18983342 0.19049704 0.20558973 0.20604623
#  0.21614847 0.23562281 0.23907145 0.25027351 0.25132831 0.25751113
#  0.26575055 0.2688418  0.44273463 0.48794442 0.53561419 0.58355725
#  0.62899709 0.66969079 0.70443034 0.73241508]
# 8 day output [[0.7534177]]
# 9 day input [0.20867645 0.21090052 0.21083144 0.23047119 0.24380066 0.26968789
#  0.31186371 0.3145075  0.36542342 0.37764991 0.36122544 0.35914764
#  0.35905038 0.36113632 0.35708704 0.35981801 0.35873323 0.35962851
#  0.36003886 0.37103588 0.38481764 0.4464845  0.45385783 0.47044836
#  0.46360867 0.46060927 0.46504199 0.44031109 0.43765383 0.3782734
#  0.35509243 0.38548246 0.3936953  0.42740302 0.44640881 0.44559282
#  0.44531299 0.4797756  0.4967968  0.49640402 0.49330048 0.50619862
#  0.45779409 0.44912863 0.43252814 0.4263956  0.42077436 0.39974981
#  0.39971708 0.39971708 0.39971708 0.39971708 0.36948172 0.36030863
#  0.31668819 0.30497701 0.30550268 0.3056356  0.24518158 0.21074107
#  0.2107482  0.1968274  0.11318663 0.10637339 0.10496117 0.10332237
#  0.10332237 0.10332237 0.10332237 0.10695047 0.10874347 0.11202488
#  0.11703043 0.13431864 0.18197579 0.18212546 0.17039868 0.17360269
#  0.18870717 0.18983342 0.19049704 0.20558973 0.20604623 0.21614847
#  0.23562281 0.23907145 0.25027351 0.25132831 0.25751113 0.26575055
#  0.2688418  0.44273463 0.48794442 0.53561419 0.58355725 0.62899709
#  0.66969079 0.70443034 0.73241508 0.75341767]
# 9 day output [[0.7677984]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,111)

# %%
plt.plot(day_new,scaler.inverse_transform(df[339:]),color ='blue', label ='origial')
plt.plot(day_pred,scaler.inverse_transform(lst_output),color='red', label='future')
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 10 Days Forecasting')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=df.tolist()
df3.extend(lst_output)
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 30 Days Forecasting')
plt.plot(df3[409:],color='red', label='future')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)

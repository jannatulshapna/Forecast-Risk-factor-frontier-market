# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("/content/DESCO.csv",parse_dates=['DATE'])
df.head()
# Out:
#      #       DATE TRADING CODE  LTP*  ...   YCP  TRADE  VALUE (mn)    VOLUME
# 0  439 2018-05-08        DESCO  40.0  ...  40.8    280       7.465  181313.0
# 1  438 2018-06-08        DESCO  39.9  ...  40.2    131       3.175   79286.0
# 2  437 2018-07-08        DESCO  40.0  ...  40.0    182      11.427  284763.0
# 3  436 2018-08-08        DESCO  39.9  ...  40.0    161      11.144  277230.0
# 4  435 2018-09-08        DESCO  40.2  ...  40.0     99       2.922   73105.0
#
# [5 rows x 12 columns]

# %%
# Sort DataFrame by date
df = df.sort_values('DATE')

# Double check the result
df.head()
# Out:
#       #       DATE TRADING CODE  LTP*  ...   YCP  TRADE  VALUE (mn)    VOLUME
# 36  403 2018-01-10        DESCO  43.8  ...  43.8     75       1.989   45311.0
# 59  380 2018-01-11        DESCO  39.9  ...  41.0    340      14.165  352939.0
# 37  402 2018-02-10        DESCO  43.4  ...  43.9     28       1.045   23861.0
# 79  360 2018-02-12        DESCO  40.2  ...  39.9    138       4.990  124690.0
# 16  423 2018-03-09        DESCO  42.0  ...  41.2    253       4.630  109806.0
#
# [5 rows x 12 columns]

# %%
df = df.set_index('DATE')
df.head(3)
# Out:
#               # TRADING CODE  LTP*  HIGH  ...   YCP  TRADE  VALUE (mn)    VOLUME
# DATE                                      ...
# 2018-01-10  403        DESCO  43.8  44.5  ...  43.8     75       1.989   45311.0
# 2018-01-11  380        DESCO  39.9  41.0  ...  41.0    340      14.165  352939.0
# 2018-02-10  402        DESCO  43.4  44.0  ...  43.9     28       1.045   23861.0
#
# [3 rows x 11 columns]

# %%
df['daily_ret'] = df['CLOSEP*'].pct_change()
df['daily_ret'] = df['daily_ret'].fillna(0.0)

# %%
df['volatility']= df['daily_ret'].rolling(window=21).std()
df['volatility'] = df['volatility'].fillna(0.0)

# %%
df['volatility'] = df['volatility']*100

# %%
import matplotlib.pyplot as plt

# %%
df=df.reset_index()['volatility']

# %%
plt.plot(df)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
df.shape
# Out:
# (439, 1)

# %%
##splitting dataset into train and test split where train=70 percent and test=30 percent
training_size=int(len(df)*0.70)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [],[]
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (206, 100)
# (206,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import Bidirectional

# %%
model=Sequential()
model.add(Bidirectional(LSTM(50,return_sequences=True,input_shape=(100,1))))
model.add(Bidirectional(LSTM(50,return_sequences=True)))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 14s 592ms/step - loss: 0.2125 - val_loss: 0.1078
# Epoch 2/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0282 - val_loss: 0.0640
# Epoch 3/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0280 - val_loss: 0.0975
# Epoch 4/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0212 - val_loss: 0.0670
# Epoch 5/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0139 - val_loss: 0.0708
# Epoch 6/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0105 - val_loss: 0.0687
# Epoch 7/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0103 - val_loss: 0.0645
# Epoch 8/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0094 - val_loss: 0.0656
# Epoch 9/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0094 - val_loss: 0.0613
# Epoch 10/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0079 - val_loss: 0.0557
# Epoch 11/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0081 - val_loss: 0.0634
# Epoch 12/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0094 - val_loss: 0.0506
# Epoch 13/100
# 7/7 [==============================] - 1s 215ms/step - loss: 0.0083 - val_loss: 0.0492
# Epoch 14/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0073 - val_loss: 0.0468
# Epoch 15/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0068 - val_loss: 0.0410
# Epoch 16/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0072 - val_loss: 0.0407
# Epoch 17/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0065 - val_loss: 0.0351
# Epoch 18/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0063 - val_loss: 0.0335
# Epoch 19/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0066 - val_loss: 0.0291
# Epoch 20/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0058 - val_loss: 0.0257
# Epoch 21/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0069 - val_loss: 0.0248
# Epoch 22/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0065 - val_loss: 0.0236
# Epoch 23/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0081 - val_loss: 0.0244
# Epoch 24/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0067 - val_loss: 0.0284
# Epoch 25/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0071 - val_loss: 0.0281
# Epoch 26/100
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0072 - val_loss: 0.0256
# Epoch 27/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0063 - val_loss: 0.0249
# Epoch 28/100
# 7/7 [==============================] - 2s 229ms/step - loss: 0.0059 - val_loss: 0.0236
# Epoch 29/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0064 - val_loss: 0.0221
# Epoch 30/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0060 - val_loss: 0.0202
# Epoch 31/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0057 - val_loss: 0.0182
# Epoch 32/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0054 - val_loss: 0.0178
# Epoch 33/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0052 - val_loss: 0.0196
# Epoch 34/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0070 - val_loss: 0.0226
# Epoch 35/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0083 - val_loss: 0.0211
# Epoch 36/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0063 - val_loss: 0.0213
# Epoch 37/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0066 - val_loss: 0.0237
# Epoch 38/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0057 - val_loss: 0.0202
# Epoch 39/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0053 - val_loss: 0.0192
# Epoch 40/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0057 - val_loss: 0.0181
# Epoch 41/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0047 - val_loss: 0.0167
# Epoch 42/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0046 - val_loss: 0.0147
# Epoch 43/100
# 7/7 [==============================] - 2s 234ms/step - loss: 0.0042 - val_loss: 0.0135
# Epoch 44/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0050 - val_loss: 0.0135
# Epoch 45/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0055 - val_loss: 0.0136
# Epoch 46/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0050 - val_loss: 0.0139
# Epoch 47/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0049 - val_loss: 0.0134
# Epoch 48/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0050 - val_loss: 0.0123
# Epoch 49/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0047 - val_loss: 0.0129
# Epoch 50/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0045 - val_loss: 0.0143
# Epoch 51/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0051 - val_loss: 0.0129
# Epoch 52/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0044 - val_loss: 0.0119
# Epoch 53/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0052 - val_loss: 0.0112
# Epoch 54/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0045 - val_loss: 0.0107
# Epoch 55/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0043 - val_loss: 0.0107
# Epoch 56/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0046 - val_loss: 0.0107
# Epoch 57/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0048 - val_loss: 0.0127
# Epoch 58/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0043 - val_loss: 0.0113
# Epoch 59/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0044 - val_loss: 0.0105
# Epoch 60/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0040 - val_loss: 0.0096
# Epoch 61/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0037 - val_loss: 0.0099
# Epoch 62/100
# 7/7 [==============================] - 2s 231ms/step - loss: 0.0050 - val_loss: 0.0102
# Epoch 63/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0050 - val_loss: 0.0113
# Epoch 64/100
# 7/7 [==============================] - 2s 214ms/step - loss: 0.0040 - val_loss: 0.0132
# Epoch 65/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0044 - val_loss: 0.0112
# Epoch 66/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0037 - val_loss: 0.0105
# Epoch 67/100
# 7/7 [==============================] - 2s 216ms/step - loss: 0.0039 - val_loss: 0.0098
# Epoch 68/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0043 - val_loss: 0.0102
# Epoch 69/100
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0041 - val_loss: 0.0108
# Epoch 70/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0041 - val_loss: 0.0104
# Epoch 71/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0040 - val_loss: 0.0099
# Epoch 72/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0043 - val_loss: 0.0097
# Epoch 73/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0038 - val_loss: 0.0121
# Epoch 74/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0039 - val_loss: 0.0109
# Epoch 75/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0044 - val_loss: 0.0096
# Epoch 76/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0042 - val_loss: 0.0098
# Epoch 77/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0036 - val_loss: 0.0095
# Epoch 78/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0039 - val_loss: 0.0091
# Epoch 79/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0031 - val_loss: 0.0084
# Epoch 80/100
# 7/7 [==============================] - 2s 218ms/step - loss: 0.0039 - val_loss: 0.0086
# Epoch 81/100
# 7/7 [==============================] - 2s 219ms/step - loss: 0.0033 - val_loss: 0.0087
# Epoch 82/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0037 - val_loss: 0.0082
# Epoch 83/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0036 - val_loss: 0.0068
# Epoch 84/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0037 - val_loss: 0.0068
# Epoch 85/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0036 - val_loss: 0.0070
# Epoch 86/100
# 7/7 [==============================] - 2s 229ms/step - loss: 0.0036 - val_loss: 0.0073
# Epoch 87/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0031 - val_loss: 0.0089
# Epoch 88/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0039 - val_loss: 0.0091
# Epoch 89/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0036 - val_loss: 0.0088
# Epoch 90/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0032 - val_loss: 0.0079
# Epoch 91/100
# 7/7 [==============================] - 2s 221ms/step - loss: 0.0031 - val_loss: 0.0080
# Epoch 92/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0030 - val_loss: 0.0078
# Epoch 93/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0035 - val_loss: 0.0074
# Epoch 94/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0043 - val_loss: 0.0080
# Epoch 95/100
# 7/7 [==============================] - 2s 220ms/step - loss: 0.0032 - val_loss: 0.0084
# Epoch 96/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0031 - val_loss: 0.0075
# Epoch 97/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0038 - val_loss: 0.0073
# Epoch 98/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0041 - val_loss: 0.0074
# Epoch 99/100
# 7/7 [==============================] - 2s 217ms/step - loss: 0.0035 - val_loss: 0.0080
# Epoch 100/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0034 - val_loss: 0.0085

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath = "/content/drive/MyDrive/stock_price_BILSTM/modelsDESCO/model.h5"
model.save(filepath)

# %%
from keras.models import load_model
f1 = '/content/drive/MyDrive/stock_price_BILSTM/modelsDESCO/model.h5'
model = load_model(f1)

# %%
import tensorflow as tf
from sklearn.metrics import r2_score

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict = np.reshape(train_predict,(1, train_predict.size))
train_predict=scaler.inverse_transform(train_predict)
test_predict = np.reshape(test_predict,(1, test_predict.size))
test_predict=scaler.inverse_transform(test_predict)
X = np.reshape(ytest,(1, ytest.size))
Y_test =scaler.inverse_transform(X)

# %%
Y_test
# Out:
# array([[4.1638621 , 3.93468193, 3.33340385, 1.68365192, 1.68237586,
#         1.68237586, 1.68237586, 1.68237586, 1.68237586, 1.68237586,
#         1.68237586, 1.68237586, 1.68237586, 1.81711736, 1.96645825,
#         2.46293795, 2.46293795, 2.23161447, 2.70056959, 3.78154271,
#         3.78597022, 3.78597022, 4.7498514 , 5.10484531, 5.19681017,
#         5.99078812, 6.2309951 , 6.36203243, 6.39463366, 6.87864634,
#         7.31196381]])

# %%
test_predict
# Out:
# array([[4.7486153, 4.61849  , 4.4800143, 4.203549 , 3.5002475, 3.0006037,
#         2.6648889, 2.4497366, 2.319256 , 2.245607 , 2.2126434, 2.2362628,
#         2.2318327, 2.232147 , 2.2658072, 2.3448164, 2.5508163, 2.713859 ,
#         2.7606647, 2.9226854, 3.3815112, 3.7437775, 3.9993253, 4.4853425,
#         4.9551787, 5.297384 , 5.783259 , 6.181597 , 6.4595814, 6.6113253,
#         6.8643374]], dtype=float32)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
#Y_test = Y_test.transpose()
RMSE = math.sqrt(mean_squared_error(Y_test,test_predict))
RMSE
# Out:
# 0.736742634064118

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(Y_test,test_predict)
print('MAE: %f' % mae)
# Out:
# MAE: 0.579537

# %%
train_predict.shape
# Out:
# (1, 206)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
test_predict = test_predict.transpose()

# %%
train_predict = train_predict.transpose()

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df),color ='blue', label ='original')
plt.plot(trainPredictPlot, color ='orange', label ='predicted')
plt.plot(testPredictPlot , color ='red', label ='tested')
#plt.show()
plt.xlabel('number of days')
plt.ylabel('volatility magnitude')
plt.title('ABBANk Risk Factor Prediction')
plt.legend(loc='best')
plt.show(block=False)

# %%
x_input=test_data[32:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<10):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

#print(lst_output)
# Out:
# [0.9237194]
# 101
# 1 day input [0.41865486 0.43707088 0.37062697 0.37188426 0.36452444 0.40035555
#  0.39745113 0.39965317 0.40182236 0.39423456 0.38847087 0.39407087
#  0.45848533 0.48635468 0.55615661 0.5560904  0.73570287 0.68257175
#  0.68050487 0.67923271 0.67905053 0.69231141 0.68759081 0.68946576
#  0.68446707 0.69081708 0.67569486 0.70018759 0.7186249  0.76497398
#  0.76491396 0.76579886 0.77092413 0.73429993 0.76844155 0.72068919
#  0.72068472 0.51333664 0.50819697 0.7299009  0.74878433 0.79174579
#  0.8209982  0.84684862 0.86960752 0.89207206 0.88810158 0.90268711
#  0.91704915 0.97466638 0.93657381 0.9366007  0.936264   0.92648236
#  0.91338362 0.88340663 0.88340663 0.88342779 0.88333386 0.88333386
#  0.71394599 0.69687259 0.63870475 0.61415682 0.59065684 0.56007246
#  0.52091982 0.52091982 0.49224824 0.41702537 0.21063321 0.21047357
#  0.21047357 0.21047357 0.21047357 0.21047357 0.21047357 0.21047357
#  0.21047357 0.21047357 0.2273304  0.24601369 0.30812576 0.30812576
#  0.27918605 0.33785466 0.47308977 0.47364367 0.47364367 0.59422999
#  0.63864149 0.65014675 0.74947734 0.77952842 0.79592184 0.80000042
#  0.86055281 0.91476297 0.91698727 0.92371941]
# 1 day output [[0.9387894]]
# 2 day input [0.43707088 0.37062697 0.37188426 0.36452444 0.40035555 0.39745113
#  0.39965317 0.40182236 0.39423456 0.38847087 0.39407087 0.45848533
#  0.48635468 0.55615661 0.5560904  0.73570287 0.68257175 0.68050487
#  0.67923271 0.67905053 0.69231141 0.68759081 0.68946576 0.68446707
#  0.69081708 0.67569486 0.70018759 0.7186249  0.76497398 0.76491396
#  0.76579886 0.77092413 0.73429993 0.76844155 0.72068919 0.72068472
#  0.51333664 0.50819697 0.7299009  0.74878433 0.79174579 0.8209982
#  0.84684862 0.86960752 0.89207206 0.88810158 0.90268711 0.91704915
#  0.97466638 0.93657381 0.9366007  0.936264   0.92648236 0.91338362
#  0.88340663 0.88340663 0.88342779 0.88333386 0.88333386 0.71394599
#  0.69687259 0.63870475 0.61415682 0.59065684 0.56007246 0.52091982
#  0.52091982 0.49224824 0.41702537 0.21063321 0.21047357 0.21047357
#  0.21047357 0.21047357 0.21047357 0.21047357 0.21047357 0.21047357
#  0.21047357 0.2273304  0.24601369 0.30812576 0.30812576 0.27918605
#  0.33785466 0.47308977 0.47364367 0.47364367 0.59422999 0.63864149
#  0.65014675 0.74947734 0.77952842 0.79592184 0.80000042 0.86055281
#  0.91476297 0.91698727 0.92371941 0.93878943]
# 2 day output [[0.95179474]]
# 3 day input [0.37062697 0.37188426 0.36452444 0.40035555 0.39745113 0.39965317
#  0.40182236 0.39423456 0.38847087 0.39407087 0.45848533 0.48635468
#  0.55615661 0.5560904  0.73570287 0.68257175 0.68050487 0.67923271
#  0.67905053 0.69231141 0.68759081 0.68946576 0.68446707 0.69081708
#  0.67569486 0.70018759 0.7186249  0.76497398 0.76491396 0.76579886
#  0.77092413 0.73429993 0.76844155 0.72068919 0.72068472 0.51333664
#  0.50819697 0.7299009  0.74878433 0.79174579 0.8209982  0.84684862
#  0.86960752 0.89207206 0.88810158 0.90268711 0.91704915 0.97466638
#  0.93657381 0.9366007  0.936264   0.92648236 0.91338362 0.88340663
#  0.88340663 0.88342779 0.88333386 0.88333386 0.71394599 0.69687259
#  0.63870475 0.61415682 0.59065684 0.56007246 0.52091982 0.52091982
#  0.49224824 0.41702537 0.21063321 0.21047357 0.21047357 0.21047357
#  0.21047357 0.21047357 0.21047357 0.21047357 0.21047357 0.21047357
#  0.2273304  0.24601369 0.30812576 0.30812576 0.27918605 0.33785466
#  0.47308977 0.47364367 0.47364367 0.59422999 0.63864149 0.65014675
#  0.74947734 0.77952842 0.79592184 0.80000042 0.86055281 0.91476297
#  0.91698727 0.92371941 0.93878943 0.95179474]
# 3 day output [[0.9648723]]
# 4 day input [0.37188426 0.36452444 0.40035555 0.39745113 0.39965317 0.40182236
#  0.39423456 0.38847087 0.39407087 0.45848533 0.48635468 0.55615661
#  0.5560904  0.73570287 0.68257175 0.68050487 0.67923271 0.67905053
#  0.69231141 0.68759081 0.68946576 0.68446707 0.69081708 0.67569486
#  0.70018759 0.7186249  0.76497398 0.76491396 0.76579886 0.77092413
#  0.73429993 0.76844155 0.72068919 0.72068472 0.51333664 0.50819697
#  0.7299009  0.74878433 0.79174579 0.8209982  0.84684862 0.86960752
#  0.89207206 0.88810158 0.90268711 0.91704915 0.97466638 0.93657381
#  0.9366007  0.936264   0.92648236 0.91338362 0.88340663 0.88340663
#  0.88342779 0.88333386 0.88333386 0.71394599 0.69687259 0.63870475
#  0.61415682 0.59065684 0.56007246 0.52091982 0.52091982 0.49224824
#  0.41702537 0.21063321 0.21047357 0.21047357 0.21047357 0.21047357
#  0.21047357 0.21047357 0.21047357 0.21047357 0.21047357 0.2273304
#  0.24601369 0.30812576 0.30812576 0.27918605 0.33785466 0.47308977
#  0.47364367 0.47364367 0.59422999 0.63864149 0.65014675 0.74947734
#  0.77952842 0.79592184 0.80000042 0.86055281 0.91476297 0.91698727
#  0.92371941 0.93878943 0.95179474 0.9648723 ]
# 4 day output [[0.97772235]]
# 5 day input [0.36452444 0.40035555 0.39745113 0.39965317 0.40182236 0.39423456
#  0.38847087 0.39407087 0.45848533 0.48635468 0.55615661 0.5560904
#  0.73570287 0.68257175 0.68050487 0.67923271 0.67905053 0.69231141
#  0.68759081 0.68946576 0.68446707 0.69081708 0.67569486 0.70018759
#  0.7186249  0.76497398 0.76491396 0.76579886 0.77092413 0.73429993
#  0.76844155 0.72068919 0.72068472 0.51333664 0.50819697 0.7299009
#  0.74878433 0.79174579 0.8209982  0.84684862 0.86960752 0.89207206
#  0.88810158 0.90268711 0.91704915 0.97466638 0.93657381 0.9366007
#  0.936264   0.92648236 0.91338362 0.88340663 0.88340663 0.88342779
#  0.88333386 0.88333386 0.71394599 0.69687259 0.63870475 0.61415682
#  0.59065684 0.56007246 0.52091982 0.52091982 0.49224824 0.41702537
#  0.21063321 0.21047357 0.21047357 0.21047357 0.21047357 0.21047357
#  0.21047357 0.21047357 0.21047357 0.21047357 0.2273304  0.24601369
#  0.30812576 0.30812576 0.27918605 0.33785466 0.47308977 0.47364367
#  0.47364367 0.59422999 0.63864149 0.65014675 0.74947734 0.77952842
#  0.79592184 0.80000042 0.86055281 0.91476297 0.91698727 0.92371941
#  0.93878943 0.95179474 0.9648723  0.97772235]
# 5 day output [[0.9921161]]
# 6 day input [0.40035555 0.39745113 0.39965317 0.40182236 0.39423456 0.38847087
#  0.39407087 0.45848533 0.48635468 0.55615661 0.5560904  0.73570287
#  0.68257175 0.68050487 0.67923271 0.67905053 0.69231141 0.68759081
#  0.68946576 0.68446707 0.69081708 0.67569486 0.70018759 0.7186249
#  0.76497398 0.76491396 0.76579886 0.77092413 0.73429993 0.76844155
#  0.72068919 0.72068472 0.51333664 0.50819697 0.7299009  0.74878433
#  0.79174579 0.8209982  0.84684862 0.86960752 0.89207206 0.88810158
#  0.90268711 0.91704915 0.97466638 0.93657381 0.9366007  0.936264
#  0.92648236 0.91338362 0.88340663 0.88340663 0.88342779 0.88333386
#  0.88333386 0.71394599 0.69687259 0.63870475 0.61415682 0.59065684
#  0.56007246 0.52091982 0.52091982 0.49224824 0.41702537 0.21063321
#  0.21047357 0.21047357 0.21047357 0.21047357 0.21047357 0.21047357
#  0.21047357 0.21047357 0.21047357 0.2273304  0.24601369 0.30812576
#  0.30812576 0.27918605 0.33785466 0.47308977 0.47364367 0.47364367
#  0.59422999 0.63864149 0.65014675 0.74947734 0.77952842 0.79592184
#  0.80000042 0.86055281 0.91476297 0.91698727 0.92371941 0.93878943
#  0.95179474 0.9648723  0.97772235 0.99211609]
# 6 day output [[1.0088559]]
# 7 day input [0.39745113 0.39965317 0.40182236 0.39423456 0.38847087 0.39407087
#  0.45848533 0.48635468 0.55615661 0.5560904  0.73570287 0.68257175
#  0.68050487 0.67923271 0.67905053 0.69231141 0.68759081 0.68946576
#  0.68446707 0.69081708 0.67569486 0.70018759 0.7186249  0.76497398
#  0.76491396 0.76579886 0.77092413 0.73429993 0.76844155 0.72068919
#  0.72068472 0.51333664 0.50819697 0.7299009  0.74878433 0.79174579
#  0.8209982  0.84684862 0.86960752 0.89207206 0.88810158 0.90268711
#  0.91704915 0.97466638 0.93657381 0.9366007  0.936264   0.92648236
#  0.91338362 0.88340663 0.88340663 0.88342779 0.88333386 0.88333386
#  0.71394599 0.69687259 0.63870475 0.61415682 0.59065684 0.56007246
#  0.52091982 0.52091982 0.49224824 0.41702537 0.21063321 0.21047357
#  0.21047357 0.21047357 0.21047357 0.21047357 0.21047357 0.21047357
#  0.21047357 0.21047357 0.2273304  0.24601369 0.30812576 0.30812576
#  0.27918605 0.33785466 0.47308977 0.47364367 0.47364367 0.59422999
#  0.63864149 0.65014675 0.74947734 0.77952842 0.79592184 0.80000042
#  0.86055281 0.91476297 0.91698727 0.92371941 0.93878943 0.95179474
#  0.9648723  0.97772235 0.99211609 1.00885594]
# 7 day output [[1.0296527]]
# 8 day input [0.39965317 0.40182236 0.39423456 0.38847087 0.39407087 0.45848533
#  0.48635468 0.55615661 0.5560904  0.73570287 0.68257175 0.68050487
#  0.67923271 0.67905053 0.69231141 0.68759081 0.68946576 0.68446707
#  0.69081708 0.67569486 0.70018759 0.7186249  0.76497398 0.76491396
#  0.76579886 0.77092413 0.73429993 0.76844155 0.72068919 0.72068472
#  0.51333664 0.50819697 0.7299009  0.74878433 0.79174579 0.8209982
#  0.84684862 0.86960752 0.89207206 0.88810158 0.90268711 0.91704915
#  0.97466638 0.93657381 0.9366007  0.936264   0.92648236 0.91338362
#  0.88340663 0.88340663 0.88342779 0.88333386 0.88333386 0.71394599
#  0.69687259 0.63870475 0.61415682 0.59065684 0.56007246 0.52091982
#  0.52091982 0.49224824 0.41702537 0.21063321 0.21047357 0.21047357
#  0.21047357 0.21047357 0.21047357 0.21047357 0.21047357 0.21047357
#  0.21047357 0.2273304  0.24601369 0.30812576 0.30812576 0.27918605
#  0.33785466 0.47308977 0.47364367 0.47364367 0.59422999 0.63864149
#  0.65014675 0.74947734 0.77952842 0.79592184 0.80000042 0.86055281
#  0.91476297 0.91698727 0.92371941 0.93878943 0.95179474 0.9648723
#  0.97772235 0.99211609 1.00885594 1.02965271]
# 8 day output [[1.0545144]]
# 9 day input [0.40182236 0.39423456 0.38847087 0.39407087 0.45848533 0.48635468
#  0.55615661 0.5560904  0.73570287 0.68257175 0.68050487 0.67923271
#  0.67905053 0.69231141 0.68759081 0.68946576 0.68446707 0.69081708
#  0.67569486 0.70018759 0.7186249  0.76497398 0.76491396 0.76579886
#  0.77092413 0.73429993 0.76844155 0.72068919 0.72068472 0.51333664
#  0.50819697 0.7299009  0.74878433 0.79174579 0.8209982  0.84684862
#  0.86960752 0.89207206 0.88810158 0.90268711 0.91704915 0.97466638
#  0.93657381 0.9366007  0.936264   0.92648236 0.91338362 0.88340663
#  0.88340663 0.88342779 0.88333386 0.88333386 0.71394599 0.69687259
#  0.63870475 0.61415682 0.59065684 0.56007246 0.52091982 0.52091982
#  0.49224824 0.41702537 0.21063321 0.21047357 0.21047357 0.21047357
#  0.21047357 0.21047357 0.21047357 0.21047357 0.21047357 0.21047357
#  0.2273304  0.24601369 0.30812576 0.30812576 0.27918605 0.33785466
#  0.47308977 0.47364367 0.47364367 0.59422999 0.63864149 0.65014675
#  0.74947734 0.77952842 0.79592184 0.80000042 0.86055281 0.91476297
#  0.91698727 0.92371941 0.93878943 0.95179474 0.9648723  0.97772235
#  0.99211609 1.00885594 1.02965271 1.05451441]
# 9 day output [[1.0834769]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,111)

# %%
plt.plot(day_new,scaler.inverse_transform(df[339:]),color ='blue', label ='origial')
plt.plot(day_pred,scaler.inverse_transform(lst_output),color='red', label='future')
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 10 Days Forecasting')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=df.tolist()
df3.extend(lst_output)
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 30 Days Forecasting')
plt.plot(df3[409:],color='red', label='future')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("/content/CITYBANK.csv",parse_dates=['DATE'])
df.head()
# Out:
#      #       DATE TRADING CODE  LTP*  ...   YCP   TRADE  VALUE (mn)     VOLUME
# 0  439 2018-05-08     CITYBANK  30.5  ...  30.7   347.0      14.650   476443.0
# 1  438 2018-06-08     CITYBANK  30.8  ...  30.4   365.0      23.843   787366.0
# 2  437 2018-07-08     CITYBANK  30.7  ...  30.6   424.0      25.470   830120.0
# 3  436 2018-08-08     CITYBANK  31.7  ...  30.6   982.0      59.484  1902891.0
# 4  435 2018-09-08     CITYBANK  31.8  ...  31.8  1007.0      65.347  2042307.0
#
# [5 rows x 12 columns]

# %%
# Sort DataFrame by date
df = df.sort_values('DATE')

# Double check the result
df.head()
# Out:
#       #       DATE TRADING CODE  LTP*  ...   YCP   TRADE  VALUE (mn)     VOLUME
# 36  403 2018-01-10     CITYBANK  32.1  ...  32.1   324.0      25.289   785961.0
# 59  380 2018-01-11     CITYBANK  31.6  ...  31.8   537.0      37.801  1194699.0
# 37  402 2018-02-10     CITYBANK  32.7  ...  32.2   399.0      20.460   631149.0
# 79  360 2018-02-12     CITYBANK  30.5  ...  31.2   340.0      27.198   885534.0
# 16  423 2018-03-09     CITYBANK  34.5  ...  35.5  1181.0      62.509  1796220.0
#
# [5 rows x 12 columns]

# %%
df = df.set_index('DATE')
df.head(3)
# Out:
#               # TRADING CODE  LTP*  HIGH  ...   YCP  TRADE  VALUE (mn)     VOLUME
# DATE                                      ...
# 2018-01-10  403     CITYBANK  32.1  32.6  ...  32.1  324.0      25.289   785961.0
# 2018-01-11  380     CITYBANK  31.6  31.8  ...  31.8  537.0      37.801  1194699.0
# 2018-02-10  402     CITYBANK  32.7  32.7  ...  32.2  399.0      20.460   631149.0
#
# [3 rows x 11 columns]

# %%
df['daily_ret'] = df['CLOSEP*'].pct_change()
df['daily_ret'] = df['daily_ret'].fillna(0.0)

# %%
df['volatility']= df['daily_ret'].rolling(window=21).std()
df['volatility'] = df['volatility'].fillna(0.0)

# %%
df['volatility'] = df['volatility']*100

# %%
import matplotlib.pyplot as plt

# %%
df=df.reset_index()['volatility']

# %%
plt.plot(df)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
df.shape
# Out:
# (439, 1)

# %%
##splitting dataset into train and test split where train=70 percent and test=30 percent
training_size=int(len(df)*0.70)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
training_size,test_size
# Out:
# (307, 132)

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [],[]
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (206, 100)
# (206,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import Bidirectional

# %%
model=Sequential()
model.add(Bidirectional(LSTM(50,return_sequences=True,input_shape=(100,1))))
model.add(Bidirectional(LSTM(50,return_sequences=True)))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 15s 619ms/step - loss: 0.2355 - val_loss: 0.1437
# Epoch 2/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0355 - val_loss: 0.0145
# Epoch 3/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0272 - val_loss: 0.0650
# Epoch 4/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0122 - val_loss: 0.0617
# Epoch 5/100
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0115 - val_loss: 0.0413
# Epoch 6/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0127 - val_loss: 0.0678
# Epoch 7/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0092 - val_loss: 0.0492
# Epoch 8/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0094 - val_loss: 0.0566
# Epoch 9/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0105 - val_loss: 0.0566
# Epoch 10/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0097 - val_loss: 0.0539
# Epoch 11/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0097 - val_loss: 0.0561
# Epoch 12/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0088 - val_loss: 0.0539
# Epoch 13/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0088 - val_loss: 0.0530
# Epoch 14/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0093 - val_loss: 0.0509
# Epoch 15/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0078 - val_loss: 0.0560
# Epoch 16/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0100 - val_loss: 0.0448
# Epoch 17/100
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0093 - val_loss: 0.0502
# Epoch 18/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0079 - val_loss: 0.0509
# Epoch 19/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0093 - val_loss: 0.0426
# Epoch 20/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0080 - val_loss: 0.0541
# Epoch 21/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0075 - val_loss: 0.0385
# Epoch 22/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0082 - val_loss: 0.0327
# Epoch 23/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0064 - val_loss: 0.0483
# Epoch 24/100
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0087 - val_loss: 0.0417
# Epoch 25/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0058 - val_loss: 0.0311
# Epoch 26/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0064 - val_loss: 0.0296
# Epoch 27/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0071 - val_loss: 0.0367
# Epoch 28/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0071 - val_loss: 0.0601
# Epoch 29/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0082 - val_loss: 0.0384
# Epoch 30/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0057 - val_loss: 0.0385
# Epoch 31/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0054 - val_loss: 0.0421
# Epoch 32/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0049 - val_loss: 0.0328
# Epoch 33/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0059 - val_loss: 0.0454
# Epoch 34/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0050 - val_loss: 0.0479
# Epoch 35/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0051 - val_loss: 0.0428
# Epoch 36/100
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0045 - val_loss: 0.0391
# Epoch 37/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0057 - val_loss: 0.0356
# Epoch 38/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0055 - val_loss: 0.0417
# Epoch 39/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0050 - val_loss: 0.0442
# Epoch 40/100
# 7/7 [==============================] - 2s 247ms/step - loss: 0.0067 - val_loss: 0.0484
# Epoch 41/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0050 - val_loss: 0.0434
# Epoch 42/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0043 - val_loss: 0.0355
# Epoch 43/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0050 - val_loss: 0.0363
# Epoch 44/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0039 - val_loss: 0.0301
# Epoch 45/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0045 - val_loss: 0.0304
# Epoch 46/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0075 - val_loss: 0.0591
# Epoch 47/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0061 - val_loss: 0.0364
# Epoch 48/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0041 - val_loss: 0.0352
# Epoch 49/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0043 - val_loss: 0.0441
# Epoch 50/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0066 - val_loss: 0.0333
# Epoch 51/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0049 - val_loss: 0.0323
# Epoch 52/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0039 - val_loss: 0.0340
# Epoch 53/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0039 - val_loss: 0.0317
# Epoch 54/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0043 - val_loss: 0.0341
# Epoch 55/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0044 - val_loss: 0.0339
# Epoch 56/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0052 - val_loss: 0.0366
# Epoch 57/100
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0038 - val_loss: 0.0384
# Epoch 58/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0039 - val_loss: 0.0341
# Epoch 59/100
# 7/7 [==============================] - 2s 246ms/step - loss: 0.0043 - val_loss: 0.0363
# Epoch 60/100
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0057 - val_loss: 0.0469
# Epoch 61/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0053 - val_loss: 0.0513
# Epoch 62/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0054 - val_loss: 0.0500
# Epoch 63/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0054 - val_loss: 0.0288
# Epoch 64/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0050 - val_loss: 0.0289
# Epoch 65/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0047 - val_loss: 0.0424
# Epoch 66/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0040 - val_loss: 0.0367
# Epoch 67/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0043 - val_loss: 0.0391
# Epoch 68/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0053 - val_loss: 0.0388
# Epoch 69/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0051 - val_loss: 0.0368
# Epoch 70/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0045 - val_loss: 0.0400
# Epoch 71/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0049 - val_loss: 0.0411
# Epoch 72/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0060 - val_loss: 0.0429
# Epoch 73/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0041 - val_loss: 0.0304
# Epoch 74/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0044 - val_loss: 0.0378
# Epoch 75/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0036 - val_loss: 0.0468
# Epoch 76/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0051 - val_loss: 0.0410
# Epoch 77/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0047 - val_loss: 0.0354
# Epoch 78/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0050 - val_loss: 0.0444
# Epoch 79/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0037 - val_loss: 0.0412
# Epoch 80/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0040 - val_loss: 0.0296
# Epoch 81/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0052 - val_loss: 0.0390
# Epoch 82/100
# 7/7 [==============================] - 2s 247ms/step - loss: 0.0040 - val_loss: 0.0373
# Epoch 83/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0041 - val_loss: 0.0377
# Epoch 84/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0040 - val_loss: 0.0344
# Epoch 85/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0044 - val_loss: 0.0355
# Epoch 86/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0049 - val_loss: 0.0383
# Epoch 87/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0043 - val_loss: 0.0411
# Epoch 88/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0051 - val_loss: 0.0380
# Epoch 89/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0045 - val_loss: 0.0308
# Epoch 90/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0045 - val_loss: 0.0324
# Epoch 91/100
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0043 - val_loss: 0.0373
# Epoch 92/100
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0036 - val_loss: 0.0351
# Epoch 93/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0031 - val_loss: 0.0305
# Epoch 94/100
# 7/7 [==============================] - 2s 246ms/step - loss: 0.0052 - val_loss: 0.0389
# Epoch 95/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0048 - val_loss: 0.0388
# Epoch 96/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0038 - val_loss: 0.0308
# Epoch 97/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0039 - val_loss: 0.0332
# Epoch 98/100
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0036 - val_loss: 0.0376
# Epoch 99/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0050 - val_loss: 0.0359
# Epoch 100/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0045 - val_loss: 0.0373

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath = "/content/drive/MyDrive/stock_price_BILSTM/modelsCITYBANK/model.h5"
model.save(filepath)

# %%
from keras.models import load_model
f1 = '/content/drive/MyDrive/stock_price_BILSTM/modelsCITYBANK/model.h5'
model = load_model(f1)

# %%
import tensorflow as tf
from sklearn.metrics import r2_score

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict = np.reshape(train_predict,(1, train_predict.size))
train_predict=scaler.inverse_transform(train_predict)
test_predict = np.reshape(test_predict,(1, test_predict.size))
test_predict=scaler.inverse_transform(test_predict)
X = np.reshape(ytest,(1, ytest.size))
Y_test =scaler.inverse_transform(X)

# %%
Y_test
# Out:
# array([[4.09002259, 3.21704756, 3.20607105, 2.85000678, 2.82100469,
#         2.82100469, 2.82100469, 2.82100469, 2.82100469, 2.82100469,
#         2.82100469, 2.82100469, 2.82100469, 3.71400881, 3.80949591,
#         4.12847939, 4.31235535, 4.18375435, 3.82210554, 3.85766129,
#         3.7918826 , 3.63436925, 3.66111983, 3.68983034, 3.88624052,
#         4.79724001, 4.95009616, 5.20394482, 5.48153018, 5.55071818,
#         5.84396955]])

# %%
test_predict
# Out:
# array([[5.93679  , 5.940545 , 5.8082995, 5.7287436, 5.6302505, 5.5797234,
#         5.575549 , 5.605996 , 5.6567993, 5.7169943, 5.7769303, 5.7820306,
#         5.8856187, 5.981389 , 6.275324 , 6.5642953, 6.8700056, 7.1640615,
#         7.3646336, 7.4116535, 7.413791 , 7.3627462, 7.2510233, 7.1323395,
#         7.0134263, 6.932933 , 7.043961 , 7.150209 , 7.25445  , 7.3443947,
#         7.379752 ]], dtype=float32)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
#Y_test = Y_test.transpose()
RMSE = math.sqrt(mean_squared_error(Y_test,test_predict))
RMSE
# Out:
# 2.7964691238252475

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(Y_test,test_predict)
print('MAE: %f' % mae)
# Out:
# MAE: 2.713326

# %%
train_predict.shape
# Out:
# (1, 206)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
test_predict = test_predict.transpose()

# %%
train_predict = train_predict.transpose()

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df),color ='blue', label ='original')
plt.plot(trainPredictPlot, color ='orange', label ='predicted')
plt.plot(testPredictPlot , color ='red', label ='tested')
#plt.show()
plt.xlabel('number of days')
plt.ylabel('volatility magnitude')
plt.title('ABBANk Risk Factor Prediction')
plt.legend(loc='best')
plt.show(block=False)

# %%
x_input=test_data[32:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<10):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

#print(lst_output)
# Out:
# [0.5164079]
# 101
# 1 day input [0.37273277 0.37145627 0.33747836 0.30273933 0.31130796 0.31175962
#  0.30969939 0.30993803 0.31039831 0.3112404  0.31118524 0.31705856
#  0.32543292 0.33465096 0.35430742 0.35543628 0.3691446  0.36716645
#  0.36405664 0.3637269  0.36649095 0.37013318 0.35629444 0.35605469
#  0.3598132  0.35935787 0.35947843 0.36681313 0.37091291 0.39008156
#  0.3896525  0.3896525  0.38513836 0.3837374  0.39789185 0.37615637
#  0.37577808 0.27385809 0.24442829 0.25707857 0.25704232 0.28584791
#  0.37066416 0.37985501 0.381914   0.39838006 0.39404203 0.42915337
#  0.42463752 0.4332677  0.41393374 0.41393374 0.41393374 0.41074743
#  0.40382522 0.3861082  0.38604014 0.38604014 0.38564004 0.38145893
#  0.37386999 0.37412521 0.34953861 0.2745513  0.28287883 0.28486792
#  0.26130613 0.2825944  0.22227741 0.221519   0.19691724 0.19491338
#  0.19491338 0.19491338 0.19491338 0.19491338 0.19491338 0.19491338
#  0.19491338 0.19491338 0.25661425 0.2632118  0.28525152 0.29795617
#  0.28907066 0.26408304 0.26653972 0.26199483 0.25111167 0.25295996
#  0.25494367 0.26851436 0.3314586  0.34201998 0.3595593  0.37873867
#  0.38351912 0.40378091 0.40561023 0.51640791]
# 1 day output [[0.54065305]]
# 2 day input [0.37145627 0.33747836 0.30273933 0.31130796 0.31175962 0.30969939
#  0.30993803 0.31039831 0.3112404  0.31118524 0.31705856 0.32543292
#  0.33465096 0.35430742 0.35543628 0.3691446  0.36716645 0.36405664
#  0.3637269  0.36649095 0.37013318 0.35629444 0.35605469 0.3598132
#  0.35935787 0.35947843 0.36681313 0.37091291 0.39008156 0.3896525
#  0.3896525  0.38513836 0.3837374  0.39789185 0.37615637 0.37577808
#  0.27385809 0.24442829 0.25707857 0.25704232 0.28584791 0.37066416
#  0.37985501 0.381914   0.39838006 0.39404203 0.42915337 0.42463752
#  0.4332677  0.41393374 0.41393374 0.41393374 0.41074743 0.40382522
#  0.3861082  0.38604014 0.38604014 0.38564004 0.38145893 0.37386999
#  0.37412521 0.34953861 0.2745513  0.28287883 0.28486792 0.26130613
#  0.2825944  0.22227741 0.221519   0.19691724 0.19491338 0.19491338
#  0.19491338 0.19491338 0.19491338 0.19491338 0.19491338 0.19491338
#  0.19491338 0.25661425 0.2632118  0.28525152 0.29795617 0.28907066
#  0.26408304 0.26653972 0.26199483 0.25111167 0.25295996 0.25494367
#  0.26851436 0.3314586  0.34201998 0.3595593  0.37873867 0.38351912
#  0.40378091 0.40561023 0.51640791 0.54065305]
# 2 day output [[0.5636122]]
# 3 day input [0.33747836 0.30273933 0.31130796 0.31175962 0.30969939 0.30993803
#  0.31039831 0.3112404  0.31118524 0.31705856 0.32543292 0.33465096
#  0.35430742 0.35543628 0.3691446  0.36716645 0.36405664 0.3637269
#  0.36649095 0.37013318 0.35629444 0.35605469 0.3598132  0.35935787
#  0.35947843 0.36681313 0.37091291 0.39008156 0.3896525  0.3896525
#  0.38513836 0.3837374  0.39789185 0.37615637 0.37577808 0.27385809
#  0.24442829 0.25707857 0.25704232 0.28584791 0.37066416 0.37985501
#  0.381914   0.39838006 0.39404203 0.42915337 0.42463752 0.4332677
#  0.41393374 0.41393374 0.41393374 0.41074743 0.40382522 0.3861082
#  0.38604014 0.38604014 0.38564004 0.38145893 0.37386999 0.37412521
#  0.34953861 0.2745513  0.28287883 0.28486792 0.26130613 0.2825944
#  0.22227741 0.221519   0.19691724 0.19491338 0.19491338 0.19491338
#  0.19491338 0.19491338 0.19491338 0.19491338 0.19491338 0.19491338
#  0.25661425 0.2632118  0.28525152 0.29795617 0.28907066 0.26408304
#  0.26653972 0.26199483 0.25111167 0.25295996 0.25494367 0.26851436
#  0.3314586  0.34201998 0.3595593  0.37873867 0.38351912 0.40378091
#  0.40561023 0.51640791 0.54065305 0.56361222]
# 3 day output [[0.58351225]]
# 4 day input [0.30273933 0.31130796 0.31175962 0.30969939 0.30993803 0.31039831
#  0.3112404  0.31118524 0.31705856 0.32543292 0.33465096 0.35430742
#  0.35543628 0.3691446  0.36716645 0.36405664 0.3637269  0.36649095
#  0.37013318 0.35629444 0.35605469 0.3598132  0.35935787 0.35947843
#  0.36681313 0.37091291 0.39008156 0.3896525  0.3896525  0.38513836
#  0.3837374  0.39789185 0.37615637 0.37577808 0.27385809 0.24442829
#  0.25707857 0.25704232 0.28584791 0.37066416 0.37985501 0.381914
#  0.39838006 0.39404203 0.42915337 0.42463752 0.4332677  0.41393374
#  0.41393374 0.41393374 0.41074743 0.40382522 0.3861082  0.38604014
#  0.38604014 0.38564004 0.38145893 0.37386999 0.37412521 0.34953861
#  0.2745513  0.28287883 0.28486792 0.26130613 0.2825944  0.22227741
#  0.221519   0.19691724 0.19491338 0.19491338 0.19491338 0.19491338
#  0.19491338 0.19491338 0.19491338 0.19491338 0.19491338 0.25661425
#  0.2632118  0.28525152 0.29795617 0.28907066 0.26408304 0.26653972
#  0.26199483 0.25111167 0.25295996 0.25494367 0.26851436 0.3314586
#  0.34201998 0.3595593  0.37873867 0.38351912 0.40378091 0.40561023
#  0.51640791 0.54065305 0.56361222 0.58351225]
# 4 day output [[0.6000547]]
# 5 day input [0.31130796 0.31175962 0.30969939 0.30993803 0.31039831 0.3112404
#  0.31118524 0.31705856 0.32543292 0.33465096 0.35430742 0.35543628
#  0.3691446  0.36716645 0.36405664 0.3637269  0.36649095 0.37013318
#  0.35629444 0.35605469 0.3598132  0.35935787 0.35947843 0.36681313
#  0.37091291 0.39008156 0.3896525  0.3896525  0.38513836 0.3837374
#  0.39789185 0.37615637 0.37577808 0.27385809 0.24442829 0.25707857
#  0.25704232 0.28584791 0.37066416 0.37985501 0.381914   0.39838006
#  0.39404203 0.42915337 0.42463752 0.4332677  0.41393374 0.41393374
#  0.41393374 0.41074743 0.40382522 0.3861082  0.38604014 0.38604014
#  0.38564004 0.38145893 0.37386999 0.37412521 0.34953861 0.2745513
#  0.28287883 0.28486792 0.26130613 0.2825944  0.22227741 0.221519
#  0.19691724 0.19491338 0.19491338 0.19491338 0.19491338 0.19491338
#  0.19491338 0.19491338 0.19491338 0.19491338 0.25661425 0.2632118
#  0.28525152 0.29795617 0.28907066 0.26408304 0.26653972 0.26199483
#  0.25111167 0.25295996 0.25494367 0.26851436 0.3314586  0.34201998
#  0.3595593  0.37873867 0.38351912 0.40378091 0.40561023 0.51640791
#  0.54065305 0.56361222 0.58351225 0.60005468]
# 5 day output [[0.61297375]]
# 6 day input [0.31175962 0.30969939 0.30993803 0.31039831 0.3112404  0.31118524
#  0.31705856 0.32543292 0.33465096 0.35430742 0.35543628 0.3691446
#  0.36716645 0.36405664 0.3637269  0.36649095 0.37013318 0.35629444
#  0.35605469 0.3598132  0.35935787 0.35947843 0.36681313 0.37091291
#  0.39008156 0.3896525  0.3896525  0.38513836 0.3837374  0.39789185
#  0.37615637 0.37577808 0.27385809 0.24442829 0.25707857 0.25704232
#  0.28584791 0.37066416 0.37985501 0.381914   0.39838006 0.39404203
#  0.42915337 0.42463752 0.4332677  0.41393374 0.41393374 0.41393374
#  0.41074743 0.40382522 0.3861082  0.38604014 0.38604014 0.38564004
#  0.38145893 0.37386999 0.37412521 0.34953861 0.2745513  0.28287883
#  0.28486792 0.26130613 0.2825944  0.22227741 0.221519   0.19691724
#  0.19491338 0.19491338 0.19491338 0.19491338 0.19491338 0.19491338
#  0.19491338 0.19491338 0.19491338 0.25661425 0.2632118  0.28525152
#  0.29795617 0.28907066 0.26408304 0.26653972 0.26199483 0.25111167
#  0.25295996 0.25494367 0.26851436 0.3314586  0.34201998 0.3595593
#  0.37873867 0.38351912 0.40378091 0.40561023 0.51640791 0.54065305
#  0.56361222 0.58351225 0.60005468 0.61297375]
# 6 day output [[0.6216776]]
# 7 day input [0.30969939 0.30993803 0.31039831 0.3112404  0.31118524 0.31705856
#  0.32543292 0.33465096 0.35430742 0.35543628 0.3691446  0.36716645
#  0.36405664 0.3637269  0.36649095 0.37013318 0.35629444 0.35605469
#  0.3598132  0.35935787 0.35947843 0.36681313 0.37091291 0.39008156
#  0.3896525  0.3896525  0.38513836 0.3837374  0.39789185 0.37615637
#  0.37577808 0.27385809 0.24442829 0.25707857 0.25704232 0.28584791
#  0.37066416 0.37985501 0.381914   0.39838006 0.39404203 0.42915337
#  0.42463752 0.4332677  0.41393374 0.41393374 0.41393374 0.41074743
#  0.40382522 0.3861082  0.38604014 0.38604014 0.38564004 0.38145893
#  0.37386999 0.37412521 0.34953861 0.2745513  0.28287883 0.28486792
#  0.26130613 0.2825944  0.22227741 0.221519   0.19691724 0.19491338
#  0.19491338 0.19491338 0.19491338 0.19491338 0.19491338 0.19491338
#  0.19491338 0.19491338 0.25661425 0.2632118  0.28525152 0.29795617
#  0.28907066 0.26408304 0.26653972 0.26199483 0.25111167 0.25295996
#  0.25494367 0.26851436 0.3314586  0.34201998 0.3595593  0.37873867
#  0.38351912 0.40378091 0.40561023 0.51640791 0.54065305 0.56361222
#  0.58351225 0.60005468 0.61297375 0.62167758]
# 7 day output [[0.62631]]
# 8 day input [0.30993803 0.31039831 0.3112404  0.31118524 0.31705856 0.32543292
#  0.33465096 0.35430742 0.35543628 0.3691446  0.36716645 0.36405664
#  0.3637269  0.36649095 0.37013318 0.35629444 0.35605469 0.3598132
#  0.35935787 0.35947843 0.36681313 0.37091291 0.39008156 0.3896525
#  0.3896525  0.38513836 0.3837374  0.39789185 0.37615637 0.37577808
#  0.27385809 0.24442829 0.25707857 0.25704232 0.28584791 0.37066416
#  0.37985501 0.381914   0.39838006 0.39404203 0.42915337 0.42463752
#  0.4332677  0.41393374 0.41393374 0.41393374 0.41074743 0.40382522
#  0.3861082  0.38604014 0.38604014 0.38564004 0.38145893 0.37386999
#  0.37412521 0.34953861 0.2745513  0.28287883 0.28486792 0.26130613
#  0.2825944  0.22227741 0.221519   0.19691724 0.19491338 0.19491338
#  0.19491338 0.19491338 0.19491338 0.19491338 0.19491338 0.19491338
#  0.19491338 0.25661425 0.2632118  0.28525152 0.29795617 0.28907066
#  0.26408304 0.26653972 0.26199483 0.25111167 0.25295996 0.25494367
#  0.26851436 0.3314586  0.34201998 0.3595593  0.37873867 0.38351912
#  0.40378091 0.40561023 0.51640791 0.54065305 0.56361222 0.58351225
#  0.60005468 0.61297375 0.62167758 0.62630999]
# 8 day output [[0.6270147]]
# 9 day input [0.31039831 0.3112404  0.31118524 0.31705856 0.32543292 0.33465096
#  0.35430742 0.35543628 0.3691446  0.36716645 0.36405664 0.3637269
#  0.36649095 0.37013318 0.35629444 0.35605469 0.3598132  0.35935787
#  0.35947843 0.36681313 0.37091291 0.39008156 0.3896525  0.3896525
#  0.38513836 0.3837374  0.39789185 0.37615637 0.37577808 0.27385809
#  0.24442829 0.25707857 0.25704232 0.28584791 0.37066416 0.37985501
#  0.381914   0.39838006 0.39404203 0.42915337 0.42463752 0.4332677
#  0.41393374 0.41393374 0.41393374 0.41074743 0.40382522 0.3861082
#  0.38604014 0.38604014 0.38564004 0.38145893 0.37386999 0.37412521
#  0.34953861 0.2745513  0.28287883 0.28486792 0.26130613 0.2825944
#  0.22227741 0.221519   0.19691724 0.19491338 0.19491338 0.19491338
#  0.19491338 0.19491338 0.19491338 0.19491338 0.19491338 0.19491338
#  0.25661425 0.2632118  0.28525152 0.29795617 0.28907066 0.26408304
#  0.26653972 0.26199483 0.25111167 0.25295996 0.25494367 0.26851436
#  0.3314586  0.34201998 0.3595593  0.37873867 0.38351912 0.40378091
#  0.40561023 0.51640791 0.54065305 0.56361222 0.58351225 0.60005468
#  0.61297375 0.62167758 0.62630999 0.6270147 ]
# 9 day output [[0.6240393]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,111)

# %%
plt.plot(day_new,scaler.inverse_transform(df[339:]),color ='blue', label ='origial')
plt.plot(day_pred,scaler.inverse_transform(lst_output),color='red', label='future')
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 10 Days Forecasting')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=df.tolist()
df3.extend(lst_output)
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 30 Days Forecasting')
plt.plot(df3[409:],color='red', label='future')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)

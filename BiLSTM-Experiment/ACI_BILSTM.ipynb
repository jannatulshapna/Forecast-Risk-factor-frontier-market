# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("/content/ACI.csv",parse_dates=['DATE'])
df.head()
# Out:
#      #       DATE TRADING CODE   LTP*  ...    YCP  TRADE  VALUE (mn)  VOLUME
# 0  439 2018-05-08          ACI  375.0  ...  361.8    453      13.478  36,659
# 1  438 2018-06-08          ACI  373.0  ...  370.6    759      25.894  69,069
# 2  437 2018-07-08          ACI  373.6  ...  373.8    368      11.013  29,387
# 3  436 2018-08-08          ACI  369.8  ...  373.0    359       9.561  25,798
# 4  435 2018-09-08          ACI  365.4  ...  369.1    461      15.324  41,913
#
# [5 rows x 12 columns]

# %%
# Sort DataFrame by date
df = df.sort_values('DATE')

# Double check the result
df.head()
# Out:
#       #       DATE TRADING CODE   LTP*  ...    YCP  TRADE  VALUE (mn)  VOLUME
# 36  403 2018-01-10          ACI  344.5  ...  340.0    270       6.432  18,549
# 59  380 2018-01-11          ACI  350.4  ...  349.6    328      10.607  30,276
# 37  402 2018-02-10          ACI  347.5  ...  345.3    199       3.682  10,600
# 79  360 2018-02-12          ACI  322.2  ...  325.2    294       5.220  16,130
# 16  423 2018-03-09          ACI  364.0  ...  366.5    437      13.092  35,969
#
# [5 rows x 12 columns]

# %%
df = df.set_index('DATE')
df.head(3)
# Out:
#               # TRADING CODE   LTP*   HIGH  ...    YCP  TRADE  VALUE (mn)  VOLUME
# DATE                                        ...
# 2018-01-10  403          ACI  344.5  352.8  ...  340.0    270       6.432  18,549
# 2018-01-11  380          ACI  350.4  351.6  ...  349.6    328      10.607  30,276
# 2018-02-10  402          ACI  347.5  349.0  ...  345.3    199       3.682  10,600
#
# [3 rows x 11 columns]

# %%
df['daily_ret'] = df['CLOSEP*'].pct_change()
df['daily_ret'] = df['daily_ret'].fillna(0.0)

# %%
df['volatility']= df['daily_ret'].rolling(window=21).std()
df['volatility'] = df['volatility'].fillna(0.0)

# %%
df['volatility'] = df['volatility']*100

# %%
import matplotlib.pyplot as plt

# %%
df=df.reset_index()['volatility']

# %%
plt.plot(df)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
df.shape
# Out:
# (439, 1)

# %%
##splitting dataset into train and test split where train=70 percent and test=30 percent
training_size=int(len(df)*0.70)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
training_size,test_size
# Out:
# (307, 132)

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [],[]
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (206, 100)
# (206,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import Bidirectional

# %%
model=Sequential()
model.add(Bidirectional(LSTM(50,return_sequences=True,input_shape=(100,1))))
model.add(Bidirectional(LSTM(50,return_sequences=True)))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-5f15418b3570> in <module>()
# ----> 1 model.summary()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in summary(self, line_length, positions, print_fn)
#    2374     """
#    2375     if not self.built:
# -> 2376       raise ValueError('This model has not yet been built. '
#    2377                        'Build the model first by calling `build()` or calling '
#    2378                        '`fit()` with some data, or specify '
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or calling `fit()` with some data, or specify an `input_shape` argument in the first layer(s) for automatic build.

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 13s 537ms/step - loss: 0.1089 - val_loss: 0.0527
# Epoch 2/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0204 - val_loss: 0.0151
# Epoch 3/100
# 7/7 [==============================] - 2s 231ms/step - loss: 0.0209 - val_loss: 0.0178
# Epoch 4/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0162 - val_loss: 0.0102
# Epoch 5/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0117 - val_loss: 0.0099
# Epoch 6/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0087 - val_loss: 0.0236
# Epoch 7/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0070 - val_loss: 0.0116
# Epoch 8/100
# 7/7 [==============================] - 2s 231ms/step - loss: 0.0074 - val_loss: 0.0264
# Epoch 9/100
# 7/7 [==============================] - 2s 229ms/step - loss: 0.0050 - val_loss: 0.0169
# Epoch 10/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0048 - val_loss: 0.0131
# Epoch 11/100
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0041 - val_loss: 0.0122
# Epoch 12/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0042 - val_loss: 0.0171
# Epoch 13/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0047 - val_loss: 0.0098
# Epoch 14/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0041 - val_loss: 0.0034
# Epoch 15/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0054 - val_loss: 0.0079
# Epoch 16/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0042 - val_loss: 0.0106
# Epoch 17/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 18/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0037 - val_loss: 0.0046
# Epoch 19/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0032 - val_loss: 0.0060
# Epoch 20/100
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 21/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0035 - val_loss: 0.0052
# Epoch 22/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0032 - val_loss: 0.0026
# Epoch 23/100
# 7/7 [==============================] - 2s 231ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 24/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0036 - val_loss: 0.0033
# Epoch 25/100
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0040 - val_loss: 0.0027
# Epoch 26/100
# 7/7 [==============================] - 2s 231ms/step - loss: 0.0041 - val_loss: 0.0065
# Epoch 27/100
# 7/7 [==============================] - 2s 229ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 28/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0030 - val_loss: 0.0035
# Epoch 29/100
# 7/7 [==============================] - 2s 229ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 30/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 31/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0035 - val_loss: 0.0054
# Epoch 32/100
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0040 - val_loss: 0.0032
# Epoch 33/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 34/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0037 - val_loss: 0.0080
# Epoch 35/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0034 - val_loss: 0.0045
# Epoch 36/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 37/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 38/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 39/100
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 40/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 41/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 42/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 43/100
# 7/7 [==============================] - 2s 247ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 44/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 45/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 46/100
# 7/7 [==============================] - 2s 231ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 47/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 48/100
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 49/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0027 - val_loss: 0.0021
# Epoch 50/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 51/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 52/100
# 7/7 [==============================] - 2s 232ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 53/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 54/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 55/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 56/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0021 - val_loss: 0.0076
# Epoch 57/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0029 - val_loss: 0.0051
# Epoch 58/100
# 7/7 [==============================] - 2s 231ms/step - loss: 0.0031 - val_loss: 0.0017
# Epoch 59/100
# 7/7 [==============================] - 2s 232ms/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 60/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 61/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0024 - val_loss: 0.0069
# Epoch 62/100
# 7/7 [==============================] - 2s 232ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 63/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 64/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 65/100
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 66/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 67/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0027 - val_loss: 0.0055
# Epoch 68/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0032 - val_loss: 0.0016
# Epoch 69/100
# 7/7 [==============================] - 2s 229ms/step - loss: 0.0030 - val_loss: 0.0018
# Epoch 70/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 71/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0025 - val_loss: 0.0038
# Epoch 72/100
# 7/7 [==============================] - 2s 232ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 73/100
# 7/7 [==============================] - 2s 226ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 74/100
# 7/7 [==============================] - 2s 232ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 75/100
# 7/7 [==============================] - 2s 229ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 76/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 77/100
# 7/7 [==============================] - 2s 225ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 78/100
# 7/7 [==============================] - 2s 229ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 79/100
# 7/7 [==============================] - 2s 231ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 80/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 81/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 82/100
# 7/7 [==============================] - 2s 229ms/step - loss: 0.0022 - val_loss: 0.0045
# Epoch 83/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 84/100
# 7/7 [==============================] - 2s 234ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 85/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 86/100
# 7/7 [==============================] - 2s 229ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 87/100
# 7/7 [==============================] - 2s 234ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 88/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 89/100
# 7/7 [==============================] - 2s 227ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 90/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0020 - val_loss: 0.0051
# Epoch 91/100
# 7/7 [==============================] - 2s 228ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 92/100
# 7/7 [==============================] - 2s 234ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 93/100
# 7/7 [==============================] - 2s 223ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 94/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 95/100
# 7/7 [==============================] - 2s 222ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 96/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 97/100
# 7/7 [==============================] - 2s 231ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 98/100
# 7/7 [==============================] - 2s 231ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 99/100
# 7/7 [==============================] - 2s 224ms/step - loss: 0.0015 - val_loss: 0.0052
# Epoch 100/100
# 7/7 [==============================] - 2s 230ms/step - loss: 0.0020 - val_loss: 0.0020

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath = "/content/drive/MyDrive/stock_price_BILSTM/modelsACI/model.h5"
model.save(filepath)

# %%
from keras.models import load_model
f1 = '/content/drive/MyDrive/stock_price_BILSTM/modelsACI/model.h5'
model = load_model(f1)

# %%
import tensorflow as tf
from sklearn.metrics import r2_score

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict = np.reshape(train_predict,(1, train_predict.size))
train_predict=scaler.inverse_transform(train_predict)
test_predict = np.reshape(test_predict,(1, test_predict.size))
test_predict=scaler.inverse_transform(test_predict)
X = np.reshape(ytest,(1, ytest.size))
Y_test =scaler.inverse_transform(X)

# %%
Y_test
# Out:
# array([[4.8415822 , 3.64903095, 3.54389713, 2.90619719, 2.77801506,
#         2.70505406, 2.7029941 , 2.70046665, 2.88658429, 3.00819794,
#         3.07924753, 3.15192822, 3.14391121, 6.32575965, 6.32147298,
#         6.44883925, 6.54867157, 6.5523816 , 6.49261228, 6.46785892,
#         6.9083622 , 7.14619919, 7.82042649, 7.82491791, 7.91390179,
#         7.97094707, 8.04322845, 8.06294477, 8.12044363, 8.01211293,
#         8.05218934]])

# %%
test_predict
# Out:
# array([[7.356669 , 7.0562863, 6.432394 , 5.8727727, 5.226958 , 4.667017 ,
#         4.201887 , 3.8405633, 3.5658648, 3.4183507, 3.3580818, 3.3561916,
#         3.348484 , 3.337243 , 4.2858605, 5.0671654, 5.709378 , 6.2161283,
#         6.5615673, 6.7523613, 6.823881 , 6.9603887, 7.100549 , 7.3812165,
#         7.5760417, 7.724289 , 7.8283896, 7.9064574, 7.952699 , 7.9935265,
#         8.001996 ]], dtype=float32)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
#Y_test = Y_test.transpose()
RMSE = math.sqrt(mean_squared_error(Y_test,test_predict))
RMSE
# Out:
# 0.22806403891126528

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(Y_test,test_predict)
print('MAE: %f' % mae)
# Out:
# MAE: 0.193185

# %%
train_predict.shape
# Out:
# (1, 206)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
test_predict = test_predict.transpose()

# %%
train_predict = train_predict.transpose()

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df),color ='blue', label ='original')
plt.plot(trainPredictPlot, color ='orange', label ='predicted')
plt.plot(testPredictPlot , color ='red', label ='tested')
#plt.show()
plt.xlabel('number of days')
plt.ylabel('volatility magnitude')
plt.title('ABBANk Risk Factor Prediction')
plt.legend(loc='best')
plt.show(block=False)

# %%
x_input=test_data[32:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<10):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

#print(lst_output)
# Out:
# [0.48175797]
# 101
# 1 day input [0.40347607 0.40676387 0.40463047 0.38739803 0.27421549 0.28337759
#  0.2833259  0.28286761 0.28310761 0.28264977 0.30068437 0.31316072
#  0.32948386 0.32899958 0.35512618 0.35708615 0.37557857 0.34493845
#  0.29573309 0.29407283 0.29733074 0.29695707 0.29339656 0.29531466
#  0.29484175 0.29491749 0.28571011 0.29443713 0.29711445 0.31799932
#  0.46690862 0.58429257 0.57917951 0.57298744 0.5814854  0.56842312
#  0.57262542 0.56395035 0.5514931  0.56594669 0.56663393 0.57056145
#  0.57041684 0.57510459 0.57369617 0.5781223  0.59676788 0.62695655
#  0.62323902 0.63349573 0.62747912 0.51794705 0.37955403 0.37665634
#  0.37363478 0.36163028 0.35700648 0.34773668 0.34249096 0.34173258
#  0.3162313  0.31596909 0.30805393 0.32992379 0.32621335 0.32904206
#  0.32417619 0.28367114 0.21379886 0.20763901 0.1702758  0.16276553
#  0.1584907  0.15837001 0.15822192 0.16912667 0.17625208 0.18041492
#  0.18467332 0.1842036  0.37062997 0.37037881 0.37784127 0.38369051
#  0.38390788 0.38040596 0.37895565 0.40476499 0.4187     0.45820337
#  0.45846653 0.46368015 0.46702246 0.47125747 0.47241266 0.47578156
#  0.4694344  0.4717825  0.50034533 0.48175797]
# 1 day output [[0.4864913]]
# 2 day input [0.40676387 0.40463047 0.38739803 0.27421549 0.28337759 0.2833259
#  0.28286761 0.28310761 0.28264977 0.30068437 0.31316072 0.32948386
#  0.32899958 0.35512618 0.35708615 0.37557857 0.34493845 0.29573309
#  0.29407283 0.29733074 0.29695707 0.29339656 0.29531466 0.29484175
#  0.29491749 0.28571011 0.29443713 0.29711445 0.31799932 0.46690862
#  0.58429257 0.57917951 0.57298744 0.5814854  0.56842312 0.57262542
#  0.56395035 0.5514931  0.56594669 0.56663393 0.57056145 0.57041684
#  0.57510459 0.57369617 0.5781223  0.59676788 0.62695655 0.62323902
#  0.63349573 0.62747912 0.51794705 0.37955403 0.37665634 0.37363478
#  0.36163028 0.35700648 0.34773668 0.34249096 0.34173258 0.3162313
#  0.31596909 0.30805393 0.32992379 0.32621335 0.32904206 0.32417619
#  0.28367114 0.21379886 0.20763901 0.1702758  0.16276553 0.1584907
#  0.15837001 0.15822192 0.16912667 0.17625208 0.18041492 0.18467332
#  0.1842036  0.37062997 0.37037881 0.37784127 0.38369051 0.38390788
#  0.38040596 0.37895565 0.40476499 0.4187     0.45820337 0.45846653
#  0.46368015 0.46702246 0.47125747 0.47241266 0.47578156 0.4694344
#  0.4717825  0.50034533 0.48175797 0.48649129]
# 2 day output [[0.49271953]]
# 3 day input [0.40463047 0.38739803 0.27421549 0.28337759 0.2833259  0.28286761
#  0.28310761 0.28264977 0.30068437 0.31316072 0.32948386 0.32899958
#  0.35512618 0.35708615 0.37557857 0.34493845 0.29573309 0.29407283
#  0.29733074 0.29695707 0.29339656 0.29531466 0.29484175 0.29491749
#  0.28571011 0.29443713 0.29711445 0.31799932 0.46690862 0.58429257
#  0.57917951 0.57298744 0.5814854  0.56842312 0.57262542 0.56395035
#  0.5514931  0.56594669 0.56663393 0.57056145 0.57041684 0.57510459
#  0.57369617 0.5781223  0.59676788 0.62695655 0.62323902 0.63349573
#  0.62747912 0.51794705 0.37955403 0.37665634 0.37363478 0.36163028
#  0.35700648 0.34773668 0.34249096 0.34173258 0.3162313  0.31596909
#  0.30805393 0.32992379 0.32621335 0.32904206 0.32417619 0.28367114
#  0.21379886 0.20763901 0.1702758  0.16276553 0.1584907  0.15837001
#  0.15822192 0.16912667 0.17625208 0.18041492 0.18467332 0.1842036
#  0.37062997 0.37037881 0.37784127 0.38369051 0.38390788 0.38040596
#  0.37895565 0.40476499 0.4187     0.45820337 0.45846653 0.46368015
#  0.46702246 0.47125747 0.47241266 0.47578156 0.4694344  0.4717825
#  0.50034533 0.48175797 0.48649129 0.49271953]
# 3 day output [[0.5012204]]
# 4 day input [0.38739803 0.27421549 0.28337759 0.2833259  0.28286761 0.28310761
#  0.28264977 0.30068437 0.31316072 0.32948386 0.32899958 0.35512618
#  0.35708615 0.37557857 0.34493845 0.29573309 0.29407283 0.29733074
#  0.29695707 0.29339656 0.29531466 0.29484175 0.29491749 0.28571011
#  0.29443713 0.29711445 0.31799932 0.46690862 0.58429257 0.57917951
#  0.57298744 0.5814854  0.56842312 0.57262542 0.56395035 0.5514931
#  0.56594669 0.56663393 0.57056145 0.57041684 0.57510459 0.57369617
#  0.5781223  0.59676788 0.62695655 0.62323902 0.63349573 0.62747912
#  0.51794705 0.37955403 0.37665634 0.37363478 0.36163028 0.35700648
#  0.34773668 0.34249096 0.34173258 0.3162313  0.31596909 0.30805393
#  0.32992379 0.32621335 0.32904206 0.32417619 0.28367114 0.21379886
#  0.20763901 0.1702758  0.16276553 0.1584907  0.15837001 0.15822192
#  0.16912667 0.17625208 0.18041492 0.18467332 0.1842036  0.37062997
#  0.37037881 0.37784127 0.38369051 0.38390788 0.38040596 0.37895565
#  0.40476499 0.4187     0.45820337 0.45846653 0.46368015 0.46702246
#  0.47125747 0.47241266 0.47578156 0.4694344  0.4717825  0.50034533
#  0.48175797 0.48649129 0.49271953 0.50122041]
# 4 day output [[0.5123763]]
# 5 day input [0.27421549 0.28337759 0.2833259  0.28286761 0.28310761 0.28264977
#  0.30068437 0.31316072 0.32948386 0.32899958 0.35512618 0.35708615
#  0.37557857 0.34493845 0.29573309 0.29407283 0.29733074 0.29695707
#  0.29339656 0.29531466 0.29484175 0.29491749 0.28571011 0.29443713
#  0.29711445 0.31799932 0.46690862 0.58429257 0.57917951 0.57298744
#  0.5814854  0.56842312 0.57262542 0.56395035 0.5514931  0.56594669
#  0.56663393 0.57056145 0.57041684 0.57510459 0.57369617 0.5781223
#  0.59676788 0.62695655 0.62323902 0.63349573 0.62747912 0.51794705
#  0.37955403 0.37665634 0.37363478 0.36163028 0.35700648 0.34773668
#  0.34249096 0.34173258 0.3162313  0.31596909 0.30805393 0.32992379
#  0.32621335 0.32904206 0.32417619 0.28367114 0.21379886 0.20763901
#  0.1702758  0.16276553 0.1584907  0.15837001 0.15822192 0.16912667
#  0.17625208 0.18041492 0.18467332 0.1842036  0.37062997 0.37037881
#  0.37784127 0.38369051 0.38390788 0.38040596 0.37895565 0.40476499
#  0.4187     0.45820337 0.45846653 0.46368015 0.46702246 0.47125747
#  0.47241266 0.47578156 0.4694344  0.4717825  0.50034533 0.48175797
#  0.48649129 0.49271953 0.50122041 0.51237631]
# 5 day output [[0.5262643]]
# 6 day input [0.28337759 0.2833259  0.28286761 0.28310761 0.28264977 0.30068437
#  0.31316072 0.32948386 0.32899958 0.35512618 0.35708615 0.37557857
#  0.34493845 0.29573309 0.29407283 0.29733074 0.29695707 0.29339656
#  0.29531466 0.29484175 0.29491749 0.28571011 0.29443713 0.29711445
#  0.31799932 0.46690862 0.58429257 0.57917951 0.57298744 0.5814854
#  0.56842312 0.57262542 0.56395035 0.5514931  0.56594669 0.56663393
#  0.57056145 0.57041684 0.57510459 0.57369617 0.5781223  0.59676788
#  0.62695655 0.62323902 0.63349573 0.62747912 0.51794705 0.37955403
#  0.37665634 0.37363478 0.36163028 0.35700648 0.34773668 0.34249096
#  0.34173258 0.3162313  0.31596909 0.30805393 0.32992379 0.32621335
#  0.32904206 0.32417619 0.28367114 0.21379886 0.20763901 0.1702758
#  0.16276553 0.1584907  0.15837001 0.15822192 0.16912667 0.17625208
#  0.18041492 0.18467332 0.1842036  0.37062997 0.37037881 0.37784127
#  0.38369051 0.38390788 0.38040596 0.37895565 0.40476499 0.4187
#  0.45820337 0.45846653 0.46368015 0.46702246 0.47125747 0.47241266
#  0.47578156 0.4694344  0.4717825  0.50034533 0.48175797 0.48649129
#  0.49271953 0.50122041 0.51237631 0.52626431]
# 6 day output [[0.5417087]]
# 7 day input [0.2833259  0.28286761 0.28310761 0.28264977 0.30068437 0.31316072
#  0.32948386 0.32899958 0.35512618 0.35708615 0.37557857 0.34493845
#  0.29573309 0.29407283 0.29733074 0.29695707 0.29339656 0.29531466
#  0.29484175 0.29491749 0.28571011 0.29443713 0.29711445 0.31799932
#  0.46690862 0.58429257 0.57917951 0.57298744 0.5814854  0.56842312
#  0.57262542 0.56395035 0.5514931  0.56594669 0.56663393 0.57056145
#  0.57041684 0.57510459 0.57369617 0.5781223  0.59676788 0.62695655
#  0.62323902 0.63349573 0.62747912 0.51794705 0.37955403 0.37665634
#  0.37363478 0.36163028 0.35700648 0.34773668 0.34249096 0.34173258
#  0.3162313  0.31596909 0.30805393 0.32992379 0.32621335 0.32904206
#  0.32417619 0.28367114 0.21379886 0.20763901 0.1702758  0.16276553
#  0.1584907  0.15837001 0.15822192 0.16912667 0.17625208 0.18041492
#  0.18467332 0.1842036  0.37062997 0.37037881 0.37784127 0.38369051
#  0.38390788 0.38040596 0.37895565 0.40476499 0.4187     0.45820337
#  0.45846653 0.46368015 0.46702246 0.47125747 0.47241266 0.47578156
#  0.4694344  0.4717825  0.50034533 0.48175797 0.48649129 0.49271953
#  0.50122041 0.51237631 0.52626431 0.54170871]
# 7 day output [[0.5593193]]
# 8 day input [0.28286761 0.28310761 0.28264977 0.30068437 0.31316072 0.32948386
#  0.32899958 0.35512618 0.35708615 0.37557857 0.34493845 0.29573309
#  0.29407283 0.29733074 0.29695707 0.29339656 0.29531466 0.29484175
#  0.29491749 0.28571011 0.29443713 0.29711445 0.31799932 0.46690862
#  0.58429257 0.57917951 0.57298744 0.5814854  0.56842312 0.57262542
#  0.56395035 0.5514931  0.56594669 0.56663393 0.57056145 0.57041684
#  0.57510459 0.57369617 0.5781223  0.59676788 0.62695655 0.62323902
#  0.63349573 0.62747912 0.51794705 0.37955403 0.37665634 0.37363478
#  0.36163028 0.35700648 0.34773668 0.34249096 0.34173258 0.3162313
#  0.31596909 0.30805393 0.32992379 0.32621335 0.32904206 0.32417619
#  0.28367114 0.21379886 0.20763901 0.1702758  0.16276553 0.1584907
#  0.15837001 0.15822192 0.16912667 0.17625208 0.18041492 0.18467332
#  0.1842036  0.37062997 0.37037881 0.37784127 0.38369051 0.38390788
#  0.38040596 0.37895565 0.40476499 0.4187     0.45820337 0.45846653
#  0.46368015 0.46702246 0.47125747 0.47241266 0.47578156 0.4694344
#  0.4717825  0.50034533 0.48175797 0.48649129 0.49271953 0.50122041
#  0.51237631 0.52626431 0.54170871 0.55931932]
# 8 day output [[0.5787098]]
# 9 day input [0.28310761 0.28264977 0.30068437 0.31316072 0.32948386 0.32899958
#  0.35512618 0.35708615 0.37557857 0.34493845 0.29573309 0.29407283
#  0.29733074 0.29695707 0.29339656 0.29531466 0.29484175 0.29491749
#  0.28571011 0.29443713 0.29711445 0.31799932 0.46690862 0.58429257
#  0.57917951 0.57298744 0.5814854  0.56842312 0.57262542 0.56395035
#  0.5514931  0.56594669 0.56663393 0.57056145 0.57041684 0.57510459
#  0.57369617 0.5781223  0.59676788 0.62695655 0.62323902 0.63349573
#  0.62747912 0.51794705 0.37955403 0.37665634 0.37363478 0.36163028
#  0.35700648 0.34773668 0.34249096 0.34173258 0.3162313  0.31596909
#  0.30805393 0.32992379 0.32621335 0.32904206 0.32417619 0.28367114
#  0.21379886 0.20763901 0.1702758  0.16276553 0.1584907  0.15837001
#  0.15822192 0.16912667 0.17625208 0.18041492 0.18467332 0.1842036
#  0.37062997 0.37037881 0.37784127 0.38369051 0.38390788 0.38040596
#  0.37895565 0.40476499 0.4187     0.45820337 0.45846653 0.46368015
#  0.46702246 0.47125747 0.47241266 0.47578156 0.4694344  0.4717825
#  0.50034533 0.48175797 0.48649129 0.49271953 0.50122041 0.51237631
#  0.52626431 0.54170871 0.55931932 0.57870978]
# 9 day output [[0.5994057]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,111)

# %%
plt.plot(day_new,scaler.inverse_transform(df[339:]),color ='blue', label ='origial')
plt.plot(day_pred,scaler.inverse_transform(lst_output),color='red', label='future')
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 10 Days Forecasting')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=df.tolist()
df3.extend(lst_output)
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 30 Days Forecasting')
plt.plot(df3[409:],color='red', label='future')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("/content/APEXFOOT.csv",parse_dates=['DATE'])
df.head()
# Out:
#      #       DATE TRADING CODE   LTP*  ...    YCP  TRADE  VALUE (mn)  VOLUME
# 0  439 2018-05-08     APEXFOOT  331.7  ...  341.2    143       5.122  15,334
# 1  438 2018-06-08     APEXFOOT  331.2  ...  332.7     94       3.217   9,626
# 2  437 2018-07-08     APEXFOOT  327.1  ...  331.8    123       3.645  11,049
# 3  436 2018-08-08     APEXFOOT  325.1  ...  327.7    118       6.380  19,344
# 4  435 2018-09-08     APEXFOOT  322.0  ...  328.4    165       7.030  21,712
#
# [5 rows x 12 columns]

# %%
# Sort DataFrame by date
df = df.sort_values('DATE')

# Double check the result
df.head()
# Out:
#       #       DATE TRADING CODE   LTP*  ...    YCP  TRADE  VALUE (mn)  VOLUME
# 36  403 2018-01-10     APEXFOOT  296.5  ...  298.9    139       2.509   8,392
# 59  380 2018-01-11     APEXFOOT  269.9  ...  270.7     72       1.005   3,724
# 37  402 2018-02-10     APEXFOOT  294.4  ...  297.9    237       5.574  18,816
# 79  360 2018-02-12     APEXFOOT  273.0  ...  273.9    107       2.479   9,064
# 16  423 2018-03-09     APEXFOOT  319.7  ...  309.5    224       8.640  26,931
#
# [5 rows x 12 columns]

# %%
df = df.set_index('DATE')
df.head(3)
# Out:
#               # TRADING CODE   LTP*   HIGH  ...    YCP  TRADE  VALUE (mn)  VOLUME
# DATE                                        ...
# 2018-01-10  403     APEXFOOT  296.5  300.1  ...  298.9    139       2.509   8,392
# 2018-01-11  380     APEXFOOT  269.9  273.0  ...  270.7     72       1.005   3,724
# 2018-02-10  402     APEXFOOT  294.4  297.9  ...  297.9    237       5.574  18,816
#
# [3 rows x 11 columns]

# %%
df['daily_ret'] = df['CLOSEP*'].pct_change()
df['daily_ret'] = df['daily_ret'].fillna(0.0)

# %%
df['volatility']= df['daily_ret'].rolling(window=21).std()
df['volatility'] = df['volatility'].fillna(0.0)

# %%
df['volatility'] = df['volatility']*100

# %%
import matplotlib.pyplot as plt

# %%
df=df.reset_index()['volatility']

# %%
plt.plot(df)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
df.shape
# Out:
# (439, 1)

# %%
##splitting dataset into train and test split where train=70 percent and test=30 percent
training_size=int(len(df)*0.70)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
training_size,test_size
# Out:
# (307, 132)

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [],[]
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (206, 100)
# (206,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import Bidirectional

# %%
model=Sequential()
model.add(Bidirectional(LSTM(50,return_sequences=True,input_shape=(100,1))))
model.add(Bidirectional(LSTM(50,return_sequences=True)))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 17s 747ms/step - loss: 0.2114 - val_loss: 0.1554
# Epoch 2/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0245 - val_loss: 0.0487
# Epoch 3/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0199 - val_loss: 0.1155
# Epoch 4/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0185 - val_loss: 0.0656
# Epoch 5/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0122 - val_loss: 0.0695
# Epoch 6/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0103 - val_loss: 0.0689
# Epoch 7/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0096 - val_loss: 0.0560
# Epoch 8/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0092 - val_loss: 0.0550
# Epoch 9/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0090 - val_loss: 0.0441
# Epoch 10/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0079 - val_loss: 0.0397
# Epoch 11/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0076 - val_loss: 0.0337
# Epoch 12/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0076 - val_loss: 0.0289
# Epoch 13/100
# 7/7 [==============================] - 2s 263ms/step - loss: 0.0066 - val_loss: 0.0324
# Epoch 14/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0061 - val_loss: 0.0263
# Epoch 15/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0061 - val_loss: 0.0301
# Epoch 16/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0067 - val_loss: 0.0305
# Epoch 17/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0066 - val_loss: 0.0267
# Epoch 18/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0053 - val_loss: 0.0276
# Epoch 19/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0061 - val_loss: 0.0233
# Epoch 20/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0065 - val_loss: 0.0240
# Epoch 21/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0064 - val_loss: 0.0303
# Epoch 22/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0072 - val_loss: 0.0275
# Epoch 23/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0059 - val_loss: 0.0194
# Epoch 24/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0057 - val_loss: 0.0238
# Epoch 25/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0053 - val_loss: 0.0264
# Epoch 26/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0056 - val_loss: 0.0205
# Epoch 27/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0057 - val_loss: 0.0218
# Epoch 28/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0062 - val_loss: 0.0219
# Epoch 29/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0056 - val_loss: 0.0252
# Epoch 30/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0059 - val_loss: 0.0217
# Epoch 31/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0058 - val_loss: 0.0202
# Epoch 32/100
# 7/7 [==============================] - 2s 250ms/step - loss: 0.0059 - val_loss: 0.0270
# Epoch 33/100
# 7/7 [==============================] - 2s 247ms/step - loss: 0.0047 - val_loss: 0.0372
# Epoch 34/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0079 - val_loss: 0.0287
# Epoch 35/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0065 - val_loss: 0.0224
# Epoch 36/100
# 7/7 [==============================] - 2s 295ms/step - loss: 0.0056 - val_loss: 0.0188
# Epoch 37/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0050 - val_loss: 0.0192
# Epoch 38/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0058 - val_loss: 0.0237
# Epoch 39/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0048 - val_loss: 0.0287
# Epoch 40/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0045 - val_loss: 0.0276
# Epoch 41/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0046 - val_loss: 0.0251
# Epoch 42/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0049 - val_loss: 0.0216
# Epoch 43/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0051 - val_loss: 0.0193
# Epoch 44/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0059 - val_loss: 0.0253
# Epoch 45/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0064 - val_loss: 0.0304
# Epoch 46/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0046 - val_loss: 0.0271
# Epoch 47/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0048 - val_loss: 0.0325
# Epoch 48/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0061 - val_loss: 0.0235
# Epoch 49/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0052 - val_loss: 0.0203
# Epoch 50/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0053 - val_loss: 0.0210
# Epoch 51/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0059 - val_loss: 0.0335
# Epoch 52/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0051 - val_loss: 0.0292
# Epoch 53/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0044 - val_loss: 0.0226
# Epoch 54/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0047 - val_loss: 0.0225
# Epoch 55/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0053 - val_loss: 0.0249
# Epoch 56/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0050 - val_loss: 0.0267
# Epoch 57/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0045 - val_loss: 0.0253
# Epoch 58/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0044 - val_loss: 0.0205
# Epoch 59/100
# 7/7 [==============================] - 2s 250ms/step - loss: 0.0058 - val_loss: 0.0250
# Epoch 60/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0049 - val_loss: 0.0232
# Epoch 61/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0052 - val_loss: 0.0274
# Epoch 62/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0054 - val_loss: 0.0280
# Epoch 63/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0044 - val_loss: 0.0209
# Epoch 64/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0048 - val_loss: 0.0198
# Epoch 65/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0052 - val_loss: 0.0286
# Epoch 66/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0063 - val_loss: 0.0277
# Epoch 67/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0044 - val_loss: 0.0218
# Epoch 68/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0051 - val_loss: 0.0212
# Epoch 69/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0048 - val_loss: 0.0253
# Epoch 70/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0060 - val_loss: 0.0290
# Epoch 71/100
# 7/7 [==============================] - 2s 286ms/step - loss: 0.0040 - val_loss: 0.0265
# Epoch 72/100
# 7/7 [==============================] - 2s 306ms/step - loss: 0.0045 - val_loss: 0.0257
# Epoch 73/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0038 - val_loss: 0.0220
# Epoch 74/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0040 - val_loss: 0.0230
# Epoch 75/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0050 - val_loss: 0.0271
# Epoch 76/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0060 - val_loss: 0.0274
# Epoch 77/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0055 - val_loss: 0.0254
# Epoch 78/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0062 - val_loss: 0.0161
# Epoch 79/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0047 - val_loss: 0.0144
# Epoch 80/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0036 - val_loss: 0.0107
# Epoch 81/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0048 - val_loss: 0.0130
# Epoch 82/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0040 - val_loss: 0.0134
# Epoch 83/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0049 - val_loss: 0.0116
# Epoch 84/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0041 - val_loss: 0.0148
# Epoch 85/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0039 - val_loss: 0.0129
# Epoch 86/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0046 - val_loss: 0.0146
# Epoch 87/100
# 7/7 [==============================] - 2s 250ms/step - loss: 0.0036 - val_loss: 0.0160
# Epoch 88/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0032 - val_loss: 0.0141
# Epoch 89/100
# 7/7 [==============================] - 2s 261ms/step - loss: 0.0042 - val_loss: 0.0178
# Epoch 90/100
# 7/7 [==============================] - 2s 260ms/step - loss: 0.0036 - val_loss: 0.0178
# Epoch 91/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0037 - val_loss: 0.0161
# Epoch 92/100
# 7/7 [==============================] - 2s 254ms/step - loss: 0.0034 - val_loss: 0.0136
# Epoch 93/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0040 - val_loss: 0.0124
# Epoch 94/100
# 7/7 [==============================] - 2s 257ms/step - loss: 0.0057 - val_loss: 0.0159
# Epoch 95/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0042 - val_loss: 0.0152
# Epoch 96/100
# 7/7 [==============================] - 2s 259ms/step - loss: 0.0047 - val_loss: 0.0091
# Epoch 97/100
# 7/7 [==============================] - 2s 264ms/step - loss: 0.0055 - val_loss: 0.0088
# Epoch 98/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0044 - val_loss: 0.0120
# Epoch 99/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0035 - val_loss: 0.0104
# Epoch 100/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0037 - val_loss: 0.0108

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath = "/content/drive/MyDrive/stock_price_BILSTM/modelsAPEXFOOT/model.h5"
model.save(filepath)

# %%
from keras.models import load_model
f1 = '/content/drive/MyDrive/stock_price_BILSTM/modelsAPEXFOOT/model.h5'
model = load_model(f1)

# %%
import tensorflow as tf
from sklearn.metrics import r2_score

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict = np.reshape(train_predict,(1, train_predict.size))
train_predict=scaler.inverse_transform(train_predict)
test_predict = np.reshape(test_predict,(1, test_predict.size))
test_predict=scaler.inverse_transform(test_predict)
X = np.reshape(ytest,(1, ytest.size))
Y_test =scaler.inverse_transform(X)

# %%
Y_test
# Out:
# array([[2.39999932, 2.39133286, 1.70376606, 0.14387177, 0.14387177,
#         0.14387177, 0.14387177, 0.14387177, 0.14387177, 0.14387177,
#         0.14387177, 0.14387177, 0.14387177, 0.15983648, 1.11889194,
#         1.62668515, 1.62668515, 1.62509398, 2.25079261, 2.69872078,
#         2.70246724, 2.70246724, 3.07388197, 3.20771914, 3.26346145,
#         3.62172975, 3.76110493, 3.81095094, 3.81163522, 4.0595256 ,
#         4.15521911]])

# %%
test_predict
# Out:
# array([[4.514478 , 4.4360485, 4.3851566, 4.218935 , 3.776078 , 3.409498 ,
#         3.118124 , 2.8955147, 2.732253 , 2.6180983, 2.5420394, 2.4896786,
#         2.4644163, 2.4528186, 2.4522774, 2.6409945, 2.9099505, 3.1439323,
#         3.3372617, 3.6108851, 3.919652 , 4.1631107, 4.3400764, 4.5340753,
#         4.697292 , 4.8198133, 4.9748054, 5.1191072, 5.2387385, 5.328412 ,
#         5.4448943]], dtype=float32)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
#Y_test = Y_test.transpose()
RMSE = math.sqrt(mean_squared_error(Y_test,test_predict))
RMSE
# Out:
# 1.335709758790552

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(Y_test,test_predict)
print('MAE: %f' % mae)
# Out:
# MAE: 1.058420

# %%
train_predict.shape
# Out:
# (1, 206)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
test_predict = test_predict.transpose()

# %%
train_predict = train_predict.transpose()

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df),color ='blue', label ='original')
plt.plot(trainPredictPlot, color ='orange', label ='predicted')
plt.plot(testPredictPlot , color ='red', label ='tested')
#plt.show()
plt.xlabel('number of days')
plt.ylabel('volatility magnitude')
plt.title('ABBANk Risk Factor Prediction')
plt.legend(loc='best')
plt.show(block=False)

# %%
x_input=test_data[32:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<10):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

#print(lst_output)
# Out:
# [0.44237304]
# 101
# 1 day input [0.32263292 0.30367284 0.2849645  0.13997536 0.12115192 0.12805407
#  0.12831157 0.12871967 0.13247169 0.15064282 0.15858914 0.18794618
#  0.20505352 0.20470837 0.25546745 0.25546091 0.28237207 0.26862035
#  0.27062176 0.27217356 0.27593569 0.27949973 0.28416343 0.2868073
#  0.29070917 0.29129565 0.28889592 0.29661906 0.29996952 0.31914422
#  0.306873   0.30433094 0.28954393 0.27959954 0.31680574 0.28728705
#  0.2892624  0.25742934 0.25634669 0.26353915 0.2652765  0.27961082
#  0.28066932 0.29022858 0.28991563 0.30260387 0.30264388 0.30339024
#  0.32293117 0.34670194 0.32809055 0.3276599  0.32756686 0.32723741
#  0.32216762 0.2871018  0.27941307 0.27714358 0.27528254 0.27526547
#  0.26494889 0.2617989  0.2373987  0.23541548 0.21182412 0.21076443
#  0.18708407 0.18707429 0.18639876 0.13280455 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01245888 0.08721499 0.12679627 0.12679627
#  0.12667225 0.17544398 0.21035892 0.21065095 0.21065095 0.23960185
#  0.25003415 0.25437913 0.2823053  0.29316926 0.29705464 0.29710798
#  0.31643045 0.32388954 0.32828197 0.44237304]
# 1 day output [[0.473696]]
# 2 day input [0.30367284 0.2849645  0.13997536 0.12115192 0.12805407 0.12831157
#  0.12871967 0.13247169 0.15064282 0.15858914 0.18794618 0.20505352
#  0.20470837 0.25546745 0.25546091 0.28237207 0.26862035 0.27062176
#  0.27217356 0.27593569 0.27949973 0.28416343 0.2868073  0.29070917
#  0.29129565 0.28889592 0.29661906 0.29996952 0.31914422 0.306873
#  0.30433094 0.28954393 0.27959954 0.31680574 0.28728705 0.2892624
#  0.25742934 0.25634669 0.26353915 0.2652765  0.27961082 0.28066932
#  0.29022858 0.28991563 0.30260387 0.30264388 0.30339024 0.32293117
#  0.34670194 0.32809055 0.3276599  0.32756686 0.32723741 0.32216762
#  0.2871018  0.27941307 0.27714358 0.27528254 0.27526547 0.26494889
#  0.2617989  0.2373987  0.23541548 0.21182412 0.21076443 0.18708407
#  0.18707429 0.18639876 0.13280455 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01245888 0.08721499 0.12679627 0.12679627 0.12667225
#  0.17544398 0.21035892 0.21065095 0.21065095 0.23960185 0.25003415
#  0.25437913 0.2823053  0.29316926 0.29705464 0.29710798 0.31643045
#  0.32388954 0.32828197 0.44237304 0.47369599]
# 2 day output [[0.506091]]
# 3 day input [0.2849645  0.13997536 0.12115192 0.12805407 0.12831157 0.12871967
#  0.13247169 0.15064282 0.15858914 0.18794618 0.20505352 0.20470837
#  0.25546745 0.25546091 0.28237207 0.26862035 0.27062176 0.27217356
#  0.27593569 0.27949973 0.28416343 0.2868073  0.29070917 0.29129565
#  0.28889592 0.29661906 0.29996952 0.31914422 0.306873   0.30433094
#  0.28954393 0.27959954 0.31680574 0.28728705 0.2892624  0.25742934
#  0.25634669 0.26353915 0.2652765  0.27961082 0.28066932 0.29022858
#  0.28991563 0.30260387 0.30264388 0.30339024 0.32293117 0.34670194
#  0.32809055 0.3276599  0.32756686 0.32723741 0.32216762 0.2871018
#  0.27941307 0.27714358 0.27528254 0.27526547 0.26494889 0.2617989
#  0.2373987  0.23541548 0.21182412 0.21076443 0.18708407 0.18707429
#  0.18639876 0.13280455 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01245888 0.08721499 0.12679627 0.12679627 0.12667225 0.17544398
#  0.21035892 0.21065095 0.21065095 0.23960185 0.25003415 0.25437913
#  0.2823053  0.29316926 0.29705464 0.29710798 0.31643045 0.32388954
#  0.32828197 0.44237304 0.47369599 0.506091  ]
# 3 day output [[0.5385394]]
# 4 day input [0.13997536 0.12115192 0.12805407 0.12831157 0.12871967 0.13247169
#  0.15064282 0.15858914 0.18794618 0.20505352 0.20470837 0.25546745
#  0.25546091 0.28237207 0.26862035 0.27062176 0.27217356 0.27593569
#  0.27949973 0.28416343 0.2868073  0.29070917 0.29129565 0.28889592
#  0.29661906 0.29996952 0.31914422 0.306873   0.30433094 0.28954393
#  0.27959954 0.31680574 0.28728705 0.2892624  0.25742934 0.25634669
#  0.26353915 0.2652765  0.27961082 0.28066932 0.29022858 0.28991563
#  0.30260387 0.30264388 0.30339024 0.32293117 0.34670194 0.32809055
#  0.3276599  0.32756686 0.32723741 0.32216762 0.2871018  0.27941307
#  0.27714358 0.27528254 0.27526547 0.26494889 0.2617989  0.2373987
#  0.23541548 0.21182412 0.21076443 0.18708407 0.18707429 0.18639876
#  0.13280455 0.01121447 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01121447 0.01121447 0.01121447 0.01245888
#  0.08721499 0.12679627 0.12679627 0.12667225 0.17544398 0.21035892
#  0.21065095 0.21065095 0.23960185 0.25003415 0.25437913 0.2823053
#  0.29316926 0.29705464 0.29710798 0.31643045 0.32388954 0.32828197
#  0.44237304 0.47369599 0.506091   0.53853941]
# 4 day output [[0.57008576]]
# 5 day input [0.12115192 0.12805407 0.12831157 0.12871967 0.13247169 0.15064282
#  0.15858914 0.18794618 0.20505352 0.20470837 0.25546745 0.25546091
#  0.28237207 0.26862035 0.27062176 0.27217356 0.27593569 0.27949973
#  0.28416343 0.2868073  0.29070917 0.29129565 0.28889592 0.29661906
#  0.29996952 0.31914422 0.306873   0.30433094 0.28954393 0.27959954
#  0.31680574 0.28728705 0.2892624  0.25742934 0.25634669 0.26353915
#  0.2652765  0.27961082 0.28066932 0.29022858 0.28991563 0.30260387
#  0.30264388 0.30339024 0.32293117 0.34670194 0.32809055 0.3276599
#  0.32756686 0.32723741 0.32216762 0.2871018  0.27941307 0.27714358
#  0.27528254 0.27526547 0.26494889 0.2617989  0.2373987  0.23541548
#  0.21182412 0.21076443 0.18708407 0.18707429 0.18639876 0.13280455
#  0.01121447 0.01121447 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01121447 0.01121447 0.01245888 0.08721499
#  0.12679627 0.12679627 0.12667225 0.17544398 0.21035892 0.21065095
#  0.21065095 0.23960185 0.25003415 0.25437913 0.2823053  0.29316926
#  0.29705464 0.29710798 0.31643045 0.32388954 0.32828197 0.44237304
#  0.47369599 0.506091   0.53853941 0.57008576]
# 5 day output [[0.6009054]]
# 6 day input [0.12805407 0.12831157 0.12871967 0.13247169 0.15064282 0.15858914
#  0.18794618 0.20505352 0.20470837 0.25546745 0.25546091 0.28237207
#  0.26862035 0.27062176 0.27217356 0.27593569 0.27949973 0.28416343
#  0.2868073  0.29070917 0.29129565 0.28889592 0.29661906 0.29996952
#  0.31914422 0.306873   0.30433094 0.28954393 0.27959954 0.31680574
#  0.28728705 0.2892624  0.25742934 0.25634669 0.26353915 0.2652765
#  0.27961082 0.28066932 0.29022858 0.28991563 0.30260387 0.30264388
#  0.30339024 0.32293117 0.34670194 0.32809055 0.3276599  0.32756686
#  0.32723741 0.32216762 0.2871018  0.27941307 0.27714358 0.27528254
#  0.27526547 0.26494889 0.2617989  0.2373987  0.23541548 0.21182412
#  0.21076443 0.18708407 0.18707429 0.18639876 0.13280455 0.01121447
#  0.01121447 0.01121447 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01121447 0.01245888 0.08721499 0.12679627
#  0.12679627 0.12667225 0.17544398 0.21035892 0.21065095 0.21065095
#  0.23960185 0.25003415 0.25437913 0.2823053  0.29316926 0.29705464
#  0.29710798 0.31643045 0.32388954 0.32828197 0.44237304 0.47369599
#  0.506091   0.53853941 0.57008576 0.60090542]
# 6 day output [[0.6297679]]
# 7 day input [0.12831157 0.12871967 0.13247169 0.15064282 0.15858914 0.18794618
#  0.20505352 0.20470837 0.25546745 0.25546091 0.28237207 0.26862035
#  0.27062176 0.27217356 0.27593569 0.27949973 0.28416343 0.2868073
#  0.29070917 0.29129565 0.28889592 0.29661906 0.29996952 0.31914422
#  0.306873   0.30433094 0.28954393 0.27959954 0.31680574 0.28728705
#  0.2892624  0.25742934 0.25634669 0.26353915 0.2652765  0.27961082
#  0.28066932 0.29022858 0.28991563 0.30260387 0.30264388 0.30339024
#  0.32293117 0.34670194 0.32809055 0.3276599  0.32756686 0.32723741
#  0.32216762 0.2871018  0.27941307 0.27714358 0.27528254 0.27526547
#  0.26494889 0.2617989  0.2373987  0.23541548 0.21182412 0.21076443
#  0.18708407 0.18707429 0.18639876 0.13280455 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01245888 0.08721499 0.12679627 0.12679627
#  0.12667225 0.17544398 0.21035892 0.21065095 0.21065095 0.23960185
#  0.25003415 0.25437913 0.2823053  0.29316926 0.29705464 0.29710798
#  0.31643045 0.32388954 0.32828197 0.44237304 0.47369599 0.506091
#  0.53853941 0.57008576 0.60090542 0.62976789]
# 7 day output [[0.65605086]]
# 8 day input [0.12871967 0.13247169 0.15064282 0.15858914 0.18794618 0.20505352
#  0.20470837 0.25546745 0.25546091 0.28237207 0.26862035 0.27062176
#  0.27217356 0.27593569 0.27949973 0.28416343 0.2868073  0.29070917
#  0.29129565 0.28889592 0.29661906 0.29996952 0.31914422 0.306873
#  0.30433094 0.28954393 0.27959954 0.31680574 0.28728705 0.2892624
#  0.25742934 0.25634669 0.26353915 0.2652765  0.27961082 0.28066932
#  0.29022858 0.28991563 0.30260387 0.30264388 0.30339024 0.32293117
#  0.34670194 0.32809055 0.3276599  0.32756686 0.32723741 0.32216762
#  0.2871018  0.27941307 0.27714358 0.27528254 0.27526547 0.26494889
#  0.2617989  0.2373987  0.23541548 0.21182412 0.21076443 0.18708407
#  0.18707429 0.18639876 0.13280455 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01245888 0.08721499 0.12679627 0.12679627 0.12667225
#  0.17544398 0.21035892 0.21065095 0.21065095 0.23960185 0.25003415
#  0.25437913 0.2823053  0.29316926 0.29705464 0.29710798 0.31643045
#  0.32388954 0.32828197 0.44237304 0.47369599 0.506091   0.53853941
#  0.57008576 0.60090542 0.62976789 0.65605086]
# 8 day output [[0.6794536]]
# 9 day input [0.13247169 0.15064282 0.15858914 0.18794618 0.20505352 0.20470837
#  0.25546745 0.25546091 0.28237207 0.26862035 0.27062176 0.27217356
#  0.27593569 0.27949973 0.28416343 0.2868073  0.29070917 0.29129565
#  0.28889592 0.29661906 0.29996952 0.31914422 0.306873   0.30433094
#  0.28954393 0.27959954 0.31680574 0.28728705 0.2892624  0.25742934
#  0.25634669 0.26353915 0.2652765  0.27961082 0.28066932 0.29022858
#  0.28991563 0.30260387 0.30264388 0.30339024 0.32293117 0.34670194
#  0.32809055 0.3276599  0.32756686 0.32723741 0.32216762 0.2871018
#  0.27941307 0.27714358 0.27528254 0.27526547 0.26494889 0.2617989
#  0.2373987  0.23541548 0.21182412 0.21076443 0.18708407 0.18707429
#  0.18639876 0.13280455 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01121447 0.01121447 0.01121447 0.01121447 0.01121447 0.01121447
#  0.01245888 0.08721499 0.12679627 0.12679627 0.12667225 0.17544398
#  0.21035892 0.21065095 0.21065095 0.23960185 0.25003415 0.25437913
#  0.2823053  0.29316926 0.29705464 0.29710798 0.31643045 0.32388954
#  0.32828197 0.44237304 0.47369599 0.506091   0.53853941 0.57008576
#  0.60090542 0.62976789 0.65605086 0.67945361]
# 9 day output [[0.6997853]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,111)

# %%
plt.plot(day_new,scaler.inverse_transform(df[339:]),color ='blue', label ='origial')
plt.plot(day_pred,scaler.inverse_transform(lst_output),color='red', label='future')
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 10 Days Forecasting')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=df.tolist()
df3.extend(lst_output)
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 30 Days Forecasting')
plt.plot(df3[409:],color='red', label='future')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)

# %%
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
df=pd.read_csv("/content/BRACBANK.csv",parse_dates=['DATE'])
df.head()
# Out:
#      #       DATE TRADING CODE  LTP*  ...   YCP   TRADE  VALUE (mn)     VOLUME
# 0  439 2018-05-08     BRACBANK  68.3  ...  69.1   588.0      34.442   502038.0
# 1  438 2018-06-08     BRACBANK  71.6  ...  68.2  1826.0     125.978  1796391.0
# 2  437 2018-07-08     BRACBANK  73.7  ...  71.3  1811.0     111.683  1525306.0
# 3  436 2018-08-08     BRACBANK  74.3  ...  73.6  1900.0     144.013  1952596.0
# 4  435 2018-09-08     BRACBANK  73.5  ...  74.5  1207.0      83.986  1136820.0
#
# [5 rows x 12 columns]

# %%
# Sort DataFrame by date
df = df.sort_values('DATE')

# Double check the result
df.head()
# Out:
#       #       DATE TRADING CODE  LTP*  ...   YCP  TRADE  VALUE (mn)     VOLUME
# 36  403 2018-01-10     BRACBANK  71.5  ...  71.8  308.0      10.398   144998.0
# 59  380 2018-01-11     BRACBANK  69.6  ...  70.4  703.0      46.859   667978.0
# 37  402 2018-02-10     BRACBANK  72.3  ...  71.3  352.0      12.633   175816.0
# 79  360 2018-02-12     BRACBANK  72.9  ...  72.7  247.0      15.192   209760.0
# 16  423 2018-03-09     BRACBANK  76.7  ...  77.0  952.0      84.725  1104301.0
#
# [5 rows x 12 columns]

# %%
df = df.set_index('DATE')
df.head(3)
# Out:
#               # TRADING CODE  LTP*  HIGH  ...   YCP  TRADE  VALUE (mn)    VOLUME
# DATE                                      ...
# 2018-01-10  403     BRACBANK  71.5  72.4  ...  71.8  308.0      10.398  144998.0
# 2018-01-11  380     BRACBANK  69.6  70.6  ...  70.4  703.0      46.859  667978.0
# 2018-02-10  402     BRACBANK  72.3  72.4  ...  71.3  352.0      12.633  175816.0
#
# [3 rows x 11 columns]

# %%
df['daily_ret'] = df['CLOSEP*'].pct_change()
df['daily_ret'] = df['daily_ret'].fillna(0.0)

# %%
df['volatility']= df['daily_ret'].rolling(window=21).std()
df['volatility'] = df['volatility'].fillna(0.0)

# %%
df['volatility'] = df['volatility']*100

# %%
import matplotlib.pyplot as plt

# %%
df=df.reset_index()['volatility']

# %%
plt.plot(df)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
df.shape
# Out:
# (439, 1)

# %%
##splitting dataset into train and test split where train=70 percent and test=30 percent
training_size=int(len(df)*0.70)
test_size=len(df)-training_size
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
training_size,test_size
# Out:
# (307, 132)

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [],[]
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (206, 100)
# (206,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import Bidirectional

# %%
model=Sequential()
model.add(Bidirectional(LSTM(50,return_sequences=True,input_shape=(100,1))))
model.add(Bidirectional(LSTM(50,return_sequences=True)))
model.add(Bidirectional(LSTM(50)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=32,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 14s 615ms/step - loss: 0.0733 - val_loss: 0.0319
# Epoch 2/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0113 - val_loss: 0.0670
# Epoch 3/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0084 - val_loss: 0.0362
# Epoch 4/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0063 - val_loss: 0.0595
# Epoch 5/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0062 - val_loss: 0.0427
# Epoch 6/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0049 - val_loss: 0.0539
# Epoch 7/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0042 - val_loss: 0.0494
# Epoch 8/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0043 - val_loss: 0.0474
# Epoch 9/100
# 7/7 [==============================] - 2s 265ms/step - loss: 0.0047 - val_loss: 0.0540
# Epoch 10/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0039 - val_loss: 0.0494
# Epoch 11/100
# 7/7 [==============================] - 2s 247ms/step - loss: 0.0038 - val_loss: 0.0644
# Epoch 12/100
# 7/7 [==============================] - 2s 246ms/step - loss: 0.0037 - val_loss: 0.0435
# Epoch 13/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0039 - val_loss: 0.0605
# Epoch 14/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0033 - val_loss: 0.0572
# Epoch 15/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0033 - val_loss: 0.0652
# Epoch 16/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0029 - val_loss: 0.0579
# Epoch 17/100
# 7/7 [==============================] - 2s 269ms/step - loss: 0.0030 - val_loss: 0.1143
# Epoch 18/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0044 - val_loss: 0.0679
# Epoch 19/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0032 - val_loss: 0.0447
# Epoch 20/100
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0030 - val_loss: 0.0497
# Epoch 21/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0025 - val_loss: 0.0638
# Epoch 22/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0030 - val_loss: 0.0488
# Epoch 23/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0023 - val_loss: 0.0686
# Epoch 24/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0030 - val_loss: 0.0791
# Epoch 25/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0025 - val_loss: 0.0558
# Epoch 26/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0026 - val_loss: 0.0798
# Epoch 27/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0024 - val_loss: 0.0647
# Epoch 28/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0025 - val_loss: 0.0630
# Epoch 29/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.0025 - val_loss: 0.0721
# Epoch 30/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0025 - val_loss: 0.0896
# Epoch 31/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0034 - val_loss: 0.0661
# Epoch 32/100
# 7/7 [==============================] - 2s 262ms/step - loss: 0.0026 - val_loss: 0.0528
# Epoch 33/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0029 - val_loss: 0.0494
# Epoch 34/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0031 - val_loss: 0.0578
# Epoch 35/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0025 - val_loss: 0.0748
# Epoch 36/100
# 7/7 [==============================] - 2s 267ms/step - loss: 0.0021 - val_loss: 0.0539
# Epoch 37/100
# 7/7 [==============================] - 2s 268ms/step - loss: 0.0025 - val_loss: 0.0718
# Epoch 38/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0029 - val_loss: 0.0710
# Epoch 39/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0022 - val_loss: 0.0643
# Epoch 40/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0026 - val_loss: 0.0485
# Epoch 41/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0022 - val_loss: 0.0395
# Epoch 42/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0024 - val_loss: 0.0617
# Epoch 43/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0026 - val_loss: 0.0763
# Epoch 44/100
# 7/7 [==============================] - 2s 247ms/step - loss: 0.0035 - val_loss: 0.0183
# Epoch 45/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0042 - val_loss: 0.0563
# Epoch 46/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0029 - val_loss: 0.0529
# Epoch 47/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0029 - val_loss: 0.0450
# Epoch 48/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0027 - val_loss: 0.0626
# Epoch 49/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0023 - val_loss: 0.0544
# Epoch 50/100
# 7/7 [==============================] - 2s 252ms/step - loss: 0.0029 - val_loss: 0.0590
# Epoch 51/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0022 - val_loss: 0.0566
# Epoch 52/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0017 - val_loss: 0.0602
# Epoch 53/100
# 7/7 [==============================] - 2s 246ms/step - loss: 0.0025 - val_loss: 0.0388
# Epoch 54/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0025 - val_loss: 0.0535
# Epoch 55/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0023 - val_loss: 0.0516
# Epoch 56/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0024 - val_loss: 0.0479
# Epoch 57/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0025 - val_loss: 0.0441
# Epoch 58/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.0022 - val_loss: 0.0552
# Epoch 59/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0024 - val_loss: 0.0339
# Epoch 60/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0020 - val_loss: 0.0452
# Epoch 61/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0019 - val_loss: 0.0239
# Epoch 62/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0030 - val_loss: 0.0370
# Epoch 63/100
# 7/7 [==============================] - 2s 246ms/step - loss: 0.0017 - val_loss: 0.0330
# Epoch 64/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0023 - val_loss: 0.0357
# Epoch 65/100
# 7/7 [==============================] - 2s 256ms/step - loss: 0.0019 - val_loss: 0.0257
# Epoch 66/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0025 - val_loss: 0.0268
# Epoch 67/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0022 - val_loss: 0.0312
# Epoch 68/100
# 7/7 [==============================] - 2s 246ms/step - loss: 0.0020 - val_loss: 0.0316
# Epoch 69/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0026 - val_loss: 0.0150
# Epoch 70/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0027 - val_loss: 0.0265
# Epoch 71/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0022 - val_loss: 0.0450
# Epoch 72/100
# 7/7 [==============================] - 2s 241ms/step - loss: 0.0025 - val_loss: 0.0225
# Epoch 73/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0020 - val_loss: 0.0374
# Epoch 74/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0023 - val_loss: 0.0401
# Epoch 75/100
# 7/7 [==============================] - 2s 258ms/step - loss: 0.0021 - val_loss: 0.0156
# Epoch 76/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0020 - val_loss: 0.0352
# Epoch 77/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0028 - val_loss: 0.0284
# Epoch 78/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0019 - val_loss: 0.0290
# Epoch 79/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0021 - val_loss: 0.0377
# Epoch 80/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0024 - val_loss: 0.0165
# Epoch 81/100
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0028 - val_loss: 0.0270
# Epoch 82/100
# 7/7 [==============================] - 2s 247ms/step - loss: 0.0020 - val_loss: 0.0236
# Epoch 83/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0017 - val_loss: 0.0175
# Epoch 84/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0022 - val_loss: 0.0233
# Epoch 85/100
# 7/7 [==============================] - 2s 247ms/step - loss: 0.0022 - val_loss: 0.0208
# Epoch 86/100
# 7/7 [==============================] - 2s 249ms/step - loss: 0.0017 - val_loss: 0.0235
# Epoch 87/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0017 - val_loss: 0.0232
# Epoch 88/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0018 - val_loss: 0.0212
# Epoch 89/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0030 - val_loss: 0.0289
# Epoch 90/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0018 - val_loss: 0.0222
# Epoch 91/100
# 7/7 [==============================] - 2s 255ms/step - loss: 0.0017 - val_loss: 0.0246
# Epoch 92/100
# 7/7 [==============================] - 2s 245ms/step - loss: 0.0020 - val_loss: 0.0241
# Epoch 93/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0022 - val_loss: 0.0373
# Epoch 94/100
# 7/7 [==============================] - 2s 244ms/step - loss: 0.0023 - val_loss: 0.0233
# Epoch 95/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0023 - val_loss: 0.0219
# Epoch 96/100
# 7/7 [==============================] - 2s 253ms/step - loss: 0.0022 - val_loss: 0.0225
# Epoch 97/100
# 7/7 [==============================] - 2s 251ms/step - loss: 0.0017 - val_loss: 0.0233
# Epoch 98/100
# 7/7 [==============================] - 2s 248ms/step - loss: 0.0023 - val_loss: 0.0315
# Epoch 99/100
# 7/7 [==============================] - 2s 243ms/step - loss: 0.0020 - val_loss: 0.0219
# Epoch 100/100
# 7/7 [==============================] - 2s 246ms/step - loss: 0.0026 - val_loss: 0.0236

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath = "/content/drive/MyDrive/stock_price_BILSTM/modelsBRACBANK/model.h5"
model.save(filepath)

# %%
from keras.models import load_model
f1 = '/content/drive/MyDrive/stock_price_BILSTM/modelsBRACBANK/model.h5'
model = load_model(f1)

# %%
import tensorflow as tf
from sklearn.metrics import r2_score

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
##Transformback to original form
train_predict = np.reshape(train_predict,(1, train_predict.size))
train_predict=scaler.inverse_transform(train_predict)
test_predict = np.reshape(test_predict,(1, test_predict.size))
test_predict=scaler.inverse_transform(test_predict)
X = np.reshape(ytest,(1, ytest.size))
Y_test =scaler.inverse_transform(X)

# %%
Y_test
# Out:
# array([[17.15806749, 13.36726854, 13.36726854, 11.24067114, 11.24067114,
#         11.24067114, 11.24067114, 11.24067114, 11.24067114, 11.24067114,
#         11.24067114, 11.24067114, 11.24067114, 14.94976376, 15.84083871,
#         16.15588539, 16.15588539, 16.7584975 , 15.24011493, 16.73421407,
#         16.78685133, 16.78685133, 19.05954192, 19.75470198, 19.9824604 ,
#         22.31636981, 23.13042591, 23.31064053, 25.36381592, 25.3927773 ,
#         26.23070224]])

# %%
test_predict
# Out:
# array([[29.66902 , 29.073784, 26.836254, 24.903234, 22.203482, 19.843208,
#         17.806152, 16.04788 , 14.518204, 13.171262, 11.97006 , 10.893348,
#          9.900938,  9.000947, 10.354613, 12.053782, 13.59736 , 14.766052,
#         16.01046 , 16.014   , 16.898499, 17.702028, 18.385757, 20.424398,
#         22.586609, 24.449825, 27.272766, 29.847393, 31.759594, 34.084072,
#         35.68822 ]], dtype=float32)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
#Y_test = Y_test.transpose()
RMSE = math.sqrt(mean_squared_error(Y_test,test_predict))
RMSE
# Out:
# 4.045217278678284

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(Y_test,test_predict)
print('MAE: %f' % mae)
# Out:
# MAE: 3.396423

# %%
train_predict.shape
# Out:
# (1, 206)

# %%
test_predict.shape
# Out:
# (1, 31)

# %%
test_predict = test_predict.transpose()

# %%
train_predict = train_predict.transpose()

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df),color ='blue', label ='original')
plt.plot(trainPredictPlot, color ='orange', label ='predicted')
plt.plot(testPredictPlot , color ='red', label ='tested')
#plt.show()
plt.xlabel('number of days')
plt.ylabel('volatility magnitude')
plt.title('ABBANk Risk Factor Prediction')
plt.legend(loc='best')
plt.show(block=False)

# %%
x_input=test_data[32:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<10):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

#print(lst_output)
# Out:
# [1.4490368]
# 101
# 1 day input [0.51210885 0.50923438 0.50037438 0.49974268 0.49855523 0.49868973
#  0.49866203 0.4986671  0.49866217 0.49876539 0.49905756 0.50038074
#  0.50248555 0.5401781  0.55325047 0.55200546 0.63149407 0.61007954
#  0.47019818 0.47146165 0.47149886 0.47133238 0.47069116 0.4711255
#  0.47560073 0.48161761 0.4827215  0.54931664 0.58232504 0.59445329
#  0.59453452 0.59466735 0.59387626 0.59729281 0.58117309 0.56485044
#  0.56485044 0.4083372  0.39737828 0.58782121 0.61545104 0.62824825
#  0.80012972 0.80161183 0.82258751 0.8334233  0.82884295 0.91463601
#  0.88356878 0.90701564 0.8957743  0.8957743  0.89587319 0.89331425
#  0.88707659 0.8806701  0.8808582  0.8808582  0.8808582  0.8808582
#  0.77410108 0.75168507 0.73844966 0.64743691 0.69239078 0.66983093
#  0.65207297 0.65207297 0.50800794 0.50800794 0.42718901 0.42718901
#  0.42718901 0.42718901 0.42718901 0.42718901 0.42718901 0.42718901
#  0.42718901 0.42718901 0.56814888 0.60201318 0.61398617 0.61398617
#  0.63688777 0.57918335 0.6359649  0.63796532 0.63796532 0.72433636
#  0.75075513 0.75941083 0.84810842 0.87904571 0.88589456 0.96392317
#  0.96502381 0.99686821 1.         1.44903684]
# 1 day output [[1.6627096]]
# 2 day input [0.50923438 0.50037438 0.49974268 0.49855523 0.49868973 0.49866203
#  0.4986671  0.49866217 0.49876539 0.49905756 0.50038074 0.50248555
#  0.5401781  0.55325047 0.55200546 0.63149407 0.61007954 0.47019818
#  0.47146165 0.47149886 0.47133238 0.47069116 0.4711255  0.47560073
#  0.48161761 0.4827215  0.54931664 0.58232504 0.59445329 0.59453452
#  0.59466735 0.59387626 0.59729281 0.58117309 0.56485044 0.56485044
#  0.4083372  0.39737828 0.58782121 0.61545104 0.62824825 0.80012972
#  0.80161183 0.82258751 0.8334233  0.82884295 0.91463601 0.88356878
#  0.90701564 0.8957743  0.8957743  0.89587319 0.89331425 0.88707659
#  0.8806701  0.8808582  0.8808582  0.8808582  0.8808582  0.77410108
#  0.75168507 0.73844966 0.64743691 0.69239078 0.66983093 0.65207297
#  0.65207297 0.50800794 0.50800794 0.42718901 0.42718901 0.42718901
#  0.42718901 0.42718901 0.42718901 0.42718901 0.42718901 0.42718901
#  0.42718901 0.56814888 0.60201318 0.61398617 0.61398617 0.63688777
#  0.57918335 0.6359649  0.63796532 0.63796532 0.72433636 0.75075513
#  0.75941083 0.84810842 0.87904571 0.88589456 0.96392317 0.96502381
#  0.99686821 1.         1.44903684 1.66270959]
# 2 day output [[1.8898513]]
# 3 day input [0.50037438 0.49974268 0.49855523 0.49868973 0.49866203 0.4986671
#  0.49866217 0.49876539 0.49905756 0.50038074 0.50248555 0.5401781
#  0.55325047 0.55200546 0.63149407 0.61007954 0.47019818 0.47146165
#  0.47149886 0.47133238 0.47069116 0.4711255  0.47560073 0.48161761
#  0.4827215  0.54931664 0.58232504 0.59445329 0.59453452 0.59466735
#  0.59387626 0.59729281 0.58117309 0.56485044 0.56485044 0.4083372
#  0.39737828 0.58782121 0.61545104 0.62824825 0.80012972 0.80161183
#  0.82258751 0.8334233  0.82884295 0.91463601 0.88356878 0.90701564
#  0.8957743  0.8957743  0.89587319 0.89331425 0.88707659 0.8806701
#  0.8808582  0.8808582  0.8808582  0.8808582  0.77410108 0.75168507
#  0.73844966 0.64743691 0.69239078 0.66983093 0.65207297 0.65207297
#  0.50800794 0.50800794 0.42718901 0.42718901 0.42718901 0.42718901
#  0.42718901 0.42718901 0.42718901 0.42718901 0.42718901 0.42718901
#  0.56814888 0.60201318 0.61398617 0.61398617 0.63688777 0.57918335
#  0.6359649  0.63796532 0.63796532 0.72433636 0.75075513 0.75941083
#  0.84810842 0.87904571 0.88589456 0.96392317 0.96502381 0.99686821
#  1.         1.44903684 1.66270959 1.88985133]
# 3 day output [[2.1063282]]
# 4 day input [0.49974268 0.49855523 0.49868973 0.49866203 0.4986671  0.49866217
#  0.49876539 0.49905756 0.50038074 0.50248555 0.5401781  0.55325047
#  0.55200546 0.63149407 0.61007954 0.47019818 0.47146165 0.47149886
#  0.47133238 0.47069116 0.4711255  0.47560073 0.48161761 0.4827215
#  0.54931664 0.58232504 0.59445329 0.59453452 0.59466735 0.59387626
#  0.59729281 0.58117309 0.56485044 0.56485044 0.4083372  0.39737828
#  0.58782121 0.61545104 0.62824825 0.80012972 0.80161183 0.82258751
#  0.8334233  0.82884295 0.91463601 0.88356878 0.90701564 0.8957743
#  0.8957743  0.89587319 0.89331425 0.88707659 0.8806701  0.8808582
#  0.8808582  0.8808582  0.8808582  0.77410108 0.75168507 0.73844966
#  0.64743691 0.69239078 0.66983093 0.65207297 0.65207297 0.50800794
#  0.50800794 0.42718901 0.42718901 0.42718901 0.42718901 0.42718901
#  0.42718901 0.42718901 0.42718901 0.42718901 0.42718901 0.56814888
#  0.60201318 0.61398617 0.61398617 0.63688777 0.57918335 0.6359649
#  0.63796532 0.63796532 0.72433636 0.75075513 0.75941083 0.84810842
#  0.87904571 0.88589456 0.96392317 0.96502381 0.99686821 1.
#  1.44903684 1.66270959 1.88985133 2.10632825]
# 4 day output [[2.2935717]]
# 5 day input [0.49855523 0.49868973 0.49866203 0.4986671  0.49866217 0.49876539
#  0.49905756 0.50038074 0.50248555 0.5401781  0.55325047 0.55200546
#  0.63149407 0.61007954 0.47019818 0.47146165 0.47149886 0.47133238
#  0.47069116 0.4711255  0.47560073 0.48161761 0.4827215  0.54931664
#  0.58232504 0.59445329 0.59453452 0.59466735 0.59387626 0.59729281
#  0.58117309 0.56485044 0.56485044 0.4083372  0.39737828 0.58782121
#  0.61545104 0.62824825 0.80012972 0.80161183 0.82258751 0.8334233
#  0.82884295 0.91463601 0.88356878 0.90701564 0.8957743  0.8957743
#  0.89587319 0.89331425 0.88707659 0.8806701  0.8808582  0.8808582
#  0.8808582  0.8808582  0.77410108 0.75168507 0.73844966 0.64743691
#  0.69239078 0.66983093 0.65207297 0.65207297 0.50800794 0.50800794
#  0.42718901 0.42718901 0.42718901 0.42718901 0.42718901 0.42718901
#  0.42718901 0.42718901 0.42718901 0.42718901 0.56814888 0.60201318
#  0.61398617 0.61398617 0.63688777 0.57918335 0.6359649  0.63796532
#  0.63796532 0.72433636 0.75075513 0.75941083 0.84810842 0.87904571
#  0.88589456 0.96392317 0.96502381 0.99686821 1.         1.44903684
#  1.66270959 1.88985133 2.10632825 2.29357171]
# 5 day output [[2.443824]]
# 6 day input [0.49868973 0.49866203 0.4986671  0.49866217 0.49876539 0.49905756
#  0.50038074 0.50248555 0.5401781  0.55325047 0.55200546 0.63149407
#  0.61007954 0.47019818 0.47146165 0.47149886 0.47133238 0.47069116
#  0.4711255  0.47560073 0.48161761 0.4827215  0.54931664 0.58232504
#  0.59445329 0.59453452 0.59466735 0.59387626 0.59729281 0.58117309
#  0.56485044 0.56485044 0.4083372  0.39737828 0.58782121 0.61545104
#  0.62824825 0.80012972 0.80161183 0.82258751 0.8334233  0.82884295
#  0.91463601 0.88356878 0.90701564 0.8957743  0.8957743  0.89587319
#  0.89331425 0.88707659 0.8806701  0.8808582  0.8808582  0.8808582
#  0.8808582  0.77410108 0.75168507 0.73844966 0.64743691 0.69239078
#  0.66983093 0.65207297 0.65207297 0.50800794 0.50800794 0.42718901
#  0.42718901 0.42718901 0.42718901 0.42718901 0.42718901 0.42718901
#  0.42718901 0.42718901 0.42718901 0.56814888 0.60201318 0.61398617
#  0.61398617 0.63688777 0.57918335 0.6359649  0.63796532 0.63796532
#  0.72433636 0.75075513 0.75941083 0.84810842 0.87904571 0.88589456
#  0.96392317 0.96502381 0.99686821 1.         1.44903684 1.66270959
#  1.88985133 2.10632825 2.29357171 2.44382405]
# 6 day output [[2.5579696]]
# 7 day input [0.49866203 0.4986671  0.49866217 0.49876539 0.49905756 0.50038074
#  0.50248555 0.5401781  0.55325047 0.55200546 0.63149407 0.61007954
#  0.47019818 0.47146165 0.47149886 0.47133238 0.47069116 0.4711255
#  0.47560073 0.48161761 0.4827215  0.54931664 0.58232504 0.59445329
#  0.59453452 0.59466735 0.59387626 0.59729281 0.58117309 0.56485044
#  0.56485044 0.4083372  0.39737828 0.58782121 0.61545104 0.62824825
#  0.80012972 0.80161183 0.82258751 0.8334233  0.82884295 0.91463601
#  0.88356878 0.90701564 0.8957743  0.8957743  0.89587319 0.89331425
#  0.88707659 0.8806701  0.8808582  0.8808582  0.8808582  0.8808582
#  0.77410108 0.75168507 0.73844966 0.64743691 0.69239078 0.66983093
#  0.65207297 0.65207297 0.50800794 0.50800794 0.42718901 0.42718901
#  0.42718901 0.42718901 0.42718901 0.42718901 0.42718901 0.42718901
#  0.42718901 0.42718901 0.56814888 0.60201318 0.61398617 0.61398617
#  0.63688777 0.57918335 0.6359649  0.63796532 0.63796532 0.72433636
#  0.75075513 0.75941083 0.84810842 0.87904571 0.88589456 0.96392317
#  0.96502381 0.99686821 1.         1.44903684 1.66270959 1.88985133
#  2.10632825 2.29357171 2.44382405 2.55796957]
# 7 day output [[2.6411405]]
# 8 day input [0.4986671  0.49866217 0.49876539 0.49905756 0.50038074 0.50248555
#  0.5401781  0.55325047 0.55200546 0.63149407 0.61007954 0.47019818
#  0.47146165 0.47149886 0.47133238 0.47069116 0.4711255  0.47560073
#  0.48161761 0.4827215  0.54931664 0.58232504 0.59445329 0.59453452
#  0.59466735 0.59387626 0.59729281 0.58117309 0.56485044 0.56485044
#  0.4083372  0.39737828 0.58782121 0.61545104 0.62824825 0.80012972
#  0.80161183 0.82258751 0.8334233  0.82884295 0.91463601 0.88356878
#  0.90701564 0.8957743  0.8957743  0.89587319 0.89331425 0.88707659
#  0.8806701  0.8808582  0.8808582  0.8808582  0.8808582  0.77410108
#  0.75168507 0.73844966 0.64743691 0.69239078 0.66983093 0.65207297
#  0.65207297 0.50800794 0.50800794 0.42718901 0.42718901 0.42718901
#  0.42718901 0.42718901 0.42718901 0.42718901 0.42718901 0.42718901
#  0.42718901 0.56814888 0.60201318 0.61398617 0.61398617 0.63688777
#  0.57918335 0.6359649  0.63796532 0.63796532 0.72433636 0.75075513
#  0.75941083 0.84810842 0.87904571 0.88589456 0.96392317 0.96502381
#  0.99686821 1.         1.44903684 1.66270959 1.88985133 2.10632825
#  2.29357171 2.44382405 2.55796957 2.64114046]
# 8 day output [[2.6997664]]
# 9 day input [0.49866217 0.49876539 0.49905756 0.50038074 0.50248555 0.5401781
#  0.55325047 0.55200546 0.63149407 0.61007954 0.47019818 0.47146165
#  0.47149886 0.47133238 0.47069116 0.4711255  0.47560073 0.48161761
#  0.4827215  0.54931664 0.58232504 0.59445329 0.59453452 0.59466735
#  0.59387626 0.59729281 0.58117309 0.56485044 0.56485044 0.4083372
#  0.39737828 0.58782121 0.61545104 0.62824825 0.80012972 0.80161183
#  0.82258751 0.8334233  0.82884295 0.91463601 0.88356878 0.90701564
#  0.8957743  0.8957743  0.89587319 0.89331425 0.88707659 0.8806701
#  0.8808582  0.8808582  0.8808582  0.8808582  0.77410108 0.75168507
#  0.73844966 0.64743691 0.69239078 0.66983093 0.65207297 0.65207297
#  0.50800794 0.50800794 0.42718901 0.42718901 0.42718901 0.42718901
#  0.42718901 0.42718901 0.42718901 0.42718901 0.42718901 0.42718901
#  0.56814888 0.60201318 0.61398617 0.61398617 0.63688777 0.57918335
#  0.6359649  0.63796532 0.63796532 0.72433636 0.75075513 0.75941083
#  0.84810842 0.87904571 0.88589456 0.96392317 0.96502381 0.99686821
#  1.         1.44903684 1.66270959 1.88985133 2.10632825 2.29357171
#  2.44382405 2.55796957 2.64114046 2.6997664 ]
# 9 day output [[2.7399857]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,111)

# %%
plt.plot(day_new,scaler.inverse_transform(df[339:]),color ='blue', label ='origial')
plt.plot(day_pred,scaler.inverse_transform(lst_output),color='red', label='future')
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 10 Days Forecasting')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=df.tolist()
df3.extend(lst_output)
plt.xlabel('last 100 days+ future 30 days')
plt.ylabel('volatility magnitude')
plt.title('Next 30 Days Forecasting')
plt.plot(df3[409:],color='red', label='future')
plt.legend(loc='best')
plt.show(block=False)

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)
